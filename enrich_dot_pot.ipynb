# %% [markdown]
# # DataDash
#
# ### Final- and Visualization

# %% [markdown]
# ## Finding Lineage Subtypes and Primary Diseases for the ranked lists

# %%
#plt.scatter(x=allGenes['CDK4'].to_list(),y=allGenes['CDK6'].to_list())

# %%
import seaborn as sns

sns.regplot(x='CDK4', y='CDK6', data=allGenes)
r2(allGenes['CDK4'],allGenes['CDK6'])
# Out:
# 0.028077777128959116

# %%
sns.regplot(x='CDK4', y='PRDM1', data=allGenes)
r2(allGenes['CDK4'],allGenes['PRDM1'])
# Out:
# 0.0027215503029406557

# %%
def get_prd(pair):
    boolean_series = data.stripped_cell_line_name.isin(pair)
    prd_df = data[boolean_series]['primary_disease']
    #sub_df = data[boolean_series]['lineage_subtype']

    prd = pd.DataFrame(prd_df)
    #sub = pd.DataFrame(sub_df)
    #return [prd,sub]
    return prd

# %% [markdown]
# ## THIS GIVES US THE POWER TO ADD DISEASE ANNOTATION TO THE CORRELATION PLOTS

# %%
def get_cd(prd):
    prd = [prd]
    boolean_series = data.primary_disease.isin(prd)
    cd_df = data[boolean_series]['stripped_cell_line_name']
    
    cd = cd_df.to_list()
    return cd

# %%
disease_list = list(np.unique(data['primary_disease'].to_list()))

# %%
disease_annotation = []

for _ in gene_list:
    #print(_)
    #disease_annotation[_] =
    print(data[data['stripped_cell_line_name'] == _ ]['primary_disease'].iloc[''])
# Out:
# 3    Leukemia
# Name: primary_disease, dtype: object
# 4    Leukemia
# Name: primary_disease, dtype: object
# 6    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 8    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 10    Bladder Cancer
# Name: primary_disease, dtype: object
# 11    Lung Cancer
# Name: primary_disease, dtype: object
# 12    Ovarian Cancer
# Name: primary_disease, dtype: object
# 13    Skin Cancer
# Name: primary_disease, dtype: object
# 14    Lung Cancer
# Name: primary_disease, dtype: object
# 16    Breast Cancer
# Name: primary_disease, dtype: object
# 17    Bladder Cancer
# Name: primary_disease, dtype: object
# 18    Breast Cancer
# Name: primary_disease, dtype: object
# 20    Lung Cancer
# Name: primary_disease, dtype: object
# 21    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 23    Myeloma
# Name: primary_disease, dtype: object
# 24    Brain Cancer
# Name: primary_disease, dtype: object
# 27    Breast Cancer
# Name: primary_disease, dtype: object
# 28    Lung Cancer
# Name: primary_disease, dtype: object
# 29    Lung Cancer
# Name: primary_disease, dtype: object
# 34    Lung Cancer
# Name: primary_disease, dtype: object
# 35    Brain Cancer
# Name: primary_disease, dtype: object
# 36    Sarcoma
# Name: primary_disease, dtype: object
# 38    Bone Cancer
# Name: primary_disease, dtype: object
# 39    Brain Cancer
# Name: primary_disease, dtype: object
# 40    Bone Cancer
# Name: primary_disease, dtype: object
# 41    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 44    Leukemia
# Name: primary_disease, dtype: object
# 46    Gastric Cancer
# Name: primary_disease, dtype: object
# 47    Ovarian Cancer
# Name: primary_disease, dtype: object
# 51    Bone Cancer
# Name: primary_disease, dtype: object
# 52    Lymphoma
# Name: primary_disease, dtype: object
# 53    Sarcoma
# Name: primary_disease, dtype: object
# 54    Brain Cancer
# Name: primary_disease, dtype: object
# 59    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 66    Brain Cancer
# Name: primary_disease, dtype: object
# 69    Leukemia
# Name: primary_disease, dtype: object
# 73    Leukemia
# Name: primary_disease, dtype: object
# 74    Brain Cancer
# Name: primary_disease, dtype: object
# 75    Leukemia
# Name: primary_disease, dtype: object
# 77    Neuroblastoma
# Name: primary_disease, dtype: object
# 81    Bone Cancer
# Name: primary_disease, dtype: object
# 84    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 85    Lung Cancer
# Name: primary_disease, dtype: object
# 86    Bone Cancer
# Name: primary_disease, dtype: object
# 91    Lung Cancer
# Name: primary_disease, dtype: object
# Series([], Name: primary_disease, dtype: object)
# 95    Rhabdoid
# Name: primary_disease, dtype: object
# 96    Breast Cancer
# Name: primary_disease, dtype: object
# 97    Brain Cancer
# Name: primary_disease, dtype: object
# 98    Neuroblastoma
# Name: primary_disease, dtype: object
# 107    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 110    Breast Cancer
# Name: primary_disease, dtype: object
# 112    Leukemia
# Name: primary_disease, dtype: object
# 113    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 114    Prostate Cancer
# Name: primary_disease, dtype: object
# 115    Ovarian Cancer
# Name: primary_disease, dtype: object
# 117    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 119    Neuroblastoma
# Name: primary_disease, dtype: object
# 122    Ovarian Cancer
# Name: primary_disease, dtype: object
# 126    Kidney Cancer
# Name: primary_disease, dtype: object
# 127    Brain Cancer
# Name: primary_disease, dtype: object
# 131    Ovarian Cancer
# Name: primary_disease, dtype: object
# 132    Fibroblast
# Name: primary_disease, dtype: object
# 136    Brain Cancer
# Name: primary_disease, dtype: object
# 137    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 140    Gallbladder Cancer
# Name: primary_disease, dtype: object
# 141    Bladder Cancer
# Name: primary_disease, dtype: object
# 142    Lung Cancer
# Name: primary_disease, dtype: object
# 145    Leukemia
# Name: primary_disease, dtype: object
# 147    Breast Cancer
# Name: primary_disease, dtype: object
# 149    Lung Cancer
# Name: primary_disease, dtype: object
# 150    Leukemia
# Name: primary_disease, dtype: object
# 151    Brain Cancer
# Name: primary_disease, dtype: object
# 152    Lung Cancer
# Name: primary_disease, dtype: object
# 158    Kidney Cancer
# Name: primary_disease, dtype: object
# 159    Rhabdoid
# Name: primary_disease, dtype: object
# 162    Thyroid Cancer
# Name: primary_disease, dtype: object
# 163    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 166    Gastric Cancer
# Name: primary_disease, dtype: object
# 167    Leukemia
# Name: primary_disease, dtype: object
# 168    Sarcoma
# Name: primary_disease, dtype: object
# 173    Thyroid Cancer
# Name: primary_disease, dtype: object
# 177    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 181    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 182    Myeloma
# Name: primary_disease, dtype: object
# 186    Lung Cancer
# Name: primary_disease, dtype: object
# 187    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 188    Kidney Cancer
# Name: primary_disease, dtype: object
# 189    Lymphoma
# Name: primary_disease, dtype: object
# 197    Leukemia
# Name: primary_disease, dtype: object
# 199    Brain Cancer
# Name: primary_disease, dtype: object
# 201    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 203    Myeloma
# Name: primary_disease, dtype: object
# 205    Lymphoma
# Name: primary_disease, dtype: object
# 206    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 208    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 210    Brain Cancer
# Name: primary_disease, dtype: object
# 211    Breast Cancer
# Name: primary_disease, dtype: object
# 214    Brain Cancer
# Name: primary_disease, dtype: object
# 216    Liver Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 220    Liver Cancer
# Name: primary_disease, dtype: object
# 221    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 222    Breast Cancer
# Name: primary_disease, dtype: object
# 225    Lymphoma
# Name: primary_disease, dtype: object
# 226    Neuroblastoma
# Name: primary_disease, dtype: object
# 227    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 230    Brain Cancer
# Name: primary_disease, dtype: object
# 231    Brain Cancer
# Name: primary_disease, dtype: object
# 232    Lymphoma
# Name: primary_disease, dtype: object
# 233    Kidney Cancer
# Name: primary_disease, dtype: object
# 234    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 236    Ovarian Cancer
# Name: primary_disease, dtype: object
# 237    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 242    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 243    Brain Cancer
# Name: primary_disease, dtype: object
# 245    Kidney Cancer
# Name: primary_disease, dtype: object
# 246    Gastric Cancer
# Name: primary_disease, dtype: object
# 247    Breast Cancer
# Name: primary_disease, dtype: object
# 248    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 249    Kidney Cancer
# Name: primary_disease, dtype: object
# 250    Lung Cancer
# Name: primary_disease, dtype: object
# 252    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 254    Gastric Cancer
# Name: primary_disease, dtype: object
# 255    Ovarian Cancer
# Name: primary_disease, dtype: object
# 256    Lung Cancer
# Name: primary_disease, dtype: object
# 257    Breast Cancer
# Name: primary_disease, dtype: object
# 258    Neuroblastoma
# Name: primary_disease, dtype: object
# 259    Neuroblastoma
# Name: primary_disease, dtype: object
# 260    Lung Cancer
# Name: primary_disease, dtype: object
# 261    Kidney Cancer
# Name: primary_disease, dtype: object
# 262    Leukemia
# Name: primary_disease, dtype: object
# 263    Lung Cancer
# Name: primary_disease, dtype: object
# 264    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 265    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 270    Lymphoma
# Name: primary_disease, dtype: object
# 271    Kidney Cancer
# Name: primary_disease, dtype: object
# 272    Brain Cancer
# Name: primary_disease, dtype: object
# 273    Skin Cancer
# Name: primary_disease, dtype: object
# 275    Breast Cancer
# Name: primary_disease, dtype: object
# 276    Breast Cancer
# Name: primary_disease, dtype: object
# 277    Ovarian Cancer
# Name: primary_disease, dtype: object
# 278    Bone Cancer
# Name: primary_disease, dtype: object
# 279    Ovarian Cancer
# Name: primary_disease, dtype: object
# 280    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 285    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 287    Breast Cancer
# Name: primary_disease, dtype: object
# 289    Lung Cancer
# Name: primary_disease, dtype: object
# 290    Ovarian Cancer
# Name: primary_disease, dtype: object
# 291    Lung Cancer
# Name: primary_disease, dtype: object
# 292    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 293    Leukemia
# Name: primary_disease, dtype: object
# 294    Leukemia
# Name: primary_disease, dtype: object
# 295    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 301    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 303    Skin Cancer
# Name: primary_disease, dtype: object
# 304    Esophageal Cancer
# Name: primary_disease, dtype: object
# 306    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 307    Ovarian Cancer
# Name: primary_disease, dtype: object
# 309    Neuroblastoma
# Name: primary_disease, dtype: object
# 310    Lung Cancer
# Name: primary_disease, dtype: object
# 311    Neuroblastoma
# Name: primary_disease, dtype: object
# 314    Lymphoma
# Name: primary_disease, dtype: object
# 315    Liver Cancer
# Name: primary_disease, dtype: object
# 316    Kidney Cancer
# Name: primary_disease, dtype: object
# 317    Esophageal Cancer
# Name: primary_disease, dtype: object
# 318    Lung Cancer
# Name: primary_disease, dtype: object
# 319    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 321    Skin Cancer
# Name: primary_disease, dtype: object
# 322    Brain Cancer
# Name: primary_disease, dtype: object
# 323    Ovarian Cancer
# Name: primary_disease, dtype: object
# 325    Leukemia
# Name: primary_disease, dtype: object
# 328    Brain Cancer
# Name: primary_disease, dtype: object
# 329    Breast Cancer
# Name: primary_disease, dtype: object
# 330    Lung Cancer
# Name: primary_disease, dtype: object
# 331    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 333    Lymphoma
# Name: primary_disease, dtype: object
# 334    Lung Cancer
# Name: primary_disease, dtype: object
# 335    Leukemia
# Name: primary_disease, dtype: object
# 336    Lung Cancer
# Name: primary_disease, dtype: object
# 338    Lung Cancer
# Name: primary_disease, dtype: object
# 340    Neuroblastoma
# Name: primary_disease, dtype: object
# 342    Lung Cancer
# Name: primary_disease, dtype: object
# 343    Gastric Cancer
# Name: primary_disease, dtype: object
# 347    Skin Cancer
# Name: primary_disease, dtype: object
# 349    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 351    Breast Cancer
# Name: primary_disease, dtype: object
# 354    Lung Cancer
# Name: primary_disease, dtype: object
# 355    Gastric Cancer
# Name: primary_disease, dtype: object
# 360    Liver Cancer
# Name: primary_disease, dtype: object
# 361    Leukemia
# Name: primary_disease, dtype: object
# 362    Myeloma
# Name: primary_disease, dtype: object
# 363    Bone Cancer
# Name: primary_disease, dtype: object
# 364    Lymphoma
# Name: primary_disease, dtype: object
# 365    Neuroblastoma
# Name: primary_disease, dtype: object
# 367    Brain Cancer
# Name: primary_disease, dtype: object
# 369    Brain Cancer
# Name: primary_disease, dtype: object
# 373    Breast Cancer
# Name: primary_disease, dtype: object
# 374    Kidney Cancer
# Name: primary_disease, dtype: object
# 375    Brain Cancer
# Name: primary_disease, dtype: object
# 376    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 377    Lung Cancer
# Name: primary_disease, dtype: object
# 380    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 382    Esophageal Cancer
# Name: primary_disease, dtype: object
# 384    Kidney Cancer
# Name: primary_disease, dtype: object
# 386    Leukemia
# Name: primary_disease, dtype: object
# 388    Brain Cancer
# Name: primary_disease, dtype: object
# 389    Lung Cancer
# Name: primary_disease, dtype: object
# 392    Liver Cancer
# Name: primary_disease, dtype: object
# 394    Lung Cancer
# Name: primary_disease, dtype: object
# 396    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 400    Skin Cancer
# Name: primary_disease, dtype: object
# 401    Lymphoma
# Name: primary_disease, dtype: object
# 402    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 403    Skin Cancer
# Name: primary_disease, dtype: object
# 404    Leukemia
# Name: primary_disease, dtype: object
# 405    Leukemia
# Name: primary_disease, dtype: object
# 406    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 407    Esophageal Cancer
# Name: primary_disease, dtype: object
# 409    Bone Cancer
# Name: primary_disease, dtype: object
# 410    Kidney Cancer
# Name: primary_disease, dtype: object
# 413    Lung Cancer
# Name: primary_disease, dtype: object
# 414    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 415    Lung Cancer
# Name: primary_disease, dtype: object
# 419    Liver Cancer
# Name: primary_disease, dtype: object
# 420    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 421    Liver Cancer
# Name: primary_disease, dtype: object
# 423    Bone Cancer
# Name: primary_disease, dtype: object
# 424    Skin Cancer
# Name: primary_disease, dtype: object
# 424    Skin Cancer
# Name: primary_disease, dtype: object
# 425    Myeloma
# Name: primary_disease, dtype: object
# 426    Gastric Cancer
# Name: primary_disease, dtype: object
# 430    Lung Cancer
# Name: primary_disease, dtype: object
# 432    Kidney Cancer
# Name: primary_disease, dtype: object
# 433    Lung Cancer
# Name: primary_disease, dtype: object
# 434    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 435    Myeloma
# Name: primary_disease, dtype: object
# 436    Brain Cancer
# Name: primary_disease, dtype: object
# 437    Lung Cancer
# Name: primary_disease, dtype: object
# 443    Lung Cancer
# Name: primary_disease, dtype: object
# 444    Brain Cancer
# Name: primary_disease, dtype: object
# 447    Lung Cancer
# Name: primary_disease, dtype: object
# 449    Skin Cancer
# Name: primary_disease, dtype: object
# 451    Esophageal Cancer
# Name: primary_disease, dtype: object
# 453    Lung Cancer
# Name: primary_disease, dtype: object
# 457    Skin Cancer
# Name: primary_disease, dtype: object
# 458    Kidney Cancer
# Name: primary_disease, dtype: object
# 459    Ovarian Cancer
# Name: primary_disease, dtype: object
# 460    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 462    Lung Cancer
# Name: primary_disease, dtype: object
# 463    Brain Cancer
# Name: primary_disease, dtype: object
# 465    Gastric Cancer
# Name: primary_disease, dtype: object
# 466    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 467    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 468    Brain Cancer
# Name: primary_disease, dtype: object
# 469    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 470    Liver Cancer
# Name: primary_disease, dtype: object
# 471    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 472    Bladder Cancer
# Name: primary_disease, dtype: object
# 473    Liver Cancer
# Name: primary_disease, dtype: object
# 474    Liver Cancer
# Name: primary_disease, dtype: object
# 475    Skin Cancer
# Name: primary_disease, dtype: object
# 476    Liver Cancer
# Name: primary_disease, dtype: object
# 478    Liver Cancer
# Name: primary_disease, dtype: object
# 479    Lung Cancer
# Name: primary_disease, dtype: object
# 481    Liver Cancer
# Name: primary_disease, dtype: object
# 482    Kidney Cancer
# Name: primary_disease, dtype: object
# 483    Gastric Cancer
# Name: primary_disease, dtype: object
# 484    Bladder Cancer
# Name: primary_disease, dtype: object
# 485    Leukemia
# Name: primary_disease, dtype: object
# 486    Esophageal Cancer
# Name: primary_disease, dtype: object
# 488    Brain Cancer
# Name: primary_disease, dtype: object
# 489    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 491    Liver Cancer
# Name: primary_disease, dtype: object
# 493    Kidney Cancer
# Name: primary_disease, dtype: object
# 494    Lung Cancer
# Name: primary_disease, dtype: object
# 495    Leukemia
# Name: primary_disease, dtype: object
# 496    Bone Cancer
# Name: primary_disease, dtype: object
# 497    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 499    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 500    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 501    Brain Cancer
# Name: primary_disease, dtype: object
# 502    Sarcoma
# Name: primary_disease, dtype: object
# 504    Gastric Cancer
# Name: primary_disease, dtype: object
# 507    Lung Cancer
# Name: primary_disease, dtype: object
# 508    Lung Cancer
# Name: primary_disease, dtype: object
# 509    Myeloma
# Name: primary_disease, dtype: object
# 511    Lung Cancer
# Name: primary_disease, dtype: object
# 513    Bone Cancer
# Name: primary_disease, dtype: object
# 514    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 515    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 517    Ovarian Cancer
# Name: primary_disease, dtype: object
# 518    Lung Cancer
# Name: primary_disease, dtype: object
# 519    Bladder Cancer
# Name: primary_disease, dtype: object
# 521    Ovarian Cancer
# Name: primary_disease, dtype: object
# 524    Ovarian Cancer
# Name: primary_disease, dtype: object
# 525    Lung Cancer
# Name: primary_disease, dtype: object
# 532    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 534    Liver Cancer
# Name: primary_disease, dtype: object
# 538    Myeloma
# Name: primary_disease, dtype: object
# 539    Ovarian Cancer
# Name: primary_disease, dtype: object
# 541    Esophageal Cancer
# Name: primary_disease, dtype: object
# 542    Bladder Cancer
# Name: primary_disease, dtype: object
# 544    Bladder Cancer
# Name: primary_disease, dtype: object
# 545    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 546    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 547    Skin Cancer
# Name: primary_disease, dtype: object
# 548    Leukemia
# Name: primary_disease, dtype: object
# 549    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 553    Cervical Cancer
# Name: primary_disease, dtype: object
# 554    Leukemia
# Name: primary_disease, dtype: object
# 560    Lung Cancer
# Name: primary_disease, dtype: object
# 567    Brain Cancer
# Name: primary_disease, dtype: object
# 568    Brain Cancer
# Name: primary_disease, dtype: object
# 570    Breast Cancer
# Name: primary_disease, dtype: object
# 573    Myeloma
# Name: primary_disease, dtype: object
# 574    Liver Cancer
# Name: primary_disease, dtype: object
# 576    Skin Cancer
# Name: primary_disease, dtype: object
# 577    Skin Cancer
# Name: primary_disease, dtype: object
# 578    Gastric Cancer
# Name: primary_disease, dtype: object
# 580    Lymphoma
# Name: primary_disease, dtype: object
# 581    Ovarian Cancer
# Name: primary_disease, dtype: object
# 582    Lung Cancer
# Name: primary_disease, dtype: object
# 584    Lung Cancer
# Name: primary_disease, dtype: object
# 585    Myeloma
# Name: primary_disease, dtype: object
# 586    Lung Cancer
# Name: primary_disease, dtype: object
# 588    Brain Cancer
# Name: primary_disease, dtype: object
# 589    Brain Cancer
# Name: primary_disease, dtype: object
# 590    Bladder Cancer
# Name: primary_disease, dtype: object
# 593    Lung Cancer
# Name: primary_disease, dtype: object
# 596    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 597    Kidney Cancer
# Name: primary_disease, dtype: object
# 598    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 601    Leukemia
# Name: primary_disease, dtype: object
# 602    Esophageal Cancer
# Name: primary_disease, dtype: object
# 603    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 605    Ovarian Cancer
# Name: primary_disease, dtype: object
# 611    Skin Cancer
# Name: primary_disease, dtype: object
# 613    Gastric Cancer
# Name: primary_disease, dtype: object
# 615    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 616    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 617    Liver Cancer
# Name: primary_disease, dtype: object
# 618    Breast Cancer
# Name: primary_disease, dtype: object
# 619    Brain Cancer
# Name: primary_disease, dtype: object
# 620    Brain Cancer
# Name: primary_disease, dtype: object
# 621    Breast Cancer
# Name: primary_disease, dtype: object
# 624    Lung Cancer
# Name: primary_disease, dtype: object
# 627    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 629    Skin Cancer
# Name: primary_disease, dtype: object
# 630    Gastric Cancer
# Name: primary_disease, dtype: object
# 631    Brain Cancer
# Name: primary_disease, dtype: object
# 634    Esophageal Cancer
# Name: primary_disease, dtype: object
# 635    Lung Cancer
# Name: primary_disease, dtype: object
# 636    Lung Cancer
# Name: primary_disease, dtype: object
# 643    Ovarian Cancer
# Name: primary_disease, dtype: object
# 644    Esophageal Cancer
# Name: primary_disease, dtype: object
# 645    Lung Cancer
# Name: primary_disease, dtype: object
# 646    Kidney Cancer
# Name: primary_disease, dtype: object
# 648    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 649    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 650    Myeloma
# Name: primary_disease, dtype: object
# 651    Lymphoma
# Name: primary_disease, dtype: object
# 652    Brain Cancer
# Name: primary_disease, dtype: object
# 654    Ovarian Cancer
# Name: primary_disease, dtype: object
# 655    Myeloma
# Name: primary_disease, dtype: object
# 658    Skin Cancer
# Name: primary_disease, dtype: object
# 659    Lung Cancer
# Name: primary_disease, dtype: object
# 660    Ovarian Cancer
# Name: primary_disease, dtype: object
# 662    Lung Cancer
# Name: primary_disease, dtype: object
# 664    Lung Cancer
# Name: primary_disease, dtype: object
# 668    Liver Cancer
# Name: primary_disease, dtype: object
# 670    Brain Cancer
# Name: primary_disease, dtype: object
# 673    Brain Cancer
# Name: primary_disease, dtype: object
# 674    Lung Cancer
# Name: primary_disease, dtype: object
# 677    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 678    Lung Cancer
# Name: primary_disease, dtype: object
# 679    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 680    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 681    Kidney Cancer
# Name: primary_disease, dtype: object
# 682    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 685    Ovarian Cancer
# Name: primary_disease, dtype: object
# 690    Esophageal Cancer
# Name: primary_disease, dtype: object
# 691    Esophageal Cancer
# Name: primary_disease, dtype: object
# 692    Lung Cancer
# Name: primary_disease, dtype: object
# 693    Ovarian Cancer
# Name: primary_disease, dtype: object
# 694    Lymphoma
# Name: primary_disease, dtype: object
# 695    Lung Cancer
# Name: primary_disease, dtype: object
# 696    Breast Cancer
# Name: primary_disease, dtype: object
# 697    Lung Cancer
# Name: primary_disease, dtype: object
# 698    Ovarian Cancer
# Name: primary_disease, dtype: object
# 699    Lymphoma
# Name: primary_disease, dtype: object
# 703    Lung Cancer
# Name: primary_disease, dtype: object
# 708    Breast Cancer
# Name: primary_disease, dtype: object
# 710    Ovarian Cancer
# Name: primary_disease, dtype: object
# 711    Myeloma
# Name: primary_disease, dtype: object
# 715    Lung Cancer
# Name: primary_disease, dtype: object
# 717    Bladder Cancer
# Name: primary_disease, dtype: object
# 718    Breast Cancer
# Name: primary_disease, dtype: object
# 721    Bladder Cancer
# Name: primary_disease, dtype: object
# 722    Breast Cancer
# Name: primary_disease, dtype: object
# 729    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 731    Liver Cancer
# Name: primary_disease, dtype: object
# 732    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 733    Gastric Cancer
# Name: primary_disease, dtype: object
# 735    Brain Cancer
# Name: primary_disease, dtype: object
# 736    Liver Cancer
# Name: primary_disease, dtype: object
# 737    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 743    Gastric Cancer
# Name: primary_disease, dtype: object
# 744    Lung Cancer
# Name: primary_disease, dtype: object
# 745    Bone Cancer
# Name: primary_disease, dtype: object
# 750    Bladder Cancer
# Name: primary_disease, dtype: object
# 753    Brain Cancer
# Name: primary_disease, dtype: object
# 754    Lung Cancer
# Name: primary_disease, dtype: object
# 755    Gastric Cancer
# Name: primary_disease, dtype: object
# 757    Brain Cancer
# Name: primary_disease, dtype: object
# 759    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 760    Myeloma
# Name: primary_disease, dtype: object
# 761    Gastric Cancer
# Name: primary_disease, dtype: object
# 762    Skin Cancer
# Name: primary_disease, dtype: object
# 763    Lung Cancer
# Name: primary_disease, dtype: object
# 764    Lung Cancer
# Name: primary_disease, dtype: object
# 765    Breast Cancer
# Name: primary_disease, dtype: object
# 766    Lung Cancer
# Name: primary_disease, dtype: object
# 767    Leukemia
# Name: primary_disease, dtype: object
# 768    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 770    Lymphoma
# Name: primary_disease, dtype: object
# 771    Lung Cancer
# Name: primary_disease, dtype: object
# 772    Lung Cancer
# Name: primary_disease, dtype: object
# 773    Brain Cancer
# Name: primary_disease, dtype: object
# 774    Esophageal Cancer
# Name: primary_disease, dtype: object
# 775    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 778    Lung Cancer
# Name: primary_disease, dtype: object
# 779    Leukemia
# Name: primary_disease, dtype: object
# 780    Breast Cancer
# Name: primary_disease, dtype: object
# 781    Esophageal Cancer
# Name: primary_disease, dtype: object
# 782    Lung Cancer
# Name: primary_disease, dtype: object
# 784    Lung Cancer
# Name: primary_disease, dtype: object
# 785    Skin Cancer
# Name: primary_disease, dtype: object
# 787    Lung Cancer
# Name: primary_disease, dtype: object
# 788    Lung Cancer
# Name: primary_disease, dtype: object
# 789    Kidney Cancer
# Name: primary_disease, dtype: object
# 790    Gastric Cancer
# Name: primary_disease, dtype: object
# 791    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 793    Ovarian Cancer
# Name: primary_disease, dtype: object
# 796    Skin Cancer
# Name: primary_disease, dtype: object
# 797    Lung Cancer
# Name: primary_disease, dtype: object
# 798    Skin Cancer
# Name: primary_disease, dtype: object
# 799    Bladder Cancer
# Name: primary_disease, dtype: object
# 801    Neuroblastoma
# Name: primary_disease, dtype: object
# 802    Skin Cancer
# Name: primary_disease, dtype: object
# 804    Brain Cancer
# Name: primary_disease, dtype: object
# 806    Esophageal Cancer
# Name: primary_disease, dtype: object
# 807    Skin Cancer
# Name: primary_disease, dtype: object
# 808    Ovarian Cancer
# Name: primary_disease, dtype: object
# 811    Skin Cancer
# Name: primary_disease, dtype: object
# 814    Myeloma
# Name: primary_disease, dtype: object
# 816    Brain Cancer
# Name: primary_disease, dtype: object
# 817    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 818    Myeloma
# Name: primary_disease, dtype: object
# 819    Skin Cancer
# Name: primary_disease, dtype: object
# 820    Esophageal Cancer
# Name: primary_disease, dtype: object
# 821    Esophageal Cancer
# Name: primary_disease, dtype: object
# 823    Lung Cancer
# Name: primary_disease, dtype: object
# 824    Skin Cancer
# Name: primary_disease, dtype: object
# 826    Myeloma
# Name: primary_disease, dtype: object
# 828    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 829    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 830    Sarcoma
# Name: primary_disease, dtype: object
# 831    Bladder Cancer
# Name: primary_disease, dtype: object
# 832    Sarcoma
# Name: primary_disease, dtype: object
# 833    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 834    Lung Cancer
# Name: primary_disease, dtype: object
# 835    Myeloma
# Name: primary_disease, dtype: object
# 836    Bladder Cancer
# Name: primary_disease, dtype: object
# 837    Lung Cancer
# Name: primary_disease, dtype: object
# 838    Lung Cancer
# Name: primary_disease, dtype: object
# 840    Lung Cancer
# Name: primary_disease, dtype: object
# 843    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 844    Gastric Cancer
# Name: primary_disease, dtype: object
# 845    Liver Cancer
# Name: primary_disease, dtype: object
# 846    Breast Cancer
# Name: primary_disease, dtype: object
# 848    Lung Cancer
# Name: primary_disease, dtype: object
# 850    Lung Cancer
# Name: primary_disease, dtype: object
# 851    Myeloma
# Name: primary_disease, dtype: object
# 852    Esophageal Cancer
# Name: primary_disease, dtype: object
# 853    Breast Cancer
# Name: primary_disease, dtype: object
# 855    Lung Cancer
# Name: primary_disease, dtype: object
# 856    Breast Cancer
# Name: primary_disease, dtype: object
# 858    Lung Cancer
# Name: primary_disease, dtype: object
# 859    Bladder Cancer
# Name: primary_disease, dtype: object
# 862    Esophageal Cancer
# Name: primary_disease, dtype: object
# 863    Lung Cancer
# Name: primary_disease, dtype: object
# 864    Lung Cancer
# Name: primary_disease, dtype: object
# 866    Lung Cancer
# Name: primary_disease, dtype: object
# 869    Lung Cancer
# Name: primary_disease, dtype: object
# 870    Esophageal Cancer
# Name: primary_disease, dtype: object
# 873    Breast Cancer
# Name: primary_disease, dtype: object
# 875    Lung Cancer
# Name: primary_disease, dtype: object
# 877    Gastric Cancer
# Name: primary_disease, dtype: object
# 878    Skin Cancer
# Name: primary_disease, dtype: object
# 879    Skin Cancer
# Name: primary_disease, dtype: object
# 881    Skin Cancer
# Name: primary_disease, dtype: object
# 882    Ovarian Cancer
# Name: primary_disease, dtype: object
# 884    Brain Cancer
# Name: primary_disease, dtype: object
# 885    Lung Cancer
# Name: primary_disease, dtype: object
# 886    Myeloma
# Name: primary_disease, dtype: object
# 887    Lung Cancer
# Name: primary_disease, dtype: object
# 893    Bladder Cancer
# Name: primary_disease, dtype: object
# 895    Gastric Cancer
# Name: primary_disease, dtype: object
# 896    Skin Cancer
# Name: primary_disease, dtype: object
# 897    Lung Cancer
# Name: primary_disease, dtype: object
# 898    Lung Cancer
# Name: primary_disease, dtype: object
# 900    Thyroid Cancer
# Name: primary_disease, dtype: object
# 902    Bladder Cancer
# Name: primary_disease, dtype: object
# 903    Ovarian Cancer
# Name: primary_disease, dtype: object
# 904    Kidney Cancer
# Name: primary_disease, dtype: object
# 907    Breast Cancer
# Name: primary_disease, dtype: object
# 908    Gastric Cancer
# Name: primary_disease, dtype: object
# 909    Lung Cancer
# Name: primary_disease, dtype: object
# 910    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 911    Lymphoma
# Name: primary_disease, dtype: object
# 912    Skin Cancer
# Name: primary_disease, dtype: object
# 913    Lung Cancer
# Name: primary_disease, dtype: object
# 914    Esophageal Cancer
# Name: primary_disease, dtype: object
# 918    Lung Cancer
# Name: primary_disease, dtype: object
# 921    Lung Cancer
# Name: primary_disease, dtype: object
# 923    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 925    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 926    Lung Cancer
# Name: primary_disease, dtype: object
# 929    Gastric Cancer
# Name: primary_disease, dtype: object
# 932    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 933    Ovarian Cancer
# Name: primary_disease, dtype: object
# 934    Leukemia
# Name: primary_disease, dtype: object
# 935    Leukemia
# Name: primary_disease, dtype: object
# 936    Sarcoma
# Name: primary_disease, dtype: object
# 938    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 940    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 943    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 944    Ovarian Cancer
# Name: primary_disease, dtype: object
# 945    Gastric Cancer
# Name: primary_disease, dtype: object
# 947    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 950    Leukemia
# Name: primary_disease, dtype: object
# 954    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 955    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 956    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 957    Leukemia
# Name: primary_disease, dtype: object
# 958    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 960    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 962    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 965    Skin Cancer
# Name: primary_disease, dtype: object
# 966    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 970    Bladder Cancer
# Name: primary_disease, dtype: object
# 971    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 972    Lung Cancer
# Name: primary_disease, dtype: object
# 973    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 975    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 977    Lung Cancer
# Name: primary_disease, dtype: object
# 980    Leukemia
# Name: primary_disease, dtype: object
# 981    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 983    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 985    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 990    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 991    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 993    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 998    Bone Cancer
# Name: primary_disease, dtype: object
# 1009    Rhabdoid
# Name: primary_disease, dtype: object
# 1014    Rhabdoid
# Name: primary_disease, dtype: object
# 1017    Rhabdoid
# Name: primary_disease, dtype: object
# 1019    Bone Cancer
# Name: primary_disease, dtype: object
# 1024    Bone Cancer
# Name: primary_disease, dtype: object
# 1032    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1034    Sarcoma
# Name: primary_disease, dtype: object
# 1036    Brain Cancer
# Name: primary_disease, dtype: object
# 1037    Brain Cancer
# Name: primary_disease, dtype: object
# 1042    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1047    Brain Cancer
# Name: primary_disease, dtype: object
# 1051    Lung Cancer
# Name: primary_disease, dtype: object
# 1065    Sarcoma
# Name: primary_disease, dtype: object
# 1086    Leukemia
# Name: primary_disease, dtype: object
# 1090    Lymphoma
# Name: primary_disease, dtype: object
# 1102    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1104    Kidney Cancer
# Name: primary_disease, dtype: object
# 1105    Sarcoma
# Name: primary_disease, dtype: object
# 1109    Brain Cancer
# Name: primary_disease, dtype: object
# 1112    Bladder Cancer
# Name: primary_disease, dtype: object
# 1113    Sarcoma
# Name: primary_disease, dtype: object
# 1117    Skin Cancer
# Name: primary_disease, dtype: object
# 1118    Bone Cancer
# Name: primary_disease, dtype: object
# 1119    Bone Cancer
# Name: primary_disease, dtype: object
# 1121    Sarcoma
# Name: primary_disease, dtype: object
# 1122    Lymphoma
# Name: primary_disease, dtype: object
# 1128    Bone Cancer
# Name: primary_disease, dtype: object
# 1133    Rhabdoid
# Name: primary_disease, dtype: object
# 1134    Rhabdoid
# Name: primary_disease, dtype: object
# 1139    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 1142    Brain Cancer
# Name: primary_disease, dtype: object
# 1145    Skin Cancer
# Name: primary_disease, dtype: object
# 1149    Sarcoma
# Name: primary_disease, dtype: object
# 1150    Sarcoma
# Name: primary_disease, dtype: object
# 1151    Sarcoma
# Name: primary_disease, dtype: object
# 1152    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1153    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1154    Sarcoma
# Name: primary_disease, dtype: object
# 1156    Bone Cancer
# Name: primary_disease, dtype: object
# 1157    Rhabdoid
# Name: primary_disease, dtype: object
# 1158    Eye Cancer
# Name: primary_disease, dtype: object
# 1159    Neuroblastoma
# Name: primary_disease, dtype: object
# 1160    Neuroblastoma
# Name: primary_disease, dtype: object
# 1161    Neuroblastoma
# Name: primary_disease, dtype: object
# 1162    Neuroblastoma
# Name: primary_disease, dtype: object
# 1163    Thyroid Cancer
# Name: primary_disease, dtype: object
# 1166    Liver Cancer
# Name: primary_disease, dtype: object
# 1168    Sarcoma
# Name: primary_disease, dtype: object
# 1169    Skin Cancer
# Name: primary_disease, dtype: object
# 1170    Brain Cancer
# Name: primary_disease, dtype: object
# 1172    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 1173    Cervical Cancer
# Name: primary_disease, dtype: object
# 1175    Cervical Cancer
# Name: primary_disease, dtype: object
# 1176    Cervical Cancer
# Name: primary_disease, dtype: object
# 1179    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1180    Cervical Cancer
# Name: primary_disease, dtype: object
# 1181    Neuroblastoma
# Name: primary_disease, dtype: object
# 1182    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1183    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 1186    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 1187    Neuroblastoma
# Name: primary_disease, dtype: object
# 1189    Thyroid Cancer
# Name: primary_disease, dtype: object
# 1198    Neuroblastoma
# Name: primary_disease, dtype: object
# 1200    Esophageal Cancer
# Name: primary_disease, dtype: object
# 1201    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1204    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1205    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 1207    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 1209    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 1210    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 1211    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 1218    Breast Cancer
# Name: primary_disease, dtype: object
# 1219    Breast Cancer
# Name: primary_disease, dtype: object
# 1222    Breast Cancer
# Name: primary_disease, dtype: object
# 1224    Breast Cancer
# Name: primary_disease, dtype: object
# 1230    Cervical Cancer
# Name: primary_disease, dtype: object
# 1231    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1232    Bladder Cancer
# Name: primary_disease, dtype: object
# 1233    Bladder Cancer
# Name: primary_disease, dtype: object
# 1234    Bladder Cancer
# Name: primary_disease, dtype: object
# 1236    Bladder Cancer
# Name: primary_disease, dtype: object
# 1237    Bladder Cancer
# Name: primary_disease, dtype: object
# 1238    Bladder Cancer
# Name: primary_disease, dtype: object
# 1239    Bladder Cancer
# Name: primary_disease, dtype: object
# 1240    Bladder Cancer
# Name: primary_disease, dtype: object
# 1241    Bladder Cancer
# Name: primary_disease, dtype: object
# 1243    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1247    Bone Cancer
# Name: primary_disease, dtype: object
# 1248    Bone Cancer
# Name: primary_disease, dtype: object
# 1249    Sarcoma
# Name: primary_disease, dtype: object
# 1251    Cervical Cancer
# Name: primary_disease, dtype: object
# 1252    Thyroid Cancer
# Name: primary_disease, dtype: object
# 1253    Lymphoma
# Name: primary_disease, dtype: object
# 1254    Cervical Cancer
# Name: primary_disease, dtype: object
# 1257    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1259    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1260    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1261    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1262    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1263    Leukemia
# Name: primary_disease, dtype: object
# 1264    Leukemia
# Name: primary_disease, dtype: object
# 1267    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1268    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 1269    Esophageal Cancer
# Name: primary_disease, dtype: object
# 1272    Esophageal Cancer
# Name: primary_disease, dtype: object
# 1273    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 1274    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 1275    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 1276    Cervical Cancer
# Name: primary_disease, dtype: object
# 1278    Cervical Cancer
# Name: primary_disease, dtype: object
# 1280    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 1283    Leukemia
# Name: primary_disease, dtype: object
# 1284    Skin Cancer
# Name: primary_disease, dtype: object
# 1285    Skin Cancer
# Name: primary_disease, dtype: object
# 1286    Skin Cancer
# Name: primary_disease, dtype: object
# 1287    Skin Cancer
# Name: primary_disease, dtype: object
# 1288    Cervical Cancer
# Name: primary_disease, dtype: object
# 1289    Bone Cancer
# Name: primary_disease, dtype: object
# 1291    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 1292    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 1293    Rhabdoid
# Name: primary_disease, dtype: object
# 1294    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1295    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1299    Head and Neck Cancer
# Name: primary_disease, dtype: object
# 1302    Neuroblastoma
# Name: primary_disease, dtype: object
# 1303    Lung Cancer
# Name: primary_disease, dtype: object
# 1304    Skin Cancer
# Name: primary_disease, dtype: object
# 1305    Skin Cancer
# Name: primary_disease, dtype: object
# 1306    Skin Cancer
# Name: primary_disease, dtype: object
# 1307    Eye Cancer
# Name: primary_disease, dtype: object
# 1308    Lung Cancer
# Name: primary_disease, dtype: object
# 1312    Lung Cancer
# Name: primary_disease, dtype: object
# 1316    Skin Cancer
# Name: primary_disease, dtype: object
# 1317    Skin Cancer
# Name: primary_disease, dtype: object
# 1318    Skin Cancer
# Name: primary_disease, dtype: object
# 1319    Skin Cancer
# Name: primary_disease, dtype: object
# 1321    Skin Cancer
# Name: primary_disease, dtype: object
# 1330    Gallbladder Cancer
# Name: primary_disease, dtype: object
# 1331    Brain Cancer
# Name: primary_disease, dtype: object
# 1332    Brain Cancer
# Name: primary_disease, dtype: object
# 1333    Brain Cancer
# Name: primary_disease, dtype: object
# 1334    Brain Cancer
# Name: primary_disease, dtype: object
# 1338    Leukemia
# Name: primary_disease, dtype: object
# 1339    Gallbladder Cancer
# Name: primary_disease, dtype: object
# 1340    Brain Cancer
# Name: primary_disease, dtype: object
# 1341    Brain Cancer
# Name: primary_disease, dtype: object
# 1342    Brain Cancer
# Name: primary_disease, dtype: object
# 1346    Ovarian Cancer
# Name: primary_disease, dtype: object
# 1355    Skin Cancer
# Name: primary_disease, dtype: object
# 1356    Leukemia
# Name: primary_disease, dtype: object
# 1359    Cervical Cancer
# Name: primary_disease, dtype: object
# 1360    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 1361    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 1362    Gastric Cancer
# Name: primary_disease, dtype: object
# 1363    Esophageal Cancer
# Name: primary_disease, dtype: object
# 1364    Endometrial/Uterine Cancer
# Name: primary_disease, dtype: object
# 1366    Gastric Cancer
# Name: primary_disease, dtype: object
# 1369    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1371    Lymphoma
# Name: primary_disease, dtype: object
# 1373    Lymphoma
# Name: primary_disease, dtype: object
# 1387    Bone Cancer
# Name: primary_disease, dtype: object
# 1390    Leukemia
# Name: primary_disease, dtype: object
# 1391    Leukemia
# Name: primary_disease, dtype: object
# 1392    Leukemia
# Name: primary_disease, dtype: object
# 1394    Sarcoma
# Name: primary_disease, dtype: object
# 1397    Sarcoma
# Name: primary_disease, dtype: object
# 1398    Sarcoma
# Name: primary_disease, dtype: object
# 1400    Sarcoma
# Name: primary_disease, dtype: object
# 1402    Colon/Colorectal Cancer
# Name: primary_disease, dtype: object
# 1403    Sarcoma
# Name: primary_disease, dtype: object
# 1404    Liposarcoma
# Name: primary_disease, dtype: object
# 1405    Liposarcoma
# Name: primary_disease, dtype: object
# 1408    Liposarcoma
# Name: primary_disease, dtype: object
# 1409    Liposarcoma
# Name: primary_disease, dtype: object
# 1410    Liposarcoma
# Name: primary_disease, dtype: object
# 1413    Bone Cancer
# Name: primary_disease, dtype: object
# 1420    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1421    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1422    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1424    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1425    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1426    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1430    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1431    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1433    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1434    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1435    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1436    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1437    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1441    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1442    Bone Cancer
# Name: primary_disease, dtype: object
# 1443    Bone Cancer
# Name: primary_disease, dtype: object
# 1444    Bone Cancer
# Name: primary_disease, dtype: object
# 1446    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1447    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1451    Bile Duct Cancer
# Name: primary_disease, dtype: object
# 1452    Pancreatic Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 218    Skin Cancer
# Name: primary_disease, dtype: object
# 424    Skin Cancer
# Name: primary_disease, dtype: object
# 424    Skin Cancer
# Name: primary_disease, dtype: object
# 1457    Skin Cancer
# Name: primary_disease, dtype: object
# 1459    Eye Cancer
# Name: primary_disease, dtype: object
# 1460    Eye Cancer
# Name: primary_disease, dtype: object
# 1605    Bone Cancer
# Name: primary_disease, dtype: object

# %%
data[data['stripped_cell_line_name'] == 'HEL' ]['primary_disease']
# Out:
# 3    Leukemia
# Name: primary_disease, dtype: object

# %%
gene_list = allGenes.index.to_list()

# %%
data[data['stripped_cell_line_name'] == "HEL" ]['primary_disease']
# Out:
# 3    Leukemia
# Name: primary_disease, dtype: object

# %%
len(disease_list)
# Out:
# 29

# %%
blood_genes = allGenes[allGenes.index.isin(blood_list)]
blood_list = data[data['lineage'] == 'blood']['stripped_cell_line_name'].to_list()

# %%
#data.head()
# Out:
#      DepMap_ID stripped_cell_line_name CCLE_Name Alias  COSMICID   sex source  \
# 3   ACH-000004                     HEL       HEL   NaN  907053.0  Male   DSMZ
# 4   ACH-000005                 HEL9217   HEL9217   NaN       NaN  Male   ATCC
# 6   ACH-000007                   LS513     LS513   NaN  907795.0  Male   ATCC
# 8   ACH-000009                  C2BBE1    C2BBE1   NaN  910700.0  Male   ATCC
# 10  ACH-000011                    253J      253J   NaN       NaN  Male   KCLB
#
#     Achilles_n_replicates  cell_line_NNMD                   culture_type  ...  \
# 3                     2.0       -3.079202                     Suspension  ...
# 4                     2.0       -2.404409  Mixed adherent and suspension  ...
# 6                     2.0       -2.586708                       Adherent  ...
# 8                     3.0       -4.135491                       Adherent  ...
# 10                    1.0       -3.180379                       Adherent  ...
#
#    primary_or_metastasis          primary_disease  \
# 3                    NaN                 Leukemia
# 4                    NaN                 Leukemia
# 6                Primary  Colon/Colorectal Cancer
# 8                Primary  Colon/Colorectal Cancer
# 10            Metastasis           Bladder Cancer
#
#                                               Subtype   age Sanger_Model_ID  \
# 3   Acute Myelogenous Leukemia (AML), M6 (Erythrol...  30.0       SIDM00594
# 4   Acute Myelogenous Leukemia (AML), M6 (Erythrol...  30.0       SIDM00593
# 6                                      Adenocarcinoma  63.0       SIDM00677
# 8                                      Adenocarcinoma  72.0       SIDM01233
# 10                                          Carcinoma  53.0             NaN
#
#    depmap_public_comments        lineage            lineage_subtype  \
# 3                     NaN          blood                        AML
# 4                     NaN          blood                        AML
# 6                     NaN     colorectal  colorectal_adenocarcinoma
# 8                     NaN     colorectal  colorectal_adenocarcinoma
# 10                    NaN  urinary_tract          bladder_carcinoma
#
#    lineage_sub_subtype lineage_molecular_subtype
# 3                   M6                       NaN
# 4                   M6                       NaN
# 6                  NaN                       NaN
# 8                  NaN                       NaN
# 10                 NaN                       NaN
#
# [5 rows x 24 columns]

# %%
list(np.unique(data['Subtype'].to_list()))
# Out:
# ['ATL',
#  'Acute Lymphoblastic Leukemia (ALL), B-cell',
#  'Acute Lymphoblastic Leukemia (ALL), T-cell',
#  'Acute Myelogenous Leukemia (AML)',
#  'Acute Myelogenous Leukemia (AML), M2 (Myeloblastic)',
#  'Acute Myelogenous Leukemia (AML), M3 (Promyelocytic)',
#  'Acute Myelogenous Leukemia (AML), M4 (Myelomonocytic)',
#  'Acute Myelogenous Leukemia (AML), M5 (Eosinophilic/Monocytic)',
#  'Acute Myelogenous Leukemia (AML), M6 (Erythroleukemia)',
#  'Adenocarcinoma',
#  'Adenocarcinoma, clear cell',
#  'Adenocarcinoma, endometrioid',
#  'Adenocarcinoma, high grade serous',
#  'Adenocarcinoma, low grade serous',
#  'Adenocarcinoma, mixed',
#  'Adenocarcinoma, mucinous',
#  'Adenocarcinoma, serous',
#  'Adenocarcinoma, signet ring cell',
#  'Adenocarcinoma, tubular',
#  'Astrocytoma',
#  'Atypical Teratoid Rhabdoid Tumor (ATRT)',
#  'B-cell',
#  'B-cell, Hodgkins',
#  'B-cell, Non-Hodgkins',
#  'B-cell, Non-Hodgkins, Burkitts',
#  'B-cell, unspecified',
#  'Breast Ductal Carcinoma',
#  'Carcinoid',
#  'Carcinoma',
#  'Carcinoma, anaplastic',
#  'Carcinoma, brenner',
#  'Cervical Adenocarcinoma',
#  'Cholangiocarcinoma, extrahepatic',
#  'Cholangiocarcinoma, intrahepatic',
#  'Chondrosarcoma',
#  'Chordoma',
#  'Chordoma, sacral',
#  'Choriocarcinoma',
#  'Chronic Lymphoblastic Leukemia (CLL), B-cell',
#  'Chronic Myelogenous Leukemia (CML)',
#  'Chronic Myelogenous Leukemia (CML), blast crisis',
#  'Clear Cell Carcinoma',
#  'Cystadenocarcinoma',
#  'Cystadenocarcinoma, endometrioid',
#  'Cystadenocarcinoma, mucinous',
#  'DDLPS',
#  'Diffuse Large B-cell Lymphoma (DLBCL)',
#  'Ductal Adenocarcinoma, exocrine',
#  'Ductal Adenosquamous Carcinoma',
#  'Ductal Adenosquamous Carcinoma, exocrine',
#  'Endocervical Adenocarcinoma',
#  'Endometrial Adenocarcinoma',
#  'Endometrial Adenosquamous Carcinoma',
#  'Endometrial Squamous Cell Carcinoma',
#  'Endometrial Stromal Sarcoma',
#  'Epithelioid',
#  'Ewings Sarcoma',
#  'Fibrosarcoma',
#  'Glioblastoma',
#  'Glioma',
#  'Hepatoblastoma',
#  'Hepatocellular Carcinoma',
#  'Hepatocellular Carcinoma, HBs-antigen carrier',
#  'Hodgkins',
#  'Leiomyosarcoma',
#  'Malignant Mixed Mullerian Tumor (MMMT)',
#  'Malignant Rhabdoid Tumor',
#  'Medulloblastoma',
#  'Melanoma',
#  'Melanoma, amelanotic',
#  'Meningioma',
#  'Merkel Cell Carcinoma',
#  'Mesothelioma',
#  'Mullerian Carcinoma',
#  'Multiple Myeloma',
#  'Multiple Myeloma, plasmacytoma',
#  'Non-Small Cell Lung Cancer (NSCLC), Adenocarcinoma',
#  'Non-Small Cell Lung Cancer (NSCLC), Adenosquamous Carcinoma',
#  'Non-Small Cell Lung Cancer (NSCLC), Large Cell Carcinoma',
#  'Non-Small Cell Lung Cancer (NSCLC), Mucoepidermoid Carcinoma',
#  'Non-Small Cell Lung Cancer (NSCLC), Squamous Cell Carcinoma',
#  'Non-Small Cell Lung Cancer (NSCLC), unspecified',
#  'Oligodendroglioma',
#  'Osteosarcoma',
#  'Pleomorphic Sarcoma',
#  'Renal Carcinoma, clear cell',
#  'Renal Carcinoma, transitional cell',
#  'Renal Cell Carcinoma',
#  'Renal Leiomyoblastoma',
#  'Renal Medullary Carcinoma',
#  'Retinoblastoma',
#  'Rhabdomyosarcoma',
#  'Rhabdomyosarcoma, alveolar',
#  'Rhabdomyosarcoma, embryonal',
#  'Small Cell Carcinoma of the Ovary Hypercalcemic Type (SCCOHT)',
#  'Small Cell Lung Cancer (SCLC)',
#  'Soft tissue',
#  'Squamous Cell Carcinoma',
#  'Squamous Cell Carcinoma, basaloid',
#  'Squamous Cell Carcinoma, buccal mucosa',
#  'Squamous Cell Carcinoma, hypopharyngeal',
#  'Squamous Cell Carcinoma, laryngeal',
#  'Squamous Cell Carcinoma, oral',
#  'Squamous Cell Carcinoma, pharynx',
#  'Squamous Cell Carcinoma, salivary gland',
#  'Squamous Cell Carcinoma, tongue',
#  'Synovial',
#  'T-cell',
#  'T-cell, Non-Hodgkins, Anaplastic Large Cell (ALCL)',
#  'Thyroid Sarcoma',
#  'Transitional Cell Carcinoma',
#  'Undifferentiated',
#  'Uterine Carcinosarcoma',
#  'Uveal Melanoma',
#  'WDLPS',
#  'nan']

# %%
list(np.unique(data['lineage'].to_list()))
# Out:
# ['bile_duct',
#  'blood',
#  'bone',
#  'breast',
#  'central_nervous_system',
#  'cervix',
#  'colorectal',
#  'esophagus',
#  'eye',
#  'fibroblast',
#  'gastric',
#  'kidney',
#  'liver',
#  'lung',
#  'lymphocyte',
#  'ovary',
#  'pancreas',
#  'peripheral_nervous_system',
#  'plasma_cell',
#  'prostate',
#  'skin',
#  'soft_tissue',
#  'thyroid',
#  'upper_aerodigestive',
#  'urinary_tract',
#  'uterus']

# %%
blood_genes['CDK6'].hist()

# %%
blood_list = data[data['lineage'] == 'blood']['stripped_cell_line_name'].to_list()

# %%
import arviz as az
az.style.use("arviz-darkgrid")

axes = az.plot_forest([allGenes['CDK6'].to_numpy(),allGenes['CCND3'].to_numpy(),allGenes['CDK4'].to_numpy(),allGenes['CDK3'].to_numpy(),allGenes['ABL2'].to_numpy(),allGenes['PTEN'].to_numpy()],
            
                           kind='ridgeplot',
                           combined=True,
                           ridgeplot_overlap=7,
                           colors='white', figsize=(6, 5))

# %%
myeloma_genes['CDK6']
# Out:
# Series([], Name: CDK6, dtype: float64)

# %%
import arviz as az
az.style.use("arviz-darkgrid")

axes = az.plot_forest([blood_genes['CDK6'].to_numpy(),blood_genes['CDK4'].to_numpy(),blood_genes['CCND3'].to_numpy(),blood_genes['RB1'].to_numpy()],
                         #  var_names=blood_genes.columns,
                           kind='ridgeplot',
                           combined=True,
                           ridgeplot_overlap=4,
                           ridgeplot_truncate=False,
                           colors='white', figsize=(7, 6))

# %%
import matplotlib.pyplot as plt

import arviz as az

az.style.use("arviz-darkgrid")

centered_data = az.load_arviz_data("centered_eight")
non_centered_data = az.load_arviz_data("non_centered_eight")
axes = az.plot_forest(
    [centered_data, non_centered_data], model_names=["Centered", "Non Centered"], var_names=["mu"]
)
axes[0].set_title("Estimated theta for eight schools model")

plt.show()

# %%
myeloma_genes['CDK4'].hist()

# %%
myset
# Out:
#               CDK6      CDK4     CCND3
# OPM2     -1.489411 -0.269848 -0.225133
# L363     -1.335027 -0.414734 -0.164089
# LP1      -1.096695 -0.238041  0.025742
# SKMM2    -0.471727 -0.458140 -0.086353
# KMS20    -1.429418 -0.136413 -0.319554
# OCIMY7   -0.428250 -0.496009 -0.283632
# INA6     -0.178831 -0.146995 -0.332772
# KMS34    -0.382811 -0.559847  0.100125
# KMS27    -0.617880 -0.582266 -0.133719
# KMS26    -1.193799 -0.304155 -0.154346
# JJN3     -1.117529 -0.308197 -0.068591
# KMS18    -1.280850 -0.366414 -0.276698
# KMS11    -0.846788 -0.522419  0.062748
# MM1S     -1.445203 -0.072375 -0.151051
# RPMI8226 -1.217083 -1.071988 -0.375373
# EJM      -0.230636 -0.043012 -0.025801
# HUNS1    -0.806376 -0.183459 -0.033421
# AMO1     -1.067449 -0.494789 -0.074987
# OCIMY5   -1.643574 -0.041038 -0.005349
# KMM1     -1.159715 -1.098874 -0.953321

# %%
get_cd(["Myeloma"])
# Out:
# ['OPM2',
#  'NCIH929',
#  'OPM1',
#  'L363',
#  'KARPAS620',
#  'LP1',
#  'SKMM2',
#  'KMS12BM',
#  'KMS28BM',
#  'KMS20',
#  'OCIMY7',
#  'MOLP2',
#  'INA6',
#  'KMS34',
#  'KHM1B',
#  'KMS27',
#  'KMS26',
#  'KMS21BM',
#  'U266B1',
#  'JJN3',
#  'KMS18',
#  'KMS11',
#  'MOLP8',
#  'MM1S',
#  'RPMI8226',
#  'EJM',
#  'HUNS1',
#  'AMO1',
#  'OCIMY5',
#  'KMM1',
#  'COLO775',
#  'HTK',
#  'PCM6',
#  'KMS28PE']

# %%
data[data.stripped_cell_line_name == 'PCM6']
# Out:
#        DepMap_ID stripped_cell_line_name CCLE_Name Alias  COSMICID     sex  \
# 1103  ACH-001162                    PCM6      PCM6   NaN       NaN  Female
#
#      source  Achilles_n_replicates  cell_line_NNMD culture_type  ...  \
# 1103  RIKEN                    NaN             NaN          NaN  ...
#
#      primary_or_metastasis primary_disease           Subtype age  \
# 1103               Primary         Myeloma  Multiple Myeloma NaN
#
#      Sanger_Model_ID depmap_public_comments      lineage   lineage_subtype  \
# 1103             NaN                    NaN  plasma_cell  multiple_myeloma
#
#      lineage_sub_subtype lineage_molecular_subtype
# 1103                 NaN                       NaN
#
# [1 rows x 24 columns]

# %%
len(set(data.primary_disease.to_list()))  # there are 35 types of cancer in the depmap
# Out:
# 35

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

N = 35 # Number of labels

# setup the plot
fig, ax = plt.subplots(1,1, figsize=(6,6))
# define the data
x = allGenes['CDK4']
y = allGenes['PRDM1']
tag = [data[data.stripped_cell_line_name == x]['primary_disease'].to_list() for x in allGenes.index] # Tag each point with a corresponding label    

# define the colormap
cmap = plt.cm.jet
# extract all colors from the .jet map
cmaplist = [cmap(i) for i in range(cmap.N)]
# create the new map
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

# define the bins and normalize
bounds = np.linspace(0,N,N+1)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

# make the scatter
scat = ax.scatter(x,y,c=tag,cmap=cmap, norm=norm)
# create the colorbar
cb = plt.colorbar(scat, spacing='proportional',ticks=bounds)
cb.set_label('Custom cbar')
ax.set_title('Discrete color mappings')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4238             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4239                 colors = mcolors.to_rgba_array(c)
#    4240             except ValueError:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     184     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 185         rgba = _to_rgba_no_colorcycle(c, alpha)
#     186         try:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     267         # Test dimensionality to reject single floats.
# --> 268         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     269     # Return a tuple to prevent the cached value from being modified.
#
# ValueError: Invalid RGBA argument: ['Leukemia']
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-286-0d1a6cbb3771> in <module>
#      24
#      25 # make the scatter
# ---> 26 scat = ax.scatter(x,y,c=tag,cmap=cmap, norm=norm)
#      27 # create the colorbar
#      28 cb = plt.colorbar(scat, spacing='proportional',ticks=bounds)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4401             self._parse_scatter_color_args(
#    4402                 c, edgecolors, kwargs, x.size,
# -> 4403                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4404
#    4405         if plotnonfinite and colors is None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4244                 # severe failure => one may appreciate a verbose feedback.
#    4245                 raise ValueError(
# -> 4246                     f"'c' argument must be a color, a sequence of colors, or "
#    4247                     f"a sequence of numbers, not {c}")
#    4248             else:
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not [['Leukemia'], ['Leukemia'], ['Colon/Colorectal Cancer'], ['Colon/Colorectal Cancer'], ['Bladder Cancer'], ['Lung Cancer'], ['Ovarian Cancer'], ['Skin Cancer'], ['Lung Cancer'], ['Breast Cancer'], ['Bladder Cancer'], ['Breast Cancer'], ['Lung Cancer'], ['Pancreatic Cancer'], ['Myeloma'], ['Brain Cancer'], ['Breast Cancer'], ['Lung Cancer'], ['Lung Cancer'], ['Lung Cancer'], ['Brain Cancer'], ['Sarcoma'], ['Bone Cancer'], ['Brain Cancer'], ['Bone Cancer'], ['Pancreatic Cancer'], ['Leukemia'], ['Gastric Cancer'], ['Ovarian Cancer'], ['Bone Cancer'], ['Lymphoma'], ['Sarcoma'], ['Brain Cancer'], ['Pancreatic Cancer'], ['Brain Cancer'], ['Leukemia'], ['Leukemia'], ['Brain Cancer'], ['Leukemia'], ['Neuroblastoma'], ['Bone Cancer'], ['Pancreatic Cancer'], ['Lung Cancer'], ['Bone Cancer'], ['Lung Cancer'], [], ['Rhabdoid'], ['Breast Cancer'], ['Brain Cancer'], ['Neuroblastoma'], ['Pancreatic Cancer'], ['Breast Cancer'], ['Leukemia'], ['Pancreatic Cancer'], ['Prostate Cancer'], ['Ovarian Cancer'], ['Pancreatic Cancer'], ['Neuroblastoma'], ['Ovarian Cancer'], ['Kidney Cancer'], ['Brain Cancer'], ['Ovarian Cancer'], ['Fibroblast'], ['Brain Cancer'], ['Pancreatic Cancer'], ['Gallbladder Cancer'], ['Bladder Cancer'], ['Lung Cancer'], ['Leukemia'], ['Breast Cancer'], ['Lung Cancer'], ['Leukemia'], ['Brain Cancer'], ['Lung Cancer'], ['Kidney Cancer'], ['Rhabdoid'], ['Thyroid Cancer'], ['Pancreatic Cancer'], ['Gastric Cancer'], ['Leukemia'], ['Sarcoma'], ['Thyroid Cancer'], ['Pancreatic Cancer'], ['Bile Duct Cancer'], ['Myeloma'], ['Lung Cancer'], ['Head and Neck Cancer'], ['Kidney Cancer'], ['Lymphoma'], ['Leukemia'], ['Brain Cancer'], ['Colon/Colorectal Cancer'], ['Myeloma'], ['Lymphoma'], ['Head and Neck Cancer'], ['Bile Duct Cancer'], ['Brain Cancer'], ['Breast Cancer'], ['Brain Cancer'], ['Liver Cancer'], ['Skin Cancer'], ['Skin Cancer'], ['Skin Cancer'], ['Skin Cancer'], ['Liver Cancer'], ['Pancreatic Cancer'], ['Breast Cancer'], ['Lymphoma'], ['Neuroblastoma'], ['Head and Neck Cancer'], ['Brain Cancer'], ['Brain Cancer'], ['Lymphoma'], ['Kidney Cancer'], ['Pancreatic Cancer'], ['Ovarian Cancer'], ['Head and Neck Cancer'], ['Pancreatic Cancer'], ['Brain Cancer'], ['Kidney Cancer'], ['Gastric Cancer'], ['Breast Cancer'], ['Colon/Colorectal Cancer'], ['Kidney Cancer'], ['Lung Cancer'], ['Colon/Colorectal Cancer'], ['Gastric Cancer'], ['Ovarian Cancer'], ['Lung Cancer'], ['Breast Cancer'], ['Neuroblastoma'], ['Neuroblastoma'], ['Lung Cancer'], ['Kidney Cancer'], ['Leukemia'], ['Lung Cancer'], ['Pancreatic Cancer'], ['Pancreatic Cancer'], ['Lymphoma'], ['Kidney Cancer'], ['Brain Cancer'], ['Skin Cancer'], ['Breast Cancer'], ['Breast Cancer'], ['Ovarian Cancer'], ['Bone Cancer'], ['Ovarian Cancer'], ['Pancreatic Cancer'], ['Colon/Colorectal Cancer'], ['Breast Cancer'], ['Lung Cancer'], ['Ovarian Cancer'], ['Lung Cancer'], ['Endometrial/Uterine Cancer'], ['Leukemia'], ['Leukemia'], ['Colon/Colorectal Cancer'], ['Endometrial/Uterine Cancer'], ['Skin Cancer'], ['Esophageal Cancer'], ['Pancreatic Cancer'], ['Ovarian Cancer'], ['Neuroblastoma'], ['Lung Cancer'], ['Neuroblastoma'], ['Lymphoma'], ['Liver Cancer'], ['Kidney Cancer'], ['Esophageal Cancer'], ['Lung Cancer'], ['Pancreatic Cancer'], ['Skin Cancer'], ['Brain Cancer'], ['Ovarian Cancer'], ['Leukemia'], ['Brain Cancer'], ['Breast Cancer'], ['Lung Cancer'], ['Pancreatic Cancer'], ['Lymphoma'], ['Lung Cancer'], ['Leukemia'], ['Lung Cancer'], ['Lung Cancer'], ['Neuroblastoma'], ['Lung Cancer'], ['Gastric Cancer'], ['Skin Cancer'], ['Colon/Colorectal Cancer'], ['Breast Cancer'], ['Lung Cancer'], ['Gastric Cancer'], ['Liver Cancer'], ['Leukemia'], ['Myeloma'], ['Bone Cancer'], ['Lymphoma'], ['Neuroblastoma'], ['Brain Cancer'], ['Brain Cancer'], ['Breast Cancer'], ['Kidney Cancer'], ['Brain Cancer'], ['Bile Duct Cancer'], ['Lung Cancer'], ['Colon/Colorectal Cancer'], ['Esophageal Cancer'], ['Kidney Canc ...

# %%
get_cd(allGenes.index.to_list())
# Out:
# []

# %%
allGenes.index.to_list()
# Out:
# ['HEL',
#  'HEL9217',
#  'LS513',
#  'C2BBE1',
#  '253J',
#  'HCC827',
#  'ONCODG1',
#  'HS294T',
#  'NCIH1581',
#  'SKBR3',
#  'T24',
#  'MCF7',
#  'NCIH1693',
#  'PATU8988S',
#  'OPM2',
#  'CH157MN',
#  'KPL1',
#  'HCC827GR5',
#  'PC14',
#  'NCIH1650',
#  'U343',
#  'S117',
#  'SKNMC',
#  'U118MG',
#  'RDES',
#  'PANC0203',
#  'MV411',
#  'GCIY',
#  'TOV112D',
#  'A673',
#  'KARPAS299',
#  'HT1080',
#  'D283MED',
#  'PANC1005',
#  'HS683',
#  '697',
#  'KU812',
#  'U87MG',
#  'NCO2',
#  'MHHNB11',
#  'G292CLONEA141B1',
#  'T3M4',
#  'ACCMESO1',
#  'SKES1',
#  'NCIH2452',
#  'D341MED',
#  'G401',
#  'ZR751',
#  'GAMG',
#  'SIMA',
#  'KP3',
#  'HCC1187',
#  'OCIAML2',
#  'SU8686',
#  'VCAP',
#  'OAW28',
#  'HUPT3',
#  'CHP212',
#  'COV434',
#  'SLR20',
#  'LN319',
#  'JHOS2',
#  'HS729',
#  '8MGBA',
#  'CFPAC1',
#  'SNU308',
#  'CAL29',
#  'HCC2429',
#  'THP1',
#  'HS578T',
#  'HCC2935',
#  'JM1',
#  'M059K',
#  'NCIH2052',
#  'OSRC2',
#  'BT12',
#  'SW579',
#  'PANC1',
#  'KE97',
#  'NOMO1',
#  'RD',
#  'CAL62',
#  'HS766T',
#  'SNU869',
#  'L363',
#  'CORL311',
#  'SCC25',
#  'RCC10RGB',
#  'HDMYZ',
#  'EOL1',
#  'NMCG1',
#  'COLO320',
#  'LP1',
#  'C8166',
#  'DETROIT562',
#  'SNU1079',
#  'DAOY',
#  'CAL120',
#  'LN382',
#  'JHH6',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'SNU398',
#  'ASPC1',
#  'HCC1937',
#  'SUPM2',
#  'KPNYN',
#  'BICR31',
#  'KALS1',
#  'U251MG',
#  'DEL',
#  'CAKI2',
#  'PANC0403',
#  'JHOM1',
#  'SCC4',
#  'DANG',
#  'DKMG',
#  'SLR23',
#  'OCUM1',
#  'AU565',
#  'CL11',
#  'KMRC20',
#  'NCIH2887',
#  'COLO201',
#  'LMSU',
#  'COV318',
#  'CORL279',
#  'DU4475',
#  'KELLY',
#  'SKNAS',
#  'RERFLCAI',
#  'UOK101',
#  'KASUMI1',
#  'CALU6',
#  'KP4',
#  'SNU213',
#  'SUDHL10',
#  'SLR24',
#  'SF539',
#  'HS852T',
#  'HCC38',
#  'HCC1419',
#  'COV362',
#  'EWS502',
#  'SNU840',
#  'KP2',
#  'SNU1033',
#  'BT549',
#  'NCIH209',
#  'OV90',
#  'NCIH841',
#  'KLE',
#  'NB4',
#  'EM2',
#  'OUMS23',
#  'SNU1077',
#  'WM115',
#  'ECGI10',
#  'PK1',
#  'EFO21',
#  'IMR32',
#  'NCIH2122',
#  'SKNBE2',
#  'KARPAS422',
#  'SNU886',
#  'TUHR14TKB',
#  'TE10',
#  'MPP89',
#  'PSN1',
#  'HT144',
#  '42MGBA',
#  'JHOC5',
#  'JURLMK1',
#  'CCFSTTG1',
#  'EFM19',
#  'ISTMES2',
#  'YAPC',
#  'DB',
#  'MSTO211H',
#  'OCIAML3',
#  'NCIH3122',
#  'HCC461',
#  'SKNFI',
#  'NCIH522',
#  'SNU668',
#  'RPMI7951',
#  'COLO678',
#  'HCC1428',
#  'NCIH82',
#  'MKN45',
#  'SKHEP1',
#  'MOLM13',
#  'SKMM2',
#  'U2OS',
#  'SUDHL4',
#  'SKNDZ',
#  'SNU1105',
#  'SNU626',
#  'HCC1143',
#  'G402',
#  'SF295',
#  'SNU478',
#  'NCIH647',
#  'T84',
#  'OE33',
#  'SKRC20',
#  'TF1',
#  'H4',
#  'LUDLU1',
#  'HLF',
#  'NCIH520',
#  'TEN',
#  'COLO800',
#  'BL70',
#  'NCIH747',
#  'K029AX',
#  'MEC1',
#  'U937',
#  'SNU685',
#  'TE5',
#  'SAOS2',
#  '769P',
#  'NCIH1944',
#  'BICR6',
#  'NCIH838',
#  'SNU449',
#  'SW837',
#  'SNU475',
#  'TC71',
#  'UACC62',
#  'UACC62',
#  'KMS20',
#  'NCIN87',
#  'NCIH1694',
#  'CAKI1',
#  'NCIH1915',
#  'EFE184',
#  'OCIMY7',
#  'SW1088',
#  'LU65',
#  'LU99',
#  'KNS60',
#  'NCIH1666',
#  'MELHO',
#  'TE8',
#  'HCC95',
#  'CJM',
#  'TUHR10TKB',
#  'SNU8',
#  'SNU1196',
#  'NCIH460',
#  'CAS1',
#  'SNU216',
#  'HCC56',
#  'PK45H',
#  'YH13',
#  'SW1463',
#  'LI7',
#  'HSC2',
#  'RT112',
#  'HUH1',
#  'JHH4',
#  'MALME3M',
#  'SNU387',
#  'HUH7',
#  'NCIH2170',
#  'SNU182',
#  'VMRCRCW',
#  'GSU',
#  'KU1919',
#  'F36P',
#  'TE11',
#  'SF767',
#  'NCIH716',
#  'SNU423',
#  'TUHR4TKB',
#  'NCIH1792',
#  'KO52',
#  'EW8',
#  'SNU46',
#  'TCCPAN2',
#  'BICR16',
#  'SNB75',
#  'RKN',
#  'KE39',
#  'NCIH1299',
#  'CALU1',
#  'INA6',
#  'NCIH1092',
#  'CAL78',
#  'SNU410',
#  'CAL33',
#  '59M',
#  'NCIH2030',
#  'UMUC3',
#  'KURAMOCHI',
#  'OVISE',
#  'ABC1',
#  'BXPC3',
#  'SNU761',
#  'KMS34',
#  'HEYA8',
#  'OE21',
#  'VMCUB1',
#  'HT1197',
#  'BHY',
#  'SNU1076',
#  'IGR39',
#  'K562',
#  'HT29',
#  'SIHA',
#  'AML193',
#  'EBC1',
#  'YKG1',
#  'T98G',
#  'MDAMB436',
#  'KMS27',
#  'JHH2',
#  'UACC257',
#  'C32',
#  'SNU16',
#  'MC116',
#  'JHOS4',
#  'EPLC272H',
#  'NCIH1975',
#  'KMS26',
#  'NCIH1437',
#  'LN235',
#  'TM31',
#  'BC3C',
#  'LCLC97TM1',
#  'PATU8902',
#  'SLR26',
#  'MIAPACA2',
#  'KYO1',
#  'TE6',
#  'PECAPJ34CLONEC12',
#  'COV644',
#  'RVH421',
#  'HS746T',
#  'SNU1041',
#  'PECAPJ15',
#  'JHH1',
#  'MDAMB157',
#  'KNS42',
#  'SNU201',
#  'HCC1806',
#  'LCLC103H',
#  'YD8',
#  'HS944T',
#  'FU97',
#  'LN340',
#  'KYSE520',
#  'NCIH441',
#  'NCIH211',
#  'OVMANA',
#  'TE1',
#  'NCIH28',
#  '786O',
#  'SW620',
#  'SUIT2',
#  'JJN3',
#  'RAJI',
#  'SF268',
#  'A2780',
#  'KMS18',
#  'WM1799',
#  'CORL23',
#  'OVTOKO',
#  'SKMES1',
#  'HCC44',
#  'HUH6',
#  'LN443',
#  'LN464',
#  'SW1573',
#  'SW948',
#  'A549',
#  'SNU1066',
#  'SNU503',
#  'KMRC1',
#  'L33',
#  'OV7',
#  'KYSE180',
#  'TE9',
#  'CORL47',
#  'OVCAR8',
#  'A3KAW',
#  'DMS53',
#  'HCC1395',
#  'NCIH2882',
#  'RMUGS',
#  'L1236',
#  'EKVX',
#  'JIMT1',
#  'CAOV3',
#  'KMS11',
#  'NCIH2291',
#  'TCCSUP',
#  'HMC18',
#  'HT1376',
#  'HCC202',
#  'PECAPJ41CLONED2',
#  'JHH5',
#  'PECAPJ49',
#  'SNU601',
#  'GB1',
#  'HEPG2',
#  'A253',
#  'GSS',
#  'NCIH1703',
#  'SJSA1',
#  'JMSU1',
#  'GI1',
#  'A427',
#  'MKN74',
#  'LNZ308',
#  'YD38',
#  'MM1S',
#  'SH10TC',
#  'WM983B',
#  'NCIH1648',
#  'NCIH526',
#  'MDAMB231',
#  'LK2',
#  'P31FUJ',
#  'BICR56',
#  'KIJK',
#  'RERFLCAD2',
#  'NCIH727',
#  'ONS76',
#  'KYSE30',
#  'HSC3',
#  'NCIH2023',
#  'SEM',
#  'CAMA1',
#  'KYSE70',
#  'NCIH2126',
#  'LXF289',
#  'A2058',
#  'SHP77',
#  'RERFLCAD1',
#  'BFTC909',
#  'KATOIII',
#  'BICR22',
#  'MCAS',
#  'HS695T',
#  'NCIH446',
#  'HS936T',
#  'BFTC905',
#  'NB1',
#  'COLO679',
#  'SNU738',
#  'KYSE410',
#  'SKMEL30',
#  'SKOV3',
#  'HS939T',
#  'RPMI8226',
#  'LN18',
#  'SW403',
#  'EJM',
#  'SKMEL24',
#  'KYSE140',
#  'KYSE510',
#  'CAL12T',
#  'WM793',
#  'HUNS1',
#  'HEC50B',
#  'CAL27',
#  'RH30',
#  'UMUC1',
#  'GCT',
#  'YD15',
#  'NCIH322',
#  'AMO1',
#  'SCABER',
#  'HCC366',
#  'NCIH2087',
#  'HARA',
#  'FADU',
#  'HGC27',
#  'JHH7',
#  'MDAMB468',
#  'MORCPR',
#  'NCIH661',
#  'OCIMY5',
#  'KYSE150',
#  'CAL51',
#  'KNS62',
#  'HCC1954',
#  'HOP62',
#  'KMBC2',
#  'KYSE450',
#  'NCIH1048',
#  'CHAGOK1',
#  'NCIH1568',
#  'HCC515',
#  'KYSE270',
#  'MDAMB415',
#  'HCC15',
#  'AGS',
#  'MELJUSO',
#  'IGR1',
#  'MDAMB435S',
#  'TOV21G',
#  'SF172',
#  'NCIH1793',
#  'KMM1',
#  'SW1271',
#  '647V',
#  'SNU719',
#  'WM88',
#  'NCIH23',
#  'HCC1359',
#  'FTC133',
#  '5637',
#  'ES2',
#  'SNU349',
#  'MDAMB453',
#  'NUGC3',
#  'NCIH2286',
#  'ESS1',
#  'HT',
#  'IPC298',
#  'NCIH1573',
#  'TE4',
#  'NCIH1339',
#  'NCIH2172',
#  'HT55',
#  'JHUEM1',
#  'NCIH2110',
#  'SNU1',
#  'MDST8',
#  'EFO27',
#  'PF382',
#  'NALM6',
#  'SKUT1',
#  'HEC1B',
#  'RKO',
#  'HEC265',
#  'OVK18',
#  '2313287',
#  'LOVO',
#  'SUPT1',
#  'LS180',
#  'SW48',
#  'SNUC4',
#  'REH',
#  'ISHIKAWAHERAKLIO02ER',
#  'CCK81',
#  'RL952',
#  'COLO792',
#  'KM12',
#  '639V',
#  'SNGM',
#  'HCC2450',
#  'HUCCT1',
#  'EN',
#  'NCIH1155',
#  'KCL22',
#  'HEC6',
#  'HT115',
#  'MFE319',
#  'JHUEM7',
#  'HEC59',
#  'HEC251',
#  '143B',
#  'BT16',
#  'CHLA06ATRT',
#  'CHLA266',
#  'CHLA57',
#  'COGE352',
#  'COV504',
#  'CW9019',
#  'D425',
#  'D458',
#  'DLD1',
#  'F5',
#  'NCIH292',
#  'JR',
#  'MONOMAC1',
#  'MYLA',
#  'OVCAR5',
#  'CCLFPEDS0001T',
#  'CCLFPEDS0003T',
#  'R262',
#  'RT11284',
#  'SCMCRM2',
#  'SKMEL2',
#  'SKNEP1',
#  'SKPNDW',
#  'SMSCTR',
#  'SMZ1',
#  'TC32',
#  'TTC549',
#  'TTC642',
#  'UPCISCC152',
#  'UW228',
#  'WM2664',
#  'SW982',
#  'SYO1',
#  'YAMATO',
#  'BIN67',
#  'SCCOHT1',
#  'SCS214',
#  'TC106',
#  'COGAR359',
#  'Y79',
#  'CHLA15',
#  'COGN278',
#  'COGN305',
#  'NB1643',
#  '8305C',
#  'PLCPRF5',
#  'CME1',
#  'A431',
#  'ANGMCSS',
#  'BICR78',
#  'C33A',
#  'C4II',
#  'CASKI',
#  'COV413A',
#  'DOTC24510',
#  'GIMEN',
#  'GP5D',
#  'H103',
#  'JOPACA1',
#  'LAN2',
#  'MB1',
#  'NGP',
#  'OACM51',
#  'OCIC5X',
#  'PA1',
#  'PACADD119',
#  'PACADD137',
#  'PACADD161',
#  'PACADD165',
#  'PACADD188',
#  'SUM149PT',
#  'SUM159PT',
#  'SUM229PE',
#  'SUM52PE',
#  'SW756',
#  'TO14',
#  'UMUC13',
#  'UMUC14',
#  'UMUC16',
#  'UMUC5',
#  'UMUC10',
#  'UMUC11',
#  'UMUC6',
#  'UMUC7',
#  'UMUC9',
#  'UWB1289',
#  'TC138',
#  'TC205',
#  'CCLFPEDS0008T',
#  'A388',
#  'ASH3',
#  'BLUE1',
#  'BOKU',
#  'C10',
#  'C75',
#  'C80',
#  'C84',
#  'C99',
#  'CI',
#  'CII',
#  'EGI1',
#  'EMTOKA',
#  'ESO26',
#  'FLO1',
#  'H357',
#  'H376',
#  'H413',
#  'HCA1',
#  'HCS2',
#  'HEC1',
#  'HG3',
#  'HKA1',
#  'HMY1',
#  'HSC1',
#  'HSC5',
#  'HT3',
#  'HUO9',
#  'JAR',
#  'JEG3',
#  'JMURTK2',
#  'KKU100',
#  'KKU213',
#  'KON',
#  'LS',
#  'LU135',
#  'MCC13',
#  'MCC142',
#  'MCC26',
#  'MEL202',
#  'MERO14',
#  'MERO82',
#  'MM127',
#  'MM370',
#  'MM383',
#  'MM386',
#  'MM426',
#  'NOZ',
#  'NP2',
#  'NP3',
#  'NP5',
#  'NP8',
#  'OCIM2',
#  'OCUG1',
#  'ONDA7',
#  'ONDA8',
#  'ONDA9',
#  'PEA1',
#  'SEKI',
#  'SHI1',
#  'SISO',
#  'SKGI',
#  'SKGII',
#  'SKGT2',
#  'SKGT4',
#  'SKN',
#  'SNU638',
#  'TFK1',
#  'U2904',
#  'UHO1',
#  'CAL72',
#  'SEMK2',
#  'HB1119',
#  'HSB2',
#  'RH28',
#  'RHJT',
#  'TTC442',
#  'RH4',
#  'SNU1544',
#  'RH18DM',
#  'LPS6',
#  'LPS27',
#  '95T1000',
#  'LPS141',
#  'LPS853',
#  'OS252',
#  'ICC106',
#  'ICC108',
#  'ICC12',
#  'ICC15',
#  'ICC2',
#  'ICC3',
#  'ICC8',
#  'ICC9',
#  'HKGZCC',
#  'KMCH1',
#  'RBE',
#  'SG231',
#  'SSP25',
#  'YSCCC',
#  'JHC7',
#  'MUGCHOR1',
#  'UMCHOR1',
#  'CCLP1',
#  'CCSW1',
#  'ECC2',
#  '9505BIK',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'A375',
#  'UACC62',
#  'UACC62',
#  'SKMEL19',
#  'MEL285',
#  'MEL290',
#  'UCH2']

# %%
y_t = [data[data.stripped_cell_line_name == x]['primary_disease'].to_list() for x in allGenes.index]

# %%
l = ['apple','bat','apple','car','pet','bat']

#Create a dict that maps all unique strings to integers:

d = dict([(y,x+1) for x,y in enumerate(sorted(set(l)))])

#Map each string in the original list to its respective integer:

print [d[x] for x in l]
# [1, 2, 1, 3, 4, 2]

# %%
data[data.stripped_cell_line_name == x]['primary_disease'].to_list()
# Out:
# ['Leukemia']

# %% [markdown]
# # THIS MIGHT BE INTERESTING FOR A POTENTIAL BAYESIAN APPROACH

# %%
allGenes[allGenes['CDK6'] < -1.5]
# Out:
#              A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT     A4GNT  \
# HEL9217 -0.082364  0.239413  0.195457  0.163763 -0.188161 -0.338735  0.254489
# THP1     0.041365  0.145905 -0.096973  0.291647  0.079666 -0.090469  0.070778
# DB       0.051871  0.113330  0.012532  0.145659  0.011472  0.166918  0.027776
# MOLM13   0.308102  0.133787 -0.022596  0.212418 -0.041320 -0.077160  0.139491
# U937     0.144715  0.066047 -0.077593  0.211032 -0.059527 -0.146567  0.143907
# AML193   0.108347  0.020884 -0.081777  0.045239 -0.118562 -0.138237  0.083633
# OCIMY5   0.167658  0.242472  0.077819  0.157290 -0.125436 -0.179909  0.128232
# COGN305  0.146212  0.232924  0.015976  0.337219 -0.115562 -0.141629 -0.023043
#
#              AAAS      AACS     AADAC  ...    ZWILCH     ZWINT      ZXDA  \
# HEL9217 -0.583878 -0.060615  0.015272  ... -0.195061 -0.408063 -0.155155
# THP1    -0.424070  0.019922  0.257831  ... -0.152072 -0.303589  0.030226
# DB      -0.533610  0.097643  0.054154  ... -0.289470 -0.593797 -0.067333
# MOLM13  -0.596772  0.155061  0.101231  ... -0.072773 -0.523851  0.036924
# U937    -0.932282  0.101943  0.124244  ...  0.036116 -0.471871 -0.081859
# AML193  -0.299423  0.054790  0.086931  ... -0.068495 -0.760042 -0.054655
# OCIMY5  -1.157390  0.093012  0.132242  ... -0.128303 -0.497375       NaN
# COGN305 -0.310672  0.283444  0.349196  ... -0.414045 -0.998830  0.196458
#
#              ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
# HEL9217 -0.067415  0.229242 -0.075883 -0.104001  0.075901  0.036985 -0.243303
# THP1    -0.086638  0.064464  0.029738 -0.000896  0.215465 -0.013675 -0.178832
# DB      -0.137258 -0.050306  0.127276 -0.101908  0.180185 -0.031911 -0.132916
# MOLM13  -0.086817  0.054010  0.111579 -0.245075  0.249289 -0.125879 -0.545475
# U937    -0.039933  0.142857  0.105280 -0.210197  0.157387 -0.149289 -0.304235
# AML193  -0.000034  0.254006  0.137168 -0.025168  0.143970 -0.248898 -0.370465
# OCIMY5        NaN  0.376444  0.147671 -0.293722  0.050825 -0.096600 -0.582840
# COGN305  0.198456  0.059307 -0.096041 -0.345222 -0.099948  0.198717 -0.212524
#
# [8 rows x 18119 columns]

# %%
# given this context, that cdk6 is low, what is the effect of other genes?

# we could use this as input for our print_primary_disease function
#

# %%
cdk6index = allGenes[allGenes['CDK6'] < -1.5].index.to_list()

# %%
get_prd(cdk6index)
# Out:
#      primary_disease
# 4           Leukemia
# 145         Leukemia
# 333         Lymphoma
# 361         Leukemia
# 405         Leukemia
# 554         Leukemia
# 851          Myeloma
# 1161   Neuroblastoma

# %% [markdown]
# ## 5 leukemia in der condition des cdk6 low ist.
# ## es gibt nur 8 bei denen cdk6 und -1.5 ist, und in 5 davon ist die disease leukemia

# %%
leuk_list = data[data['primary_disease'] == 'Leukemia']['stripped_cell_line_name'].to_list()

# %%
leuk_lines = allGenes[allGenes.index.isin(leuk_list)]

# %%
leuk_lines['CDK6'].hist()

# %%
#fig = leuk_lines.plot_forest()

# %%
cdk6index
# Out:
# ['HEL9217', 'THP1', 'DB', 'MOLM13', 'U937', 'AML193', 'OCIMY5', 'COGN305']

# %%
cdk4_lowa = allGenes[allGenes.CDK4 > allGenes.CDK4.quantile(0.35)]

# %%
sns.regplot(x='CDK4', y='CDKN2C', data=cdk4_lowa)

# %%
# accelerate the looking into the data
def plot_lower_quartile_correlation(geneA,geneB):
    lowa = allGenes[allGenes.eval(geneA) < allGenes.eval(geneA).quantile(0.35)]
    sns.regplot(x=geneA, y=geneB, data=lowa)

# %%
plot_lower_quartile_correlation("CCND3","CDK6")

# %%
plot_lower_quartile_correlation2("CCND3",'CDK6')
# Out:
# /home/lannwal/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# looking at a cell line that was both low, or both high, or one low and one high
# can this be used for comparison? is this what we are really looking for?
# what would be test? how could we make the case that this is a finding?

# %%
sns.jointplot(allGenes["CDK4"], allGenes["CDKN2C"], kind="reg", stat_func=r2)
# Out:
# /home/lannwal/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# accelerate the looking into the data
def plot_lower_quartile_correlation2(geneA,geneB):
    lowa = allGenes[allGenes.eval(geneA) < allGenes.eval(geneA).quantile(0.35)]
    sns.jointplot(lowa[geneA],lowa[geneB], kind='reg', stat_func=r2)

# %%
plot_lower_quartile_correlation2("CDK6","CCND3")
# Out:
# /home/lannwal/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
from scipy import stats
def r2(x, y):
    return stats.pearsonr(x, y)[0] ** 2

# %%
def plot_lower_quartile_correlation3(geneA,geneB):
    lowa = allGenes.loc[top_cellines[geneB+'_'+geneA]]
    sns.jointplot(lowa[geneA],lowa[geneB], kind='reg', stat_func=r2)

# %%
plot_lower_quartile_correlation3('RB1','CDK4')
plt.savefig('/home/lannwal/Documents/DepMap_Mining/RB1_CDK4_correlation_of_top_celllines.png')
# Out:
# /home/lannwal/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
#the original correlation is 
# -0.27, there is a change in sign!!!!!!!

# %%
sns.regplot(x='CDK4', y='RB1', data=allGenes)
#r2(allGenes['CDK4'],allGenes['RB1'])

# %%
someGenes = allGenes.loc[top_cellines['CDK4_RB1']]
u1 = someGenes['CDK4'][0:1800]
u2 = someGenes['RB1'][0:1800]
x = allGenes['CDK4'][0:1800]
y = allGenes['RB1'][0:1800]
plt.scatter(x,y)
plt.scatter(u1,u2)

# %%
sns.regplot(x='CDK4', y='RB1', data=someGenes,scatter_kws = {"color": "orange"}, line_kws = {"color": "black"})
plt.savefig('/home/lannwal/Documents/DepMap_Mining/RB1_CDK4_correlation_of_top_celllines2.png')

# %%
sns.regplot(x='RB1', y='CDK4', data=someGenes,scatter_kws = {"color": "orange"}, line_kws = {"color": "black"})
plt.savefig('/home/lannwal/Documents/DepMap_Mining/RB1_CDK4_correlation_of_top_celllines3.png')

# %%
#allGenes[allGenes['CDK4'] < allGenes.CDK4.quantile(0.35)]
#[allGenes['CDK4'] < allGenes.CDK4.quantile(0.35)]['CDK4'].plot.box()

# %%
allGenes[allGenes['CDK4'] < allGenes.CDK4.quantile(0.35)]['CDK4'].plot.box()

# %%
someGenes = allGenes.loc[top_cellines['CDK4_CCND1']]
u1 = someGenes['CDK4'][0:1800]
u2 = someGenes['CCND1'][0:1800]
x = allGenes['CDK4'][0:1800]
y = allGenes['CCND1'][0:1800]
plt.scatter(x,y)
plt.scatter(u1,u2)

# %%
x = allGenes['CDK4'][0:1800]
y = allGenes['CCND1'][0:1800]
plt.scatter(x,y)

# %%
top_cellines['CDK4_CCND1']
# Out:
# ['G292CLONEA141B1',
#  'ES2',
#  'RCC10RGB',
#  'KPNYN',
#  'SNU216',
#  'MELHO',
#  'SKMEL24',
#  'MDAMB453',
#  'HS852T',
#  'MALME3M',
#  'HCC2429',
#  'SNU1544',
#  'NCIH1915',
#  'NCIH2052',
#  'WM115',
#  'HMY1',
#  'UMUC9',
#  'COV434',
#  'COGE352',
#  'WM1799',
#  'WM2664',
#  'LAN2',
#  'CAMA1',
#  'CHLA15',
#  'NCIH3122',
#  'HMC18',
#  'SKNFI',
#  'EWS502',
#  'DMS53',
#  'PACADD188',
#  'MEL290',
#  'BLUE1',
#  'LPS6',
#  'RMUGS',
#  'NB1',
#  'NCIH1792',
#  'NCIH2887',
#  'UMUC16',
#  'HEC1B',
#  'OVTOKO',
#  'RDES',
#  'TC71',
#  'C32',
#  'MKN45',
#  'EW8',
#  'LN464',
#  'VCAP',
#  'SKMM2',
#  'MDAMB415',
#  'HCC1428',
#  'HCC1419',
#  'UACC257',
#  'SNU308',
#  'FU97',
#  'NCIH1573',
#  'NB1643',
#  'HEC1']

# %%
someGenes = allGenes.loc[top_cellines['CDK4_CCND1']]
sns.regplot(x='CDK4', y='CCND1', data=someGenes)

# %%
pair_ins1 = allGenes.loc[top_ce['CDK4_CDKN2C']]
sns.regplot(x='RB1', y='TP53', data=someGenes)

# %%
top_ce = clank70(uli_list)
pair_ins1 = allGenes.loc[top_ce['CDK4_CDKN2C']]
sns.regplot(x='BRCA1', y='BRCA2', data=pair_ins1)

# %%
g = sns.jointplot(data=pair_ins1, x="CCND1", y="BRCA2")
g.plot_joint(sns.kdeplot, color="r", zorder=0, levels=6)
g.plot_marginals(sns.rugplot, color="r", height=-.15, clip_on=False)

# %%
someGenes = allGenes.loc[top_cellines['NF2_PTEN']]
r2(someGenes['NF2'],someGenes['PTEN'])
# Out:
# 0.2711902194676113

# %%
r2(allGenes['NF2'],allGenes['PTEN'])
# Out:
# 0.0764345705751008

# %%
# crazy mode going for 3d scatterplots

# %%
allGenes.loc[top_ce['CDK4_CDKN2C']]['RB1']
# Out:
# VCAP         0.052162
# TC32         0.721984
# MDAMB415     0.500491
# KNS42        0.463181
# NCIH2887     0.973534
#                ...
# 639V         0.097524
# TE4          0.104365
# BLUE1        0.327712
# ICC8         0.299189
# MDAMB435S    0.254969
# Name: RB1, Length: 70, dtype: float64

# %% [markdown]
# we find diverse values in mean essentiality for phosphatases, which is i guess a good sign if we want to
# make the point that they may act as TS or ON depending on circumstance?
#
# names of human phosphatases from:
# https://stke.sciencemag.org/content/10/474/eaag1796
# this paper also discusses gains and losses of kinases and phosphatases during evolution of animals.
# sea urchins and humans have a lot of kinases and phosphatases apparently.
# see also sea urchin developmental circuit model.

# %% [markdown]
# #### looking at interesting pairs, and interesting genes -- something to creatively immerese into. (Manolis lectures)

# %% [markdown]
# ## CDKN2A, CDKN1B machen troubles da sie leicht negativ sind, jedoch definitiv tumorsuppressoren sind.

# %% [markdown]
# ## Ranking based on averages is not possible. It kills the signal. Which might be interesting to note, even though this went nowhere.

# %% [markdown]
# ## Vorgeschlagene Kontrollen:

# %%
uli_list = [['CDK4','RB1'],['CDK4','CDKN2C'],['CDK4','CCND1'],['CDK6','CCND3'],['CDK6','CCNE1'],['CDK6','CDK4'],['CDKN2A','CDKN2B'],
['CDKN2A','CCNE1'],['NF2','AMOTL2'],['NF2','KIRREL1'],['NF2','TAOK1'],['NF2','LATS2'],['NF2','PTPN14'],['NF2','PTEN'],['NF2','ABL2'],['NF2','RAC1'],['NF2','CRK'],['NF2','DLG5'],['NF2','PKN2']]

UL2 = [i for j in uli_list for i in j]
UL2 = set(UL2)
UL2 = list(UL2)

# %%
uli_list_individual = ['CDK4','RB1','CDKN2C','CCND1','CDK6','CCND3','CCNE1',
'CDKN2A','CDKN2B','NF2','AMOTL2','KIRREL1','TAOK1','LATS2','PTPN14','PTEN','ABL2','RAC1','CRK','DLG5','PKN2']

# %%
mydict = {}
for _ in UL2:
    if allGenes[_].sum(skipna=True)/allGenes.shape[0] > 0:
        mydict[_] = allGenes[_].sort_values(ascending=False)
    else:
        mydict[_] = allGenes[_].sort_values()

# %%
# next step is to make a mydict for all the 18000 genes.
# sort all of them individually

# df.plot.box()

# %% [markdown]
# ## lets see, for individual genes in our list, what the primary diseases are
# ## therefore we first rank according to their status as TSG, oncogenes.
# ## therefore we first get the average of the 1st quartile of gene effects

# %%
uli_list_individual = ['CDK4','RB1','CDKN2C','CCND1','CDK6','CCND3','CCNE1',
'CDKN2A','CDKN2B','NF2','AMOTL2','KIRREL1','TAOK1','LATS2','PTPN14','PTEN','ABL2','RAC1','CRK','DLG5','PKN2']
myGenes = allGenes[uli_list_individual]

# %%
allGenes.CDKN2B.hist(bins=25)
allGenes.CDKN2B[allGenes.CDKN2B > allGenes.CDKN2B.quantile(0.65)].hist(bins=15)
allGenes.CDKN2B[allGenes.CDKN2B < allGenes.CDKN2B.quantile(0.35)].hist(bins=15)

plt.vlines(allGenes.CDKN2B.quantile(0.35), 0,250,'r')
plt.vlines(allGenes.CDKN2B.quantile(0.65), 0,250,'r')
plt.title('cancer gene classification based on quantiles')
plt.xlabel('gene effect')
plt.ylabel('number of genes')
plt.savefig('/home/lannwal/Documents/DepMap_Mining/quantiles_for_classification2.png')

# %% [markdown]
# # Doing a ranking based on quartiles does way better than using gene effect averages

# %%
allGenes[allGenes < allGenes.quantile(0.35)].hist(bins=30)
allGenes[allGenes > allGenes.quantile(0.65)].hist(bins=30)
#myGenes.quantile(1).hist(bins=30)
plt.title('quartiles of gene effects')
plt.xlabel('gene effect')
plt.ylabel('number of genes')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-442-4fe44a667e87> in <module>
# ----> 1 allGenes[allGenes < allGenes.quantile(0.35)].hist(bins=30)
#       2 allGenes[allGenes > allGenes.quantile(0.65)].hist(bins=30)
#       3 #myGenes.quantile(1).hist(bins=30)
#       4 plt.title('quartiles of gene effects')
#       5 plt.xlabel('gene effect')
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     197         layout=layout,
#     198         bins=bins,
# --> 199         **kwds
#     200     )
#     201
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     404         sharey=sharey,
#     405         figsize=figsize,
# --> 406         layout=layout,
#     407     )
#     408     _axes = _flatten(axes)
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     254             kwds["sharex"] = None
#     255             kwds["sharey"] = None
# --> 256         ax = fig.add_subplot(nrows, ncols, i + 1, **kwds)
#     257         axarr[i] = ax
#     258
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
# -> 1421         return self._add_axes_internal(key, a)
#    1422
#    1423     def _add_axes_internal(self, key, ax):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in _add_axes_internal(self, key, ax)
#    1424         """Private helper for `add_axes` and `add_subplot`."""
#    1425         self._axstack.add(key, ax)
# -> 1426         self.sca(ax)
#    1427         ax._remove_method = self._remove_ax
#    1428         self.stale = True
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in sca(self, a)
#    1959     def sca(self, a):
#    1960         """Set the current axes to be a and return a."""
# -> 1961         self._axstack.bubble(a)
#    1962         for func in self._axobservers:
#    1963             func(self)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in bubble(self, a)
#     107         stack, to the top.
#     108         """
# --> 109         return super().bubble(self._entry_from_axes(a))
#     110
#     111     def add(self, key, a):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in bubble(self, o)
#     644                 bubbles.append(thiso)
#     645             else:
# --> 646                 self.push(thiso)
#     647         for _ in bubbles:
#     648             self.push(o)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in push(self, o)
#     605         *o* is returned.
#     606         """
# --> 607         self._elements = self._elements[:self._pos + 1] + [o]
#     608         self._pos = len(self._elements) - 1
#     609         return self()
#
# KeyboardInterrupt:

# %%
q3 = myGenes[myGenes < myGenes.quantile(0.35)]

# %%
q4 = myGenes[myGenes > myGenes.quantile(0.65)]

# %%
# taking the mean of the upper and lower quartile gives us a way better ranking
# ranking = q3.mean() + q4.mean()

# %% [markdown]
# # Clanking all the genes with the quartile method

# %%
q3 = allGenes[allGenes < allGenes.quantile(0.35)]
q4 = allGenes[allGenes > allGenes.quantile(0.65)]
ranking = q3.mean() + q4.mean()

# %%
ranking.head(10)
# Out:
# A1BG       0.206654
# A1CF       0.128216
# A2M       -0.123572
# A2ML1      0.358225
# A3GALT2   -0.085509
# A4GALT    -0.106025
# A4GNT      0.237659
# AAAS      -1.050867
# AACS       0.131274
# AADAC      0.305429
# dtype: float64

# %%
allGenes.index.sort_values()[0:50]
# Out:
# Index(['143B', '2313287', '253J', '42MGBA', '5637', '59M', '639V', '647V',
#        '697', '769P', '786O', '8305C', '8MGBA', '9505BIK', '95T1000', 'A2058',
#        'A253', 'A2780', 'A375', 'A375', 'A375', 'A375', 'A375', 'A375', 'A375',
#        'A375', 'A375', 'A375', 'A375', 'A375', 'A375', 'A375', 'A375', 'A375',
#        'A388', 'A3KAW', 'A427', 'A431', 'A549', 'A673', 'ABC1', 'ACCMESO1',
#        'AGS', 'AML193', 'AMO1', 'ANGMCSS', 'ASH3', 'ASPC1', 'AU565', 'BC3C'],
#       dtype='object')

# %%
rankings = {}
for _ in range(len(ranking.index)):
    if ranking[ranking.index[_]] > 0:
        rankings[ranking.index[_]] = allGenes[ranking.index[_]].sort_values(ascending=False)
    else:
        rankings[ranking.index[_]] = allGenes[ranking.index[_]].sort_values()

# %%
# old ranking scheme
mydict = {}
for _ in myGenes.columns:
    if rankings[_] == '+':
        mydict[_] = allGenes[_].sort_values(ascending=False)
    else:
        mydict[_] = allGenes[_].sort_values()

# %%
# according to sanger:
rankings_correct = {
 'CDK4': '-',     
 'RB1': '+',         'CDKN2C': '+',
 'CCND1': '-',       'CDK6': '-',
 'CCND3': '-',       'CCNE1': '-',
 'CDKN2A': '+',      'CDKN2B': '+',
 'NF2': '+',         'PTPN14': '+',
 'KIRREL1': '-',     'AMOTL2': '-',
 'LATS2': '+',       'TAOK1': '+',
 'PTEN': '+',        'CRK': '-',
 'RAC1': '-',        'ABL2': '-',
 'DLG5': '-',        'PKN2': '-'   }

# %%
for x in uli_list_individual:
    print(x, ranking[x])
# Out:
# CDK4 -1.26919618328766
# RB1 0.43353016736432154
# CDKN2C 0.685361911284462
# CCND1 -2.061707090483832
# CDK6 -1.169650089699101
# CCND3 -0.7065068430096969
# CCNE1 -0.3635121366076865
# CDKN2A 0.1
# CDKN2B 0.03734098089132132
# NF2 0.45133473730059265
# AMOTL2 0.24680860074955818
# KIRREL1 0.6201110709373724
# TAOK1 0.4947634326178204
# LATS2 -0.21724502672683138
# PTPN14 0.6323912621318185
# PTEN 1.3948483640917653
# ABL2 0.39538919425298363
# RAC1 -1.416997333253427
# CRK -0.5364427745465853
# DLG5 -0.7057736965079454
# PKN2 -0.5113919151656031

# %%
# ranking['CDKN2A'] = 0.1 , manuell geaendert

# %%
ranking['CDKN2A']
# Out:
# 0.1

# %%
# new version with sanger cancer gene annotation
sangerdict = {}
for _ in myGenes.columns:
    if rankings_correct[_] == '+':
        sangerdict[_] = allGenes[_].sort_values(ascending=False)
    else:
        sangerdict[_] = allGenes[_].sort_values()

# %%
cdk4_list = mydict['TAOK1'].index.to_list()

# %%
cdk4_list = cdk4_list[0:35]

# %%
result_cdk4 = get_prd(cdk4_list)

# %%
result_cdk4['primary_disease']
# Out:
# 16                   Breast Cancer
# 23                         Myeloma
# 54                    Brain Cancer
# 163              Pancreatic Cancer
# 247                  Breast Cancer
# 276                  Breast Cancer
# 333                       Lymphoma
# 355                 Gastric Cancer
# 362                        Myeloma
# 511                    Lung Cancer
# 548                       Leukemia
# 573                        Myeloma
# 580                       Lymphoma
# 644              Esophageal Cancer
# 722                  Breast Cancer
# 729           Head and Neck Cancer
# 771                    Lung Cancer
# 787                    Lung Cancer
# 814                        Myeloma
# 913                    Lung Cancer
# 956        Colon/Colorectal Cancer
# 1086                      Leukemia
# 1113                       Sarcoma
# 1119                   Bone Cancer
# 1234                Bladder Cancer
# 1240                Bladder Cancer
# 1252                Thyroid Cancer
# 1276               Cervical Cancer
# 1278               Cervical Cancer
# 1280    Endometrial/Uterine Cancer
# 1364    Endometrial/Uterine Cancer
# 1373                      Lymphoma
# 1394                       Sarcoma
# 1397                       Sarcoma
# 1424              Bile Duct Cancer
# Name: primary_disease, dtype: object

# %%
top_list = result_cdk4['primary_disease'].value_counts()[:35].index.tolist()

# %%
disea = {}

for _ in mydict.keys():
    temp_list =  mydict[_].index.to_list()
    temp = temp_list[0:35]
    #disea.append({ _ : temp}, ignore_index=True)
    disea[_] = get_prd(temp)

# %%
disang = {}

for _ in sangerdict.keys():
    temp_list =  sangerdict[_].index.to_list()
    temp = temp_list[0:35]
    #disea.append({ _ : temp}, ignore_index=True)
    disang[_] = get_prd(temp)

# %%
disea['CDK4']['primary_disease'].sort_values()
# Out:
# 1241                Bladder Cancer
# 40                     Bone Cancer
# 81                     Bone Cancer
# 1024                   Bone Cancer
# 278                    Bone Cancer
# 423                    Bone Cancer
# 673                   Brain Cancer
# 907                  Breast Cancer
# 276                  Breast Cancer
# 873                  Breast Cancer
# 351                  Breast Cancer
# 780                  Breast Cancer
# 718                  Breast Cancer
# 1402       Colon/Colorectal Cancer
# 1280    Endometrial/Uterine Cancer
# 914              Esophageal Cancer
# 1460                    Eye Cancer
# 630                 Gastric Cancer
# 844                 Gastric Cancer
# 494                    Lung Cancer
# 433                    Lung Cancer
# 336                    Lung Cancer
# 142                    Lung Cancer
# 695                    Lung Cancer
# 250                    Lung Cancer
# 1253                      Lymphoma
# 122                 Ovarian Cancer
# 698                 Ovarian Cancer
# 903                 Ovarian Cancer
# 1211             Pancreatic Cancer
# 114                Prostate Cancer
# 881                    Skin Cancer
# 824                    Skin Cancer
# 1285                   Skin Cancer
# 273                    Skin Cancer
# Name: primary_disease, dtype: object

# %%
#disea['CDK4']

# %%
daat = {}
mydf = []
for i in disang.keys():
    temp = disang[i]['primary_disease'].value_counts()
    rank = rankings_correct[i]
    for _ in range(5):
        value_count = temp[_]
        dissease = temp.index[_]
        for j in range(10):
            if get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36) < 0.05:
                daat[i] = [rank,dissease,get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36)]
    
  #  get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36)disease / p-value

# %%
disea.keys()
# Out:
# dict_keys(['CDK4', 'RB1', 'CDKN2C', 'CCND1', 'CDK6', 'CCND3', 'CCNE1', 'CDKN2A', 'CDKN2B', 'NF2', 'AMOTL2', 'KIRREL1', 'TAOK1', 'LATS2', 'PTPN14', 'PTEN', 'ABL2', 'RAC1', 'CRK', 'DLG5', 'PKN2'])

# %%
# this seems to be working, at least for the single genes.

# %%
for _ in disea.keys():
    temp = disea[_]['primary_disease'].value_counts()
    print(_)
    print("\n")
    for _ in range(5):
        value_count = temp[_]
        dissease = temp.index[_]
        print(dissease)
        print(get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36))
    print('\n')
# Out:
# CDK4
#
#
# Breast Cancer
# 0.003662941207072066
# Lung Cancer
# 0.38203186468013983
# Bone Cancer
# 0.0078012723374613095
# Skin Cancer
# 0.20378037090339154
# Ovarian Cancer
# 0.31685549721507383
#
#
# RB1
#
#
# Lung Cancer
# 0.38203186468013983
# Gastric Cancer
# 0.005595913078286775
# Bladder Cancer
# 0.15150448835528713
# Colon/Colorectal Cancer
# 0.25043884101921765
# Breast Cancer
# 0.21186851899273118
#
#
# CDKN2C
#
#
# Bone Cancer
# 0.00016400415827454656
# Neuroblastoma
# 0.001260665128357237
# Brain Cancer
# 0.13657060615676408
# Leukemia
# 0.30344775537790714
# Kidney Cancer
# 0.27789949378663076
#
#
# CCND1
#
#
# Skin Cancer
# 0.0014049538993648775
# Neuroblastoma
# 0.0001244586412632915
# Gastric Cancer
# 0.11860849211511124
# Bone Cancer
# 0.14021748746765467
# Lung Cancer
# 0.8986507420569853
#
#
# CDK6
#
#
# Leukemia
# 0.0019855590056850653
# Myeloma
# 0.0016236411604765646
# Skin Cancer
# 0.42378995975481615
# Head and Neck Cancer
# 0.19934603115054572
# Brain Cancer
# 0.5375667944611938
#
#
# CCND3
#
#
# Leukemia
# 5.4159519751679205e-08
# Lymphoma
# 2.0497018618697483e-05
# Lung Cancer
# 0.7616424368825894
# Kidney Cancer
# 0.07986297477185592
# Bile Duct Cancer
# 0.3494770994438439
#
#
# CCNE1
#
#
# Ovarian Cancer
# 8.05889153968093e-07
# Endometrial/Uterine Cancer
# 9.289441753140336e-06
# Lung Cancer
# 0.8986507420569853
# Skin Cancer
# 0.6992063752104005
# Colon/Colorectal Cancer
# 0.531018726294115
#
#
# CDKN2A
#
#
# Brain Cancer
# 0.13657060615676408
# Lung Cancer
# 0.5756635114482365
# Leukemia
# 0.30344775537790714
# Ovarian Cancer
# 0.31685549721507383
# Breast Cancer
# 0.4846239573043805
#
#
# CDKN2B
#
#
# Colon/Colorectal Cancer
# 0.025344156935661583
# Rhabdoid
# 0.006647682779519955
# Sarcoma
# 0.08893742443021473
# Bile Duct Cancer
# 0.11860849211511124
# Leukemia
# 0.30344775537790714
#
#
# NF2
#
#
# Sarcoma
# 0.0031759824779939187
# Lung Cancer
# 0.5756635114482365
# Pancreatic Cancer
# 0.06994699011509398
# Breast Cancer
# 0.06994699011509398
# Skin Cancer
# 0.42378995975481615
#
#
# AMOTL2
#
#
# Lung Cancer
# 0.38203186468013983
# Gastric Cancer
# 0.11860849211511124
# Sarcoma
# 0.08893742443021473
# Brain Cancer
# 0.5375667944611938
# Colon/Colorectal Cancer
# 0.25043884101921765
#
#
# KIRREL1
#
#
# Brain Cancer
# 0.0009553232150205894
# Ovarian Cancer
# 0.1291471114979835
# Skin Cancer
# 0.20378037090339154
# Bile Duct Cancer
# 0.11860849211511124
# Eye Cancer
# 0.012209914798453863
#
#
# TAOK1
#
#
# Breast Cancer
# 0.06994699011509398
# Lung Cancer
# 0.7616424368825894
# Myeloma
# 0.011733090805031347
# Sarcoma
# 0.08893742443021473
# Lymphoma
# 0.07122950683179584
#
#
# LATS2
#
#
# Lung Cancer
# 0.38203186468013983
# Bone Cancer
# 0.14021748746765467
# Colon/Colorectal Cancer
# 0.25043884101921765
# Endometrial/Uterine Cancer
# 0.11860849211511124
# Gastric Cancer
# 0.3494770994438439
#
#
# PTPN14
#
#
# Brain Cancer
# 0.13657060615676408
# Kidney Cancer
# 0.01655087654427856
# Ovarian Cancer
# 0.1291471114979835
# Lung Cancer
# 0.8986507420569853
# Sarcoma
# 0.08893742443021473
#
#
# PTEN
#
#
# Liver Cancer
# 0.01655087654427856
# Pancreatic Cancer
# 0.06994699011509398
# Myeloma
# 0.011733090805031347
# Kidney Cancer
# 0.27789949378663076
# Neuroblastoma
# 0.22404064954775063
#
#
# ABL2
#
#
# Brain Cancer
# 0.05132556487939811
# Lung Cancer
# 0.38203186468013983
# Kidney Cancer
# 0.07986297477185592
# Bile Duct Cancer
# 0.11860849211511124
# Rhabdoid
# 0.06310597678014068
#
#
# RAC1
#
#
# Skin Cancer
# 0.07869427401608511
# Brain Cancer
# 0.5375667944611938
# Sarcoma
# 0.08893742443021473
# Lung Cancer
# 0.8986507420569853
# Bladder Cancer
# 0.15150448835528713
#
#
# CRK
#
#
# Ovarian Cancer
# 0.04161787511478907
# Pancreatic Cancer
# 0.06994699011509398
# Bile Duct Cancer
# 0.029535781202476345
# Lung Cancer
# 0.8986507420569853
# Bladder Cancer
# 0.40181033156708545
#
#
# DLG5
#
#
# Ovarian Cancer
# 0.010811637360217749
# Breast Cancer
# 0.06994699011509398
# Bile Duct Cancer
# 0.029535781202476345
# Lung Cancer
# 0.7616424368825894
# Brain Cancer
# 0.5375667944611938
#
#
# PKN2
#
#
# Bile Duct Cancer
# 0.0008282561732141397
# Ovarian Cancer
# 0.1291471114979835
# Kidney Cancer
# 0.01655087654427856
# Bladder Cancer
# 0.15150448835528713
# Liver Cancer
# 0.07986297477185592

# %%
for _ in disang.keys():
    temp = disang[_]['primary_disease'].value_counts()
    print(_)
    print("\n")
    for _ in range(5):
        value_count = temp[_]
        dissease = temp.index[_]
        print(dissease)
        print(get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36))
    print('\n')
    
    
# give it in the form     gene  / ranking / primary disease / p-value
# Out:
# CDK4
#
#
# Breast Cancer
# 0.003662941207072066
# Lung Cancer
# 0.38203186468013983
# Bone Cancer
# 0.0078012723374613095
# Skin Cancer
# 0.20378037090339154
# Ovarian Cancer
# 0.31685549721507383
#
#
# RB1
#
#
# Ovarian Cancer
# 0.010811637360217749
# Skin Cancer
# 0.20378037090339154
# Endometrial/Uterine Cancer
# 0.11860849211511124
# Rhabdoid
# 0.006647682779519955
# Lung Cancer
# 0.8986507420569853
#
#
# CDKN2C
#
#
# Bone Cancer
# 0.00016400415827454656
# Neuroblastoma
# 0.001260665128357237
# Brain Cancer
# 0.13657060615676408
# Leukemia
# 0.30344775537790714
# Kidney Cancer
# 0.27789949378663076
#
#
# CCND1
#
#
# Skin Cancer
# 0.0014049538993648775
# Neuroblastoma
# 0.0001244586412632915
# Gastric Cancer
# 0.11860849211511124
# Bone Cancer
# 0.14021748746765467
# Lung Cancer
# 0.8986507420569853
#
#
# CDK6
#
#
# Leukemia
# 0.0019855590056850653
# Myeloma
# 0.0016236411604765646
# Skin Cancer
# 0.42378995975481615
# Head and Neck Cancer
# 0.19934603115054572
# Brain Cancer
# 0.5375667944611938
#
#
# CCND3
#
#
# Leukemia
# 5.4159519751679205e-08
# Lymphoma
# 2.0497018618697483e-05
# Lung Cancer
# 0.7616424368825894
# Kidney Cancer
# 0.07986297477185592
# Bile Duct Cancer
# 0.3494770994438439
#
#
# CCNE1
#
#
# Ovarian Cancer
# 8.05889153968093e-07
# Endometrial/Uterine Cancer
# 9.289441753140336e-06
# Lung Cancer
# 0.8986507420569853
# Skin Cancer
# 0.6992063752104005
# Colon/Colorectal Cancer
# 0.531018726294115
#
#
# CDKN2A
#
#
# Leukemia
# 0.03795046585826519
# Skin Cancer
# 0.20378037090339154
# Ovarian Cancer
# 0.1291471114979835
# Liposarcoma
# 0.0009027664668420572
# Myeloma
# 0.06305521662983778
#
#
# CDKN2B
#
#
# Lung Cancer
# 0.2211346550117451
# Skin Cancer
# 0.20378037090339154
# Head and Neck Cancer
# 0.06382927040997433
# Liver Cancer
# 0.07986297477185592
# Leukemia
# 0.30344775537790714
#
#
# NF2
#
#
# Brain Cancer
# 0.13657060615676408
# Ovarian Cancer
# 0.1291471114979835
# Skin Cancer
# 0.20378037090339154
# Bile Duct Cancer
# 0.029535781202476345
# Lung Cancer
# 0.7616424368825894
#
#
# AMOTL2
#
#
# Lung Cancer
# 0.38203186468013983
# Gastric Cancer
# 0.11860849211511124
# Sarcoma
# 0.08893742443021473
# Brain Cancer
# 0.5375667944611938
# Colon/Colorectal Cancer
# 0.25043884101921765
#
#
# KIRREL1
#
#
# Lung Cancer
# 0.5756635114482365
# Leukemia
# 0.30344775537790714
# Lymphoma
# 0.07122950683179584
# Colon/Colorectal Cancer
# 0.25043884101921765
# Head and Neck Cancer
# 0.46857951975647877
#
#
# TAOK1
#
#
# Brain Cancer
# 0.13657060615676408
# Skin Cancer
# 0.20378037090339154
# Ovarian Cancer
# 0.1291471114979835
# Bile Duct Cancer
# 0.11860849211511124
# Kidney Cancer
# 0.27789949378663076
#
#
# LATS2
#
#
# Skin Cancer
# 0.20378037090339154
# Lung Cancer
# 0.7616424368825894
# Sarcoma
# 0.08893742443021473
# Ovarian Cancer
# 0.31685549721507383
# Brain Cancer
# 0.5375667944611938
#
#
# PTPN14
#
#
# Brain Cancer
# 0.13657060615676408
# Kidney Cancer
# 0.01655087654427856
# Ovarian Cancer
# 0.1291471114979835
# Lung Cancer
# 0.8986507420569853
# Sarcoma
# 0.08893742443021473
#
#
# PTEN
#
#
# Liver Cancer
# 0.01655087654427856
# Pancreatic Cancer
# 0.06994699011509398
# Myeloma
# 0.011733090805031347
# Kidney Cancer
# 0.27789949378663076
# Neuroblastoma
# 0.22404064954775063
#
#
# ABL2
#
#
# Colon/Colorectal Cancer
# 0.025344156935661583
# Lymphoma
# 0.014009475418235513
# Endometrial/Uterine Cancer
# 0.11860849211511124
# Myeloma
# 0.06305521662983778
# Head and Neck Cancer
# 0.19934603115054572
#
#
# RAC1
#
#
# Skin Cancer
# 0.07869427401608511
# Brain Cancer
# 0.5375667944611938
# Sarcoma
# 0.08893742443021473
# Lung Cancer
# 0.8986507420569853
# Bladder Cancer
# 0.15150448835528713
#
#
# CRK
#
#
# Ovarian Cancer
# 0.04161787511478907
# Pancreatic Cancer
# 0.06994699011509398
# Bile Duct Cancer
# 0.029535781202476345
# Lung Cancer
# 0.8986507420569853
# Bladder Cancer
# 0.40181033156708545
#
#
# DLG5
#
#
# Ovarian Cancer
# 0.010811637360217749
# Breast Cancer
# 0.06994699011509398
# Bile Duct Cancer
# 0.029535781202476345
# Lung Cancer
# 0.7616424368825894
# Brain Cancer
# 0.5375667944611938
#
#
# PKN2
#
#
# Bile Duct Cancer
# 0.0008282561732141397
# Ovarian Cancer
# 0.1291471114979835
# Kidney Cancer
# 0.01655087654427856
# Bladder Cancer
# 0.15150448835528713
# Liver Cancer
# 0.07986297477185592

# %%
allGenes[allGenes['CDK4'] < -1.5 & allGenes['CDK6'] < -1.5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/ops/roperator.py in rand_(left, right)
#      52 def rand_(left, right):
# ---> 53     return operator.and_(right, left)
#      54
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1268                 try:
# -> 1269                     result = libops.scalar_binop(x, y, op)
#    1270                 except (
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'double'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-610-1e434e11bc54> in <module>
# ----> 1 allGenes[allGenes['CDK4'] < -1.5 & allGenes['CDK6'] < -1.5]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#    1319         #   integer dtypes.  Otherwise these are boolean ops
#    1320         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# -> 1321         res_values = na_op(self.values, ovalues)
#    1322         unfilled = self._constructor(res_values, index=self.index, name=res_name)
#    1323         filled = filler(unfilled)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1278                         "cannot compare a dtyped [{dtype}] array "
#    1279                         "with a scalar of type [{typ}]".format(
# -> 1280                             dtype=x.dtype, typ=type(y).__name__
#    1281                         )
#    1282                     )
#
# TypeError: cannot compare a dtyped [float64] array with a scalar of type [bool]

# %%
cdk4_low = allGenes[allGenes['CDK4'] < -1.0]

# %%
cdk4_cdk6_low = cdk4_low[cdk4_low['CDK6'] < -1.0]

# %%
#cdk4_cdk6_low

# %%
cdk46low = cdk4_cdk6_low.index.to_list()

# %%
a = set(cdk46low)
b = set(top_cellines['CDK6_CDK4'])
b.intersection(a)
# Out:
# {'HEL9217', 'SNU308'}

# %%
len(cdk46low)
# Out:
# 7

# %%
# zum überprüfen, wir haben 7 zelllinien in denen cdk4 und cdk6 sehr niedrig sind. zwei davon finden sich in unserem ranking in den ersten 35 wieder.

# %% [markdown]
# ## von 7 zellinien in denen cdk4 und cdk6 niedrig sind sind 2 in den top 35, wieviele sind in den top 70?

# %% [markdown]
# # CLANKING IS NOW COMPLETE

# %%
# this works well now, had a huge clusterfuck here, took forever to run, now it takes seconds :/
# pandas is elegant if you know how to use it

def clank(list_of_pairs):
    top_ce = {}
    for _ in list_of_pairs:
        a,b = _
        a_list = rankings[a].index.to_list()
        a_df = pd.DataFrame(a_list)

        b_list = rankings[b].index.to_list()
        b_df = pd.DataFrame(b_list)

        ranked_index = pd.concat([a_df,b_df]).sort_index().reset_index(drop=True)
        top_ce[a + '_' + b] = ranked_index[0].to_list()[0:35]
    return top_ce

# %% [markdown]
# # ALL OF THE ABOVE MIGHT BE CRAP, NEW CLANK70 and print_PRIMARY_DISEASE work

# %%
print_PRIMARY_DISEASES(clank70(uli_list),70)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-529a4d6e6e15> in <module>
# ----> 1 print_PRIMARY_DISEASES(clank70(uli_list),70)
#
# <ipython-input-22-b44ce539deb2> in print_PRIMARY_DISEASES(clank_lines, number_of_celllines)
#       3     i = 0
#       4     for _ in clank_lines.keys():
# ----> 5         temp = get_prd(clank_lines[_])
#       6         temp = temp['primary_disease'].value_counts()
#       7         print(_)
#
# NameError: name 'get_prd' is not defined

# %%
uli_df = print_PRIMARY_DISEASES(clank70(uli_list),70)
# Out:
# CDK4_RB1
# Ovarian Cancer
# 0.010190793555315391
# Breast Cancer
# 0.02878554933390633
# Bone Cancer
# 0.03538484245000727
# Rhabdoid
# 0.04139143580056207
#
#
# CDK4_CDKN2C
# Bone Cancer
# 0.002323693843004446
# Breast Cancer
# 0.02878554933390633
# Neuroblastoma
# 0.023522443343404056
#
#
# CDK4_CCND1
# Skin Cancer
# 0.000992436391054638
# Bone Cancer
# 0.03538484245000727
# Neuroblastoma
# 0.004964998183642506
#
#
# CDK6_CCND3
# Leukemia
# 4.0281625863791305e-06
# Lymphoma
# 0.0002585647488144837
# Myeloma
# 0.029168556412179015
#
#
# CDK6_CCNE1
# Ovarian Cancer
# 0.0007453255437763656
# Leukemia
# 0.008638717677791043
# Endometrial/Uterine Cancer
# 0.0013590486627923105
# Myeloma
# 0.029168556412179015
#
#
# CDK6_CDK4
# Bone Cancer
# 0.009931161932342909
# Myeloma
# 0.029168556412179015
#
#
# CDKN2A_CDKN2B
# Liposarcoma
# 0.006451500660135721
# Eye Cancer
# 0.043994249129214735
#
#
# CDKN2A_CCNE1
# Ovarian Cancer
# 3.239977386113974e-05
# Endometrial/Uterine Cancer
# 0.00024067924659887434
# Liposarcoma
# 0.006451500660135721
#
#
# NF2_AMOTL2
#
#
# NF2_KIRREL1
# Eye Cancer
# 0.043994249129214735
#
#
# NF2_TAOK1
# Bile Duct Cancer
# 0.025063551799296657
#
#
# NF2_LATS2
# Thyroid Cancer
# 0.012057356821538094
#
#
# NF2_PTPN14
# Kidney Cancer
# 0.042870121906064255
#
#
# NF2_PTEN
#
#
# NF2_ABL2
# Kidney Cancer
# 0.010923837570628047
#
#
# NF2_RAC1
# Skin Cancer
# 0.03120870605596447
# Gallbladder Cancer
# 0.023378288987235485
#
#
# NF2_CRK
# Ovarian Cancer
# 0.0306313678019082
# Bile Duct Cancer
# 0.006411798706877841
#
#
# NF2_DLG5
# Ovarian Cancer
# 0.0306313678019082
# Bile Duct Cancer
# 0.006411798706877841
#
#
# NF2_PKN2
# Bile Duct Cancer
# 0.006411798706877841
# Kidney Cancer
# 0.010923837570628047

# %%
uli_df = pd.DataFrame(uli_df)
uli_df = uli_df.transpose()
uli_df
corres = []
alist = uli_df[0].to_list()

for _ in alist:
    a = _.split('_')[0]
    b = _.split('_')[1]
    
    nas = np.logical_or(np.isnan(allGenes[a]), np.isnan(allGenes[b]))
    corr = stats.pearsonr(allGenes[a][~nas], allGenes[b][~nas])[0]
    corres.append(corr)
    #corres.append(stats.pearsonr(allGenes[a],allGenes[b])[0])

corres = pd.DataFrame(corres)
uli_frame = pd.concat([uli_df,corres], axis=1)
uli_frame.to_csv('/home/lannwal/Documents/pairs_data70.txt')

# %%
uli_frame
# Out:
#                 0                           1            2         0
# 0        CDK4_RB1              Ovarian Cancer    0.0101908 -0.263779
# 1        CDK4_RB1               Breast Cancer    0.0287855 -0.263779
# 2        CDK4_RB1                 Bone Cancer    0.0353848 -0.263779
# 3        CDK4_RB1                    Rhabdoid    0.0413914 -0.263779
# 4     CDK4_CDKN2C                 Bone Cancer   0.00232369 -0.331270
# 5     CDK4_CDKN2C               Breast Cancer    0.0287855 -0.331270
# 6     CDK4_CDKN2C               Neuroblastoma    0.0235224 -0.331270
# 7      CDK4_CCND1                 Skin Cancer  0.000992436  0.376336
# 8      CDK4_CCND1                 Bone Cancer    0.0353848  0.376336
# 9      CDK4_CCND1               Neuroblastoma     0.004965  0.376336
# 10     CDK6_CCND3                    Leukemia  4.02816e-06  0.422625
# 11     CDK6_CCND3                    Lymphoma  0.000258565  0.422625
# 12     CDK6_CCND3                     Myeloma    0.0291686  0.422625
# 13     CDK6_CCNE1              Ovarian Cancer  0.000745326 -0.287111
# 14     CDK6_CCNE1                    Leukemia   0.00863872 -0.287111
# 15     CDK6_CCNE1  Endometrial/Uterine Cancer   0.00135905 -0.287111
# 16     CDK6_CCNE1                     Myeloma    0.0291686 -0.287111
# 17      CDK6_CDK4                 Bone Cancer   0.00993116 -0.167564
# 18      CDK6_CDK4                     Myeloma    0.0291686 -0.167564
# 19  CDKN2A_CDKN2B                 Liposarcoma    0.0064515  0.253078
# 20  CDKN2A_CDKN2B                  Eye Cancer    0.0439942  0.253078
# 21   CDKN2A_CCNE1              Ovarian Cancer  3.23998e-05 -0.163066
# 22   CDKN2A_CCNE1  Endometrial/Uterine Cancer  0.000240679 -0.163066
# 23   CDKN2A_CCNE1                 Liposarcoma    0.0064515 -0.163066
# 24    NF2_KIRREL1                  Eye Cancer    0.0439942  0.547631
# 25      NF2_TAOK1            Bile Duct Cancer    0.0250636  0.549264
# 26      NF2_LATS2              Thyroid Cancer    0.0120574  0.526110
# 27     NF2_PTPN14               Kidney Cancer    0.0428701  0.428898
# 28       NF2_ABL2               Kidney Cancer    0.0109238  0.261554
# 29       NF2_RAC1                 Skin Cancer    0.0312087 -0.357088
# 30       NF2_RAC1          Gallbladder Cancer    0.0233783 -0.357088
# 31        NF2_CRK              Ovarian Cancer    0.0306314 -0.412336
# 32        NF2_CRK            Bile Duct Cancer    0.0064118 -0.412336
# 33       NF2_DLG5              Ovarian Cancer    0.0306314 -0.399228
# 34       NF2_DLG5            Bile Duct Cancer    0.0064118 -0.399228
# 35       NF2_PKN2            Bile Duct Cancer    0.0064118 -0.454593
# 36       NF2_PKN2               Kidney Cancer    0.0109238 -0.454593

# %% [markdown]
# ## CLANKING SINGLE GENES

# %%
def clank2(list_of_genes):
    top_ce = {}
    for _ in list_of_genes:
        a = _
        a_list = rankings[a].index.to_list()
        a_df = pd.DataFrame(a_list)

        ranked_index = pd.concat([a_df,b_df]).sort_index().reset_index(drop=True)
        top_ce[a] = ranked_index[0].to_list()[0:50]
    return top_ce

# %%
def print_prd_and_ps(clank_lines):
    ressults = {}
    for _ in clank_lines.keys():
        temp = get_prd(clank_lines[_])
        temp = temp['primary_disease'].value_counts()
        print(_)
        for j in range(15):
            value_count = temp[j]
            dissease = temp.index[j]
            if get_hypergeometric_p_value(value_count,784,total_occurence(dissease),50) < 0.1:
                print(dissease)
                print(get_hypergeometric_p_value(value_count,784,total_occurence(dissease),50))
                ressults[j] = [_,ranking[_],dissease,get_hypergeometric_p_value(value_count,784,total_occurence(dissease),50)]
                # give it in the form     gene  / ranking / primary disease / p-value
                
        print('\n')
    return ressults

# %%
rezults = print_prd_and_ps(clank2(uli_list_individual))
# Out:
# CDK4
#
#
# RB1
#
#
# CDKN2C
#
#
# CCND1
# Skin Cancer
# 0.04312869543536226
#
#
# CDK6
# Myeloma
# 0.01682715335417644
#
#
# CCND3
#
#
# CCNE1
# Ovarian Cancer
# 0.013883867092110386
# Endometrial/Uterine Cancer
# 0.008874403504237852
#
#
# CDKN2A
# Liposarcoma
# 0.02801748877624971
#
#
# CDKN2B
#
#
# NF2
#
#
# AMOTL2
#
#
# KIRREL1
#
#
# TAOK1
#
#
# LATS2
#
#
# PTPN14
#
#
# PTEN
#
#
# ABL2
#
#
# RAC1
# Gallbladder Cancer
# 0.06814063781563229
#
#
# CRK
# Bile Duct Cancer
# 0.07198089840453077
#
#
# DLG5
#
#
# PKN2

# %%
rezults
# Out:
# {0: ['CCNE1', -0.3635121366076865, 'Ovarian Cancer', 0.013883867092110386],
#  2: ['CDK6', -1.169650089699101, 'Myeloma', 0.01682715335417644],
#  1: ['CRK', -0.5364427745465853, 'Bile Duct Cancer', 0.07198089840453077],
#  5: ['CDKN2A', 0.1, 'Liposarcoma', 0.02801748877624971],
#  9: ['RAC1', -1.416997333253427, 'Gallbladder Cancer', 0.06814063781563229]}

# %%
df1 = pd.DataFrame(rezults)

# %%
df1.transpose()
# Out:
#         0         1                   2          3
# 0   CCNE1 -0.363512      Ovarian Cancer  0.0138839
# 2    CDK6  -1.16965             Myeloma  0.0168272
# 1     CRK -0.536443    Bile Duct Cancer  0.0719809
# 5  CDKN2A       0.1         Liposarcoma  0.0280175
# 9    RAC1    -1.417  Gallbladder Cancer  0.0681406

# %%
# to compare, make list of -log(p)

# %% [markdown]
# # Visualizing the Clank

# %%
# do for a wide variety of random pairs and our network priors.
# this would be a good validation of the selection.

# %%
## part of clank visualization is of course the clustermap, but there is also
   the -log(p) plot, comparing to random pairs.

# %% [markdown]
# # KEEP IN MIND THAT NOT ALL GENES MIGHT BE CORRECTLY RANKED, WE HAVE TO VALIDATE FOR OUR SELECTION

# %%
a = set(cdk46low)
b = set(top_ce['CDK4_CDK6'][0:220])
b.intersection(a)
# Out:
# {'C32', 'HEL9217', 'KMM1', 'NCIH1573', 'RCC10RGB', 'RPMI8226', 'SNU308'}

# %% [markdown]
# # wir brauchen 220 Zelllinien um alle 7 linien die cdk4 und cdk6 von weniger als -1 haben zu inkludieren.

# %%
temp = disea["KIRREL1"]['primary_disease'].value_counts()

# %%
temp
# Out:
# Brain Cancer                  9
# Ovarian Cancer                4
# Skin Cancer                   4
# Bile Duct Cancer              3
# Eye Cancer                    2
# Lung Cancer                   2
# Liver Cancer                  2
# Kidney Cancer                 1
# Neuroblastoma                 1
# Liposarcoma                   1
# Pancreatic Cancer             1
# Endometrial/Uterine Cancer    1
# Colon/Colorectal Cancer       1
# Sarcoma                       1
# Breast Cancer                 1
# Head and Neck Cancer          1
# Name: primary_disease, dtype: int64

# %%
test1 = disea['CDK4']['primary_disease'].value_counts()

# %%
test1.index[1]
# Out:
# 'Lung Cancer'

# %%
get_hypergeometric_p_value(4,764,34,31)

# %%
def total_occurence(x):
    temp = data[data['primary_disease'] == x]
    return temp.shape[0]

# %%
data.shape
# Out:
# (1804, 24)

# %%
allGenes.shape
# Out:
# (783, 18119)

# %%
new_data = data[data.stripped_cell_line_name.isin(allGenes.index)]

# %%
new_data.shape
# Out:
# (764, 24)

# %%
data = new_data

# %%
total_occurence('Bone Cancer')
# Out:
# 28

# %%
# ueberpruefung nf2

# %%
nf2 = allGenes['NF2'].sort_values(ascending=False)

# %%
nf2_list = nf2.index.to_list()[0:35]

# %%
result_nf2 = get_prd(nf2_list)

# %%
result_nf2['primary_disease'].sort_values()
# Out:
# 1446              Bile Duct Cancer
# 1294              Bile Duct Cancer
# 208               Bile Duct Cancer
# 1426              Bile Duct Cancer
# 1239                Bladder Cancer
# 721                 Bladder Cancer
# 501                   Brain Cancer
# 468                   Brain Cancer
# 35                    Brain Cancer
# 97                    Brain Cancer
# 243                   Brain Cancer
# 932        Colon/Colorectal Cancer
# 285        Colon/Colorectal Cancer
# 985     Endometrial/Uterine Cancer
# 343                 Gastric Cancer
# 500           Head and Neck Cancer
# 627           Head and Neck Cancer
# 261                  Kidney Cancer
# 904                  Kidney Cancer
# 681                  Kidney Cancer
# 823                    Lung Cancer
# 394                    Lung Cancer
# 678                    Lung Cancer
# 518                    Lung Cancer
# 1181                 Neuroblastoma
# 882                 Ovarian Cancer
# 1032                Ovarian Cancer
# 1204                Ovarian Cancer
# 685                 Ovarian Cancer
# 1034                       Sarcoma
# 629                    Skin Cancer
# 547                    Skin Cancer
# 1284                   Skin Cancer
# 1306                   Skin Cancer
# 1163                Thyroid Cancer
# Name: primary_disease, dtype: object

# %%
get_hypergeometric_p_value(4,764,total_occurence('Neuroblastoma'),36)
# Out:
# 0.00971120087611825

# %%
sang[sang['Gene Symbol'] == 'NF2']['Role in Cancer']
# Out:
# 444    TSG
# Name: Role in Cancer, dtype: object

# %%
for _ in uli_list_individual:
    print(_)
    print(sang[sang['Gene Symbol'] == _]['Role in Cancer'])
    print('\n')
# Out:
# CDK4
# 115    oncogene
# Name: Role in Cancer, dtype: object
#
#
# RB1
# 552    TSG
# Name: Role in Cancer, dtype: object
#
#
# CDKN2C
# 120    TSG
# Name: Role in Cancer, dtype: object
#
#
# CCND1
# 97    oncogene, fusion
# Name: Role in Cancer, dtype: object
#
#
# CDK6
# 116    oncogene, fusion
# Name: Role in Cancer, dtype: object
#
#
# CCND3
# 99    oncogene, fusion
# Name: Role in Cancer, dtype: object
#
#
# CCNE1
# 100    oncogene
# Name: Role in Cancer, dtype: object
#
#
# CDKN2A
# 119    TSG
# Name: Role in Cancer, dtype: object
#
#
# CDKN2B
# Series([], Name: Role in Cancer, dtype: object)
#
#
# NF2
# 444    TSG
# Name: Role in Cancer, dtype: object
#
#
# AMOTL2
# Series([], Name: Role in Cancer, dtype: object)
#
#
# KIRREL1
# Series([], Name: Role in Cancer, dtype: object)
#
#
# TAOK1
# Series([], Name: Role in Cancer, dtype: object)
#
#
# LATS2
# 362    TSG
# Name: Role in Cancer, dtype: object
#
#
# PTPN14
# Series([], Name: Role in Cancer, dtype: object)
#
#
# PTEN
# 530    TSG
# Name: Role in Cancer, dtype: object
#
#
# ABL2
# 3    oncogene, fusion
# Name: Role in Cancer, dtype: object
#
#
# RAC1
# 543    oncogene
# Name: Role in Cancer, dtype: object
#
#
# CRK
# Series([], Name: Role in Cancer, dtype: object)
#
#
# DLG5
# Series([], Name: Role in Cancer, dtype: object)
#
#
# PKN2
# Series([], Name: Role in Cancer, dtype: object)

# %% [markdown]
# # rankings for our pairs!

# %%
uli_list = [['CDK4','RB1'],['CDK4','CDKN2C'],['CDK4','CCND1'],['CDK6','CCND3'],['CDK6','CDKN2A'],['CDK6','CCNE1'],['CDK6','CDK4'],['CDKN2A','CDKN2B'],
['CDKN2A','CCNE1'],['NF2','AMOTL2'],['NF2','KIRREL1'],['NF2','TAOK1'],['NF2','LATS2'],['NF2','PTPN14'],['NF2','PTEN'],['NF2','ABL2'],['NF2','RAC1'],['NF2','CRK'],['NF2','DLG5'],['NF2','PKN2']]

UL2 = [i for j in uli_list for i in j]
UL2 = set(UL2)
UL2 = list(UL2)

# %%
# get the sorting via quantiles here
# also already called mydict

# %%
top_cellines = {}

for _ in uli_list:
    a,b = _
    a_list = mydict[a].index.to_list()
    a_df = pd.DataFrame(a_list)

    b_list = mydict[b].index.to_list()
    b_df = pd.DataFrame(b_list)

    ranked_index = {}
    top_cellines[a + '_' + b] = ceL

# %%
#top_cellines

# %%
for _ in top_cellines.keys():
    temp = get_prd(top_cellines[_])
    temp = temp['primary_disease'].value_counts()
    print(_)
    print("\n")
    for _ in range(5):
        value_count = temp[_]
        dissease = temp.index[_]
        print(dissease)
        print(get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36))
    print('\n')

# %%
top_cellines
# Out:
# {'CDK4_RB1': ['NCIH2030',
#   'MDAMB415',
#   'SNU1544',
#   'OVMANA',
#   'OCUM1',
#   'WM88',
#   'LS',
#   'VCAP',
#   'EWS502',
#   'JHUEM7',
#   'MFE319',
#   'HS852T',
#   'UMUC9',
#   'JM1',
#   'BIN67',
#   'FU97',
#   'NCIH2122',
#   'K029AX',
#   'DMS53',
#   'RDES',
#   'PACADD188',
#   'COGE352',
#   'HCC2429',
#   'MDAMB453',
#   'GCIY',
#   'HEC1',
#   'SCCOHT1',
#   'MEL290',
#   'TO14',
#   'TTC642',
#   'JHUEM1',
#   'CHLA266',
#   'NCIH1915',
#   'HCC1419',
#   'ES2',
#   'NCIH2887'],
#  'CDK4_CDKN2C': ['MDAMB415',
#   'SNU1544',
#   'GIMEN',
#   'ONDA8',
#   'LS',
#   'SNU1',
#   'VCAP',
#   'EWS502',
#   'TC138',
#   'HS852T',
#   'UMUC9',
#   'JM1',
#   'U118MG',
#   'FU97',
#   'TC32',
#   'NB1643',
#   'DMS53',
#   'RDES',
#   'PACADD188',
#   'KU812',
#   'COGE352',
#   'KNS42',
#   'HCC2429',
#   'MDAMB453',
#   'MOLM13',
#   'HEC1',
#   'LP1',
#   'MEL290',
#   'CCLFPEDS0001T',
#   'TC71',
#   'TC205',
#   'NCIH1915',
#   'HCC1419',
#   'LN443',
#   'ES2',
#   'NCIH2887'],
#  'CDK4_CCND1': ['NCIH2052',
#   'MDAMB415',
#   'SNU1544',
#   'KPNYN',
#   'VCAP',
#   'EWS502',
#   'WM1799',
#   'MALME3M',
#   'UACC257',
#   'HS852T',
#   'UMUC9',
#   'NCIH1573',
#   'WM115',
#   'SKNFI',
#   'FU97',
#   'NB1643',
#   'DMS53',
#   'RDES',
#   'UMUC16',
#   'PACADD188',
#   'ES2',
#   'COGE352',
#   'HCC2429',
#   'C32',
#   'MDAMB453',
#   'HEC1',
#   'MELHO',
#   'LPS6',
#   'MEL290',
#   'LAN2',
#   'SNU216',
#   'SNU308',
#   'WM2664',
#   'NCIH1915',
#   'HCC1419',
#   'CHLA15',
#   'NCIH2887'],
#  'CDK6_CCND3': ['AML193',
#   'BLUE1',
#   'HSC1',
#   'DB',
#   'U937',
#   'SHI1',
#   'COGN305',
#   'EOL1',
#   'NCIH1568',
#   'U251MG',
#   'OPM2',
#   'CAKI2',
#   'SEMK2',
#   'SEM',
#   'OCIMY5',
#   'MM1S',
#   'KMS20',
#   'HEL9217',
#   'NCIH2023',
#   'MOLM13',
#   'TFK1',
#   'IGR39',
#   'BFTC909',
#   'KARPAS422',
#   'RAJI',
#   'KIJK',
#   'SNU308',
#   'F36P',
#   'SUDHL4',
#   'KARPAS299',
#   'COV434',
#   'THP1'],
#  'CDK6_CCNE1': ['EMTOKA',
#   'OVMANA',
#   'AML193',
#   'HSC1',
#   'DB',
#   'UWB1289',
#   'U937',
#   'SNU182',
#   'COGN305',
#   'JHUEM7',
#   'EFO21',
#   'EN',
#   'JHH1',
#   'NCIH1568',
#   'EFE184',
#   'NCIH522',
#   'COV318',
#   'OPM2',
#   'KMS20',
#   'SEMK2',
#   'OCIMY5',
#   'ONCODG1',
#   'MM1S',
#   'HEL9217',
#   'SNU1077',
#   'KURAMOCHI',
#   'MOLM13',
#   'GCIY',
#   'TFK1',
#   'IGR39',
#   'KLE',
#   'KARPAS422',
#   'TO14',
#   'SNU308',
#   'SNU8',
#   'SNU1033',
#   'SUDHL4',
#   'MDAMB157',
#   'THP1'],
#  'CDK6_CDK4': ['MDAMB415',
#   'SNU1544',
#   'AML193',
#   'HSC1',
#   'DB',
#   'U937',
#   'VCAP',
#   'EWS502',
#   'COGN305',
#   'HS852T',
#   'NCIH2887',
#   'UMUC9',
#   'NCIH1568',
#   'FU97',
#   'DMS53',
#   'RDES',
#   'OPM2',
#   'PACADD188',
#   'KMS20',
#   'COGE352',
#   'OCIMY5',
#   'MM1S',
#   'SEMK2',
#   'HEL9217',
#   'HCC2429',
#   'MDAMB453',
#   'MOLM13',
#   'HEC1',
#   'TFK1',
#   'IGR39',
#   'MEL290',
#   'KARPAS422',
#   'SNU308',
#   'NCIH1915',
#   'HCC1419',
#   'SUDHL4',
#   'NCIH3122',
#   'ES2',
#   'THP1'],
#  'CDKN2A_CDKN2B': ['SW948',
#   'HSB2',
#   'MV411',
#   'BT549',
#   'COGAR359',
#   'UMUC1',
#   'CHLA57',
#   'MEL285',
#   'GIMEN',
#   'LK2',
#   'EM2',
#   'JHUEM7',
#   'JHH2',
#   'HS852T',
#   'BIN67',
#   'SUM149PT',
#   'LPS853',
#   'SNU626',
#   'H413',
#   'SNU398',
#   'OCIAML2',
#   'OV7',
#   'COLO792',
#   'CCLP1',
#   'HS936T',
#   'UMCHOR1',
#   'JHH5',
#   'LPS6',
#   'LPS27',
#   'COLO679',
#   'SNU308',
#   'NCO2',
#   'EBC1',
#   'BICR56',
#   'YD8',
#   'NCIH2887'],
#  'CDKN2A_CCNE1': ['MV411',
#   'BT549',
#   'OVMANA',
#   'COGAR359',
#   'CHLA57',
#   'MEL285',
#   'EMTOKA',
#   'LK2',
#   'UWB1289',
#   'SNU182',
#   'JHUEM7',
#   'JHH2',
#   'EFO21',
#   'EN',
#   'HS852T',
#   'JHH1',
#   'BIN67',
#   'EFE184',
#   'NCIH522',
#   'LPS853',
#   'COV318',
#   'ONCODG1',
#   'SNU1077',
#   'OCIAML2',
#   'OV7',
#   'KURAMOCHI',
#   'COLO792',
#   'GCIY',
#   'HS936T',
#   'UMCHOR1',
#   'KLE',
#   'LPS6',
#   'TO14',
#   'LPS27',
#   'SNU8',
#   'NCO2',
#   'SNU1033',
#   'MDAMB157'],
#  'NF2_AMOTL2': ['HT1376',
#   'NCIH2030',
#   'NCIH2052',
#   'CASKI',
#   'GIMEN',
#   'KMRC1',
#   'MKN74',
#   'NUGC3',
#   'MCC26',
#   'LN340',
#   'RH28',
#   'PA1',
#   'BT16',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'HCC827',
#   'OV7',
#   'RHJT',
#   'CL11',
#   'CCLP1',
#   'SW620',
#   'MIAPACA2',
#   'SNU1079',
#   'IGR39',
#   'SNU668',
#   'U343',
#   'SNB75',
#   'RCC10RGB',
#   'MONOMAC1',
#   'AMO1',
#   'DKMG',
#   'CME1',
#   'OCIMY7',
#   'D283MED',
#   'SNU16',
#   'SG231',
#   'CW9019',
#   'YD8'],
#  'NF2_KIRREL1': ['KE97',
#   'HT1376',
#   'NCIH2030',
#   'NCIH2052',
#   'EMTOKA',
#   'GIMEN',
#   'KMRC1',
#   'EM2',
#   'HCA1',
#   'MCC26',
#   'RH28',
#   'JM1',
#   'AU565',
#   'SNU503',
#   'PA1',
#   'NCIH2110',
#   'RERFLCAD2',
#   'COLO678',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'KYSE450',
#   'C10',
#   'OV7',
#   'SUPT1',
#   'CCLP1',
#   'IGR39',
#   'SNU1079',
#   'SNU668',
#   'U343',
#   'SNB75',
#   'RCC10RGB',
#   'KARPAS422',
#   'EW8',
#   'UMUC7',
#   'DKMG',
#   'ICC12',
#   'CW9019',
#   'YD8'],
#  'NF2_TAOK1': ['HT1376',
#   'NCIH2030',
#   'LN235',
#   'NMCG1',
#   'GIMEN',
#   'SNU1105',
#   'CAL62',
#   'KMRC1',
#   'MCC26',
#   'PA1',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'PEA1',
#   'OV7',
#   'CCLP1',
#   'SW982',
#   'GAMG',
#   'IGR39',
#   'SNU1079',
#   'SH10TC',
#   'SNU668',
#   'HS294T',
#   'U343',
#   'SNB75',
#   'SLR26',
#   'SNU8',
#   'DKMG',
#   'ECC2',
#   'CW9019',
#   'YD8'],
#  'NF2_LATS2': ['HT1376',
#   'NCIH2030',
#   'CAL12T',
#   'HCC515',
#   'GIMEN',
#   'KMRC1',
#   'SNU761',
#   'MCC26',
#   'JHOS2',
#   'PA1',
#   'TUHR10TKB',
#   'YH13',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'OV7',
#   'COV504',
#   'SW982',
#   'CCLP1',
#   'IGR39',
#   'SNU1079',
#   'SNU668',
#   'U343',
#   'SNB75',
#   'MEL290',
#   'HS944T',
#   'DKMG',
#   'CW9019',
#   'YD8',
#   'CH157MN'],
#  'NF2_PTPN14': ['HT1376',
#   'NCIH2030',
#   'HSB2',
#   'GIMEN',
#   'CAL62',
#   'KMRC1',
#   'MCC26',
#   'JHH2',
#   'U118MG',
#   'PA1',
#   'TUHR10TKB',
#   'MM127',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'PEA1',
#   'OV7',
#   'CCLP1',
#   'SW982',
#   'COV504',
#   'GAMG',
#   'IGR39',
#   'SNU1079',
#   'UOK101',
#   'SNU668',
#   'MDAMB231',
#   'U343',
#   'HCC366',
#   'ONDA7',
#   'SNB75',
#   'ISTMES2',
#   'DKMG',
#   '253J',
#   'CW9019',
#   'YD8',
#   'CH157MN'],
#  'NF2_PTEN': ['HT1376',
#   'NCIH2030',
#   'SLR24',
#   'GIMEN',
#   'RPMI8226',
#   'KMRC1',
#   'LS',
#   'MCC26',
#   'COGN305',
#   'TC32',
#   'PA1',
#   'HUH6',
#   'OCIAML3',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'OCUG1',
#   'PEA1',
#   'OV7',
#   'H357',
#   'CCLP1',
#   'IGR39',
#   'SNU1079',
#   'SNU668',
#   'U343',
#   'SNB75',
#   'A431',
#   'ASPC1',
#   'D425',
#   'TC71',
#   'DKMG',
#   'SNU213',
#   'CW9019',
#   'SNU349',
#   'YD8'],
#  'NF2_ABL2': ['HT1376',
#   'SW948',
#   'NCIH2030',
#   'IMR32',
#   'SUM52PE',
#   'MC116',
#   'GIMEN',
#   'SKN',
#   'KMRC1',
#   'SNU46',
#   'UWB1289',
#   'HCA1',
#   'MCC26',
#   'GI1',
#   'VMRCRCW',
#   'PA1',
#   'KMS20',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'OS252',
#   'OV7',
#   'CL11',
#   'CCLP1',
#   'IGR39',
#   'SNU1079',
#   'LP1',
#   'SNU668',
#   'U2904',
#   'KLE',
#   'SNB75',
#   'U343',
#   'UMUC7',
#   'DKMG',
#   'SHP77',
#   'ONS76',
#   'CW9019',
#   'YD8'],
#  'NF2_RAC1': ['HT1376',
#   'SW1573',
#   'NCIH2030',
#   'UMUC3',
#   'GIMEN',
#   'KMRC1',
#   'MCC26',
#   'JHOS2',
#   'HS852T',
#   'PK45H',
#   'PA1',
#   'HT1080',
#   'MM127',
#   'YH13',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'OV7',
#   'CCLP1',
#   'SW982',
#   'COV504',
#   'GAMG',
#   'IGR39',
#   'SNU1079',
#   'NOZ',
#   'SNU668',
#   'U343',
#   'SNB75',
#   'ONDA7',
#   'RVH421',
#   'NCIH747',
#   'DKMG',
#   'MDAMB157',
#   'CW9019',
#   'YD8'],
#  'NF2_CRK': ['SNU840',
#   'HT1376',
#   'NCIH2030',
#   'GIMEN',
#   'KMRC1',
#   'LCLC103H',
#   'MCC26',
#   'JHOS2',
#   'CAKI1',
#   'SKMEL2',
#   'PK45H',
#   'PA1',
#   'UMUC16',
#   'C2BBE1',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'NCIH520',
#   'PEA1',
#   'OV7',
#   'CCLP1',
#   'SW982',
#   'PANC1005',
#   'IGR39',
#   'SNU1079',
#   'MUGCHOR1',
#   'SNU668',
#   'U343',
#   'SNB75',
#   'SSP25',
#   'SNU216',
#   'DKMG',
#   'ECC2',
#   'CW9019',
#   'YD8',
#   'CH157MN'],
#  'NF2_DLG5': ['HT1376',
#   'NCIH2030',
#   'MDAMB415',
#   'SUM52PE',
#   'OVMANA',
#   'GIMEN',
#   'BOKU',
#   'KMRC1',
#   'MCC26',
#   'JHOS2',
#   'PK45H',
#   'CAL51',
#   'SUM149PT',
#   'PA1',
#   'MM127',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'OV7',
#   'CCLP1',
#   'IGR39',
#   'SNU1079',
#   'UOK101',
#   'SNU668',
#   'U343',
#   'SNB75',
#   'CCLFPEDS0001T',
#   'SNU8',
#   'DKMG',
#   '253J',
#   'ECC2',
#   'ONDA9',
#   'CW9019',
#   'YD8'],
#  'NF2_PKN2': ['HT1376',
#   'NCIH2030',
#   'SLR24',
#   'GIMEN',
#   'CAL120',
#   'KMRC1',
#   'SNU761',
#   'MCC26',
#   'PECAPJ49',
#   'PA1',
#   'HUCCT1',
#   'HCC461',
#   'YH13',
#   'ICC3',
#   'KKU100',
#   'TOV21G',
#   'OV7',
#   'T24',
#   '9505BIK',
#   'CCLP1',
#   'RBE',
#   'IGR39',
#   'SNU1079',
#   'SNU668',
#   'U343',
#   'NCIN87',
#   'SNB75',
#   'SNU8',
#   'DKMG',
#   '253J',
#   '95T1000',
#   'SNU449',
#   'CW9019',
#   'YD8']}

# %%
# we need our ranking now, for all the celllines

# %%
top_cellines = {}

for _ in uli_list:
    a,b = _
    a_list = sangerdict[a].index.to_list()
    a_df = pd.DataFrame(a_list)

    b_list = sangerdict[b].index.to_list()
    b_df = pd.DataFrame(b_list)

    ranked_index = {}
    for _ in a_df.index:
        for j in b_df.index:
            ranked_index[a_df.values[_][0] + '_' + b_df.values[j][0]] = _ + j

    dataX = [v for v in sorted(ranked_index.items(), key=lambda item: item[1])]
    ceL = [ x for x in range(0,500) for x in dataX[x][0].split('_')]
    ceL = set(ceL)
    ceL = list(ceL)
    top_cellines[a + '_' + b] = ceL

# %%
# IMPORTANT RESULTS OF PAIRS!
for _ in top_cellines.keys():
    temp = get_prd(top_cellines[_])
    temp = temp['primary_disease'].value_counts()
    print(_)
    print("\n")
    for _ in range(15):  # this is WRONG AND STUPID :)
        value_count = temp[_]
        dissease = temp.index[_]
        if get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36) < 0.07:
            print(dissease)
            print(get_hypergeometric_p_value(value_count,764,total_occurence(dissease),36))
    print('\n')
# Out:
# CDK4_RB1
#
#
# Ovarian Cancer
# 0.0004066541122091733
# Breast Cancer
# 0.0006056067209645454
# Bone Cancer
# 0.0012643016348884962
# Endometrial/Uterine Cancer
# 0.029535781202476345
# Rhabdoid
# 0.06310597678014068
#
#
# CDK4_CDKN2C
#
#
# Bone Cancer
# 1.726818442829255e-05
# Breast Cancer
# 0.0006056067209645454
# Brain Cancer
# 0.05132556487939811
# Neuroblastoma
# 0.001260665128357237
#
#
# CDK4_CCND1
#
#
# Skin Cancer
# 4.052714821761134e-05
# Neuroblastoma
# 0.0001244586412632915
# Bone Cancer
# 0.0012643016348884962
# Breast Cancer
# 0.003662941207072066
# Prostate Cancer
# 0.04712041884815903
#
#
# CDK6_CCND3
#
#
# Leukemia
# 2.661589367770495e-10
# Lymphoma
# 1.4331513855705839e-06
# Myeloma
# 0.0016236411604765646
#
#
# CDK6_CCNE1
#
#
# Ovarian Cancer
# 7.554772172353463e-06
# Leukemia
# 0.0003406768183894259
# Endometrial/Uterine Cancer
# 9.289441753140336e-06
# Myeloma
# 0.0016236411604765646
#
#
# CDK6_CDK4
#
#
# Leukemia
# 0.0019855590056850653
# Bone Cancer
# 0.0012643016348884962
# Breast Cancer
# 0.003662941207072066
# Myeloma
# 0.0016236411604765646
# Lymphoma
# 0.014009475418235513
#
#
# CDKN2A_CDKN2B
#
#
# Leukemia
# 0.0019855590056850653
# Skin Cancer
# 0.006450153102352905
# Head and Neck Cancer
# 0.06382927040997433
# Liposarcoma
# 0.0009027664668420572
# Eye Cancer
# 0.012209914798453863
#
#
# CDKN2A_CCNE1
#
#
# Ovarian Cancer
# 5.757134776257814e-09
# Endometrial/Uterine Cancer
# 7.208053709924553e-07
# Liposarcoma
# 0.0009027664668420572
#
#
# NF2_AMOTL2
#
#
# Brain Cancer
# 0.004251759075998065
# Bile Duct Cancer
# 0.0008282561732141397
# Kidney Cancer
# 0.01655087654427856
# Sarcoma
# 0.019366643716110046
# Gastric Cancer
# 0.029535781202476345
#
#
# NF2_KIRREL1
#
#
# Brain Cancer
# 0.01609094781807734
# Bile Duct Cancer
# 0.0008282561732141397
# Colon/Colorectal Cancer
# 0.025344156935661583
# Kidney Cancer
# 0.01655087654427856
#
#
# NF2_TAOK1
#
#
# Brain Cancer
# 0.004251759075998065
# Ovarian Cancer
# 0.002301339984381538
# Bile Duct Cancer
# 0.0008282561732141397
# Kidney Cancer
# 0.01655087654427856
# Thyroid Cancer
# 0.028748543484635146
#
#
# NF2_LATS2
#
#
# Brain Cancer
# 0.05132556487939811
# Ovarian Cancer
# 0.04161787511478907
# Kidney Cancer
# 0.01655087654427856
# Bile Duct Cancer
# 0.029535781202476345
# Thyroid Cancer
# 0.028748543484635146
# Eye Cancer
# 0.012209914798453863
#
#
# NF2_PTPN14
#
#
# Brain Cancer
# 0.004251759075998065
# Ovarian Cancer
# 0.04161787511478907
# Kidney Cancer
# 0.0025731703510618008
# Bile Duct Cancer
# 0.029535781202476345
# Thyroid Cancer
# 0.028748543484635146
#
#
# NF2_PTEN
#
#
# Brain Cancer
# 0.05132556487939811
# Ovarian Cancer
# 0.04161787511478907
# Kidney Cancer
# 0.01655087654427856
# Myeloma
# 0.011733090805031347
# Liver Cancer
# 0.01655087654427856
# Pancreatic Cancer
# 0.06994699011509398
# Bile Duct Cancer
# 0.029535781202476345
# Neuroblastoma
# 0.05535689775605679
#
#
# NF2_ABL2
#
#
# Brain Cancer
# 0.01609094781807734
# Colon/Colorectal Cancer
# 0.0010446254195455636
# Kidney Cancer
# 0.0025731703510618008
# Ovarian Cancer
# 0.04161787511478907
# Bile Duct Cancer
# 0.029535781202476345
# Head and Neck Cancer
# 0.06382927040997433
# Myeloma
# 0.06305521662983778
#
#
# NF2_RAC1
#
#
# Skin Cancer
# 0.0014049538993648775
# Brain Cancer
# 0.05132556487939811
# Ovarian Cancer
# 0.04161787511478907
# Kidney Cancer
# 0.01655087654427856
# Bile Duct Cancer
# 0.029535781202476345
# Sarcoma
# 0.019366643716110046
# Gallbladder Cancer
# 0.006291572696504389
#
#
# NF2_CRK
#
#
# Ovarian Cancer
# 0.002301339984381538
# Bile Duct Cancer
# 9.761948649094519e-05
# Brain Cancer
# 0.05132556487939811
# Kidney Cancer
# 0.01655087654427856
# Pancreatic Cancer
# 0.06994699011509398
#
#
# NF2_DLG5
#
#
# Ovarian Cancer
# 0.0004066541122091733
# Brain Cancer
# 0.01609094781807734
# Bile Duct Cancer
# 0.0008282561732141397
# Breast Cancer
# 0.06994699011509398
# Kidney Cancer
# 0.01655087654427856
#
#
# NF2_PKN2
#
#
# Bile Duct Cancer
# 9.761948649094519e-05
# Kidney Cancer
# 0.00030842808178179425
# Ovarian Cancer
# 0.04161787511478907
# Head and Neck Cancer
# 0.06382927040997433

# %%
#
#
uli_list_individual = ['CDK4','RB1','CDKN2C','CCND1','CDK6','CCND3','CCNE1',
'CDKN2A','CDKN2B','NF2','AMOTL2','KIRREL1','TAOK1','LATS2','PTPN14','PTEN','ABL2','RAC1','CRK','DLG5','PKN2']


myGenes = allGenes[uli_list_individual]

rankings_correct = {
 'CDK4': '-','RB1': '+','CDKN2C': '+','CCND1': '-','CDK6': '-','CCND3': '-','CCNE1': '-','CDKN2A': '+','CDKN2B': '+','NF2': '+','AMOTL2': '-','KIRREL1': '-','TAOK1': '+','LATS2': '+','PTPN14': '+','PTEN': '+','ABL2': '-','RAC1': '-','CRK': '-','DLG5': '-','PKN2': '-'}

# new version with sanger cancer gene annotation
sangerdict = {}
for _ in myGenes.columns:
    if rankings_correct[_] == '+':
        sangerdict[_] = allGenes[_].sort_values(ascending=False)
    else:
        sangerdict[_] = allGenes[_].sort_values()

# %% [markdown]
# # RANDOM PAIRS TO VALIDATE NETWORK PRIORS

# %%
# another idea is to explore a single gene and its connections to various diseases based on this approach.
#cdk4_pairs = []
#for _ in range(200):
  #  cdk4_pairs.append(['CDK4', random.choice(random_list)])

# %%
import random
random_list = [random.choice(allGenes.columns) for x in range(1800)]

# %%
random_pairs = []
for _ in range(40):
    random_pairs.append([random.choice(random_list), random.choice(random_list)])

# %%
# define clank70, also have clank 35 be a function
def clank70(list_of_pairs):
    top_ce = {}
    for _ in list_of_pairs:
        a,b = _
        a_list = rankings[a].index.to_list()
        a_df = pd.DataFrame(a_list)

        b_list = rankings[b].index.to_list()
        b_df = pd.DataFrame(b_list)

        ranked_index = pd.concat([a_df,b_df]).sort_index().reset_index(drop=True)
        top_ce[a + '_' + b] = ranked_index[0].to_list()[0:70]
    return top_ce

# %%
random_df = print_PRIMARY_DISEASES(clank70(random_pairs),70)
# Out:
# ARL6IP5_EFEMP1
# Bone Cancer
# 7.6098372677751e-05
#
#
# TCEAL5_TMEM145
#
#
# LILRB3_ATP1B1
# Lymphoma
# 0.035609602738929214
# Rhabdoid
# 0.005731486973824262
#
#
# GSTA2_ATP5IF1
# Skin Cancer
# 0.01119527282122772
#
#
# CLCC1_LRRC72
# Lymphoma
# 0.0016513440636849043
#
#
# MAPK13_LDHAL6B
# Lymphoma
# 0.035609602738929214
#
#
# AGK_H2AFJ
# Leukemia
# 2.4108080682516166e-05
# Bone Cancer
# 0.03538484245000727
# Lymphoma
# 0.035609602738929214
#
#
# TM7SF3_FAM160A1
# Colon/Colorectal Cancer
# 0.04403821279944405
#
#
# ESS2_VPS33B
# Breast Cancer
# 0.0022009460367995452
# Gallbladder Cancer
# 0.023378288987235485
#
#
# ARSE_PAFAH2
# Lymphoma
# 0.035609602738929214
#
#
# CAMKK2_RAB20
# Leukemia
# 0.008638717677791043
#
#
# SPP2_SIK3
#
#
# TPD52L3_RPS9
# Lymphoma
# 0.0016513440636849043
#
#
# FCGR2B_RECQL
# Myeloma
# 0.029168556412179015
# Kidney Cancer
# 0.042870121906064255
# Gallbladder Cancer
# 0.023378288987235485
#
#
# DUS1L_RECQL
#
#
# PID1_ERVV-2
#
#
# SLC35A3_SPTBN1
#
#
# GARS_NXPE3
#
#
# FRG1_CT55
# Skin Cancer
# 0.03120870605596447
#
#
# EN2_CENPN
# Skin Cancer
# 0.03120870605596447
#
#
# NKAP_SELPLG
# Neuroblastoma
# 0.023522443343404056
#
#
# SIK2_ZDHHC8
# Brain Cancer
# 0.034516935459966015
# Neuroblastoma
# 0.023522443343404056
#
#
# MINDY1_MSI2
# Neuroblastoma
# 4.21779610664284e-09
# Gallbladder Cancer
# 0.023378288987235485
#
#
# LLGL2_PAK2
# Colon/Colorectal Cancer
# 0.04403821279944405
#
#
# SIAH3_SMARCD1
# Myeloma
# 0.0011870842920610849
# Rhabdoid
# 0.04139143580056207
#
#
# NLN_TMEM50B
# Bone Cancer
# 0.03538484245000727
#
#
# GGCT_ATP6V0D1
# Colon/Colorectal Cancer
# 0.04403821279944405
# Gastric Cancer
# 0.025063551799296657
# Bone Cancer
# 0.03538484245000727
#
#
# MLST8_ARPC3
# Lymphoma
# 0.008557208166588252
# Kidney Cancer
# 0.010923837570628047
#
#
# RGS18_ZNF787
# Brain Cancer
# 0.034516935459966015
# Endometrial/Uterine Cancer
# 0.025063551799296657
# Gallbladder Cancer
# 0.023378288987235485
#
#
# ESX1_FAM173A
#
#
# QRICH1_MDN1
# Rhabdoid
# 0.0005299995179609289
#
#
# CALR3_DSC2
#
#
# KAZN_TOM1
#
#
# PLCXD3_PARP11
# Skin Cancer
# 0.03120870605596447
#
#
# FAM163A_NAGA
#
#
# MAGEA3_MED7
# Colon/Colorectal Cancer
# 0.014610902962387425
#
#
# ZNF3_PBK
# Skin Cancer
# 0.01119527282122772
#
#
# GARS_CDHR2
# Colon/Colorectal Cancer
# 0.004156463941329221
# Bone Cancer
# 0.03538484245000727
#
#
# SRRD_MORC4
# Skin Cancer
# 0.03120870605596447
#
#
# RFTN1_KRTAP13-4
# Skin Cancer
# 0.03120870605596447

# %%
random_df
# Out:
# {0: ['BRIP1_GH1', 'Leukemia', 0.008327493661142688],
#  1: ['CYP4F11_EPN1', 'Leukemia', 0.008327493661142688],
#  2: ['CYP4F11_EPN1', 'Prostate Cancer', 0.04581151832457946],
#  3: ['PBOV1_TEX9', 'Leukemia', 0.008327493661142688],
#  4: ['ACOX3_C6orf203', 'Colon/Colorectal Cancer', 0.0008721972675665855],
#  5: ['ZNF668_RAMP1', 'Prostate Cancer', 0.04581151832457946],
#  6: ['FIGNL1_RAB40B', 'Leukemia', 0.03401232901575299],
#  7: ['FIGNL1_RAB40B', 'Neuroblastoma', 0.001102858671815676],
#  8: ['FIGNL1_RAB40B', 'Sarcoma', 0.017567681356325214],
#  9: ['YBX3_GLYATL3', 'Leukemia', 0.03401232901575299],
#  10: ['MFSD5_ATRAID', 'Brain Cancer', 0.04545312870249513],
#  11: ['MFSD5_ATRAID', 'Liposarcoma', 0.01870105550732919],
#  12: ['LIN9_ACSL5', 'Prostate Cancer', 0.04581151832457946],
#  13: ['TSPAN31_XKR9', 'Skin Cancer', 0.005469142146211375],
#  14: ['TFAP2D_ALAS1', 'Leukemia', 0.0016657208025991467],
#  15: ['HIST1H2AD_KNSTRN', 'Bladder Cancer', 0.038697809420019005],
#  16: ['HIST1H2AD_KNSTRN', 'Prostate Cancer', 0.04581151832457946],
#  17: ['SLC17A9_TIMM21', 'Leukemia', 0.008327493661142688],
#  18: ['RFX3_APOA4', 'Leukemia', 0.008327493661142688],
#  19: ['H2BFM_ACSF2', 'Kidney Cancer', 0.014997798078351283],
#  20: ['ATP11C_CPOX', 'Lymphoma', 0.0018048140931732088],
#  21: ['CCAR1_TIGD3', 'Sarcoma', 0.017567681356325214],
#  22: ['SNX1_PNPLA6', 'Lung Cancer', 0.041514456397113764],
#  23: ['C11orf74_BACE2', 'Bone Cancer', 0.006893359739880277],
#  24: ['PAOX_OR6C70', 'Colon/Colorectal Cancer', 0.022616291089314386],
#  25: ['PAOX_OR6C70', 'Bile Duct Cancer', 0.026875795855328344],
#  26: ['CLPB_DSEL', 'Lymphoma', 0.0018048140931732088],
#  27: ['RUNX2_SNAPC5', 'Leukemia', 0.008327493661142688],
#  28: ['RUNX2_SNAPC5', 'Myeloma', 0.0001454712593691467],
#  29: ['RUNX2_SNAPC5', 'Sarcoma', 0.0027908525080078106],
#  30: ['RUNX2_SNAPC5', 'Bone Cancer', 0.034471204891342894],
#  31: ['KRTAP19-5_RAB8B', 'Neuroblastoma', 0.008772252459695365],
#  32: ['KRTAP19-5_RAB8B', 'Prostate Cancer', 0.04581151832457946],
#  33: ['LIM2_IRAK4', 'Gastric Cancer', 0.026875795855328344],
#  34: ['HIST1H2BF_CD8A', 'Leukemia', 0.0002758545227587288],
#  35: ['HIST1H2BF_CD8A', 'Bladder Cancer', 0.038697809420019005],
#  36: ['GH1_PERP', 'Leukemia', 0.03401232901575299],
#  37: ['GH1_PERP', 'Prostate Cancer', 0.04581151832457946],
#  38: ['RAB40B_PEA15', 'Skin Cancer', 4.223759780549234e-08],
#  39: ['RAB40B_PEA15', 'Neuroblastoma', 0.001102858671815676]}

# %%
random_df = pd.DataFrame(random_df)
random_df = random_df.transpose()
random_df
# Out:
#                   0                           1            2
# 0    ARL6IP5_EFEMP1                 Bone Cancer  7.60984e-05
# 1     LILRB3_ATP1B1                    Lymphoma    0.0356096
# 2     LILRB3_ATP1B1                    Rhabdoid   0.00573149
# 3     GSTA2_ATP5IF1                 Skin Cancer    0.0111953
# 4      CLCC1_LRRC72                    Lymphoma   0.00165134
# 5    MAPK13_LDHAL6B                    Lymphoma    0.0356096
# 6         AGK_H2AFJ                    Leukemia  2.41081e-05
# 7         AGK_H2AFJ                 Bone Cancer    0.0353848
# 8         AGK_H2AFJ                    Lymphoma    0.0356096
# 9   TM7SF3_FAM160A1     Colon/Colorectal Cancer    0.0440382
# 10      ESS2_VPS33B               Breast Cancer   0.00220095
# 11      ESS2_VPS33B          Gallbladder Cancer    0.0233783
# 12      ARSE_PAFAH2                    Lymphoma    0.0356096
# 13     CAMKK2_RAB20                    Leukemia   0.00863872
# 14     TPD52L3_RPS9                    Lymphoma   0.00165134
# 15     FCGR2B_RECQL                     Myeloma    0.0291686
# 16     FCGR2B_RECQL               Kidney Cancer    0.0428701
# 17     FCGR2B_RECQL          Gallbladder Cancer    0.0233783
# 18        FRG1_CT55                 Skin Cancer    0.0312087
# 19        EN2_CENPN                 Skin Cancer    0.0312087
# 20      NKAP_SELPLG               Neuroblastoma    0.0235224
# 21      SIK2_ZDHHC8                Brain Cancer    0.0345169
# 22      SIK2_ZDHHC8               Neuroblastoma    0.0235224
# 23      MINDY1_MSI2               Neuroblastoma   4.2178e-09
# 24      MINDY1_MSI2          Gallbladder Cancer    0.0233783
# 25       LLGL2_PAK2     Colon/Colorectal Cancer    0.0440382
# 26    SIAH3_SMARCD1                     Myeloma   0.00118708
# 27    SIAH3_SMARCD1                    Rhabdoid    0.0413914
# 28      NLN_TMEM50B                 Bone Cancer    0.0353848
# 29    GGCT_ATP6V0D1     Colon/Colorectal Cancer    0.0440382
# 30    GGCT_ATP6V0D1              Gastric Cancer    0.0250636
# 31    GGCT_ATP6V0D1                 Bone Cancer    0.0353848
# 32      MLST8_ARPC3                    Lymphoma   0.00855721
# 33      MLST8_ARPC3               Kidney Cancer    0.0109238
# 34     RGS18_ZNF787                Brain Cancer    0.0345169
# 35     RGS18_ZNF787  Endometrial/Uterine Cancer    0.0250636
# 36     RGS18_ZNF787          Gallbladder Cancer    0.0233783
# 37      QRICH1_MDN1                    Rhabdoid      0.00053
# 38    PLCXD3_PARP11                 Skin Cancer    0.0312087
# 39      MAGEA3_MED7     Colon/Colorectal Cancer    0.0146109
# 40         ZNF3_PBK                 Skin Cancer    0.0111953
# 41       GARS_CDHR2     Colon/Colorectal Cancer   0.00415646
# 42       GARS_CDHR2                 Bone Cancer    0.0353848
# 43       SRRD_MORC4                 Skin Cancer    0.0312087
# 44  RFTN1_KRTAP13-4                 Skin Cancer    0.0312087

# %%
random_df = pd.DataFrame(random_df)
random_df = random_df.transpose()
random_df
random_corres = []
alist = random_df[0].to_list()

for _ in alist:
    a = _.split('_')[0]
    b = _.split('_')[1]
    
    nas = np.logical_or(np.isnan(allGenes[a]), np.isnan(allGenes[b]))
    corr = stats.pearsonr(allGenes[a][~nas], allGenes[b][~nas])[0]
    random_corres.append(corr)
    #corres.append(stats.pearsonr(allGenes[a],allGenes[b])[0])

random_corres = pd.DataFrame(random_corres)
random_frame = pd.concat([random_df,random_corres], axis=1)
random_frame.to_csv('/home/lannwal/Documents/random_pairs_data70_2.txt')

# %%
random_corres
# Out:
# [0.0661224994776135,
#  0.07372008319941442,
#  0.07372008319941442,
#  -0.011944703337484874,
#  -0.030715381965155403,
#  0.05267922343173636,
#  -0.09508762021636323,
#  -0.09508762021636323,
#  -0.09508762021636323,
#  -0.0614078080402794,
#  0.032765398814271006,
#  0.032765398814271006,
#  -0.06468469993971657,
#  -0.07151967266214813,
#  -0.03183363460187251,
#  -0.022964907820789186,
#  -0.022964907820789186,
#  0.10057104348815663,
#  -0.015006280451864765,
#  -0.06383644871968526,
#  0.08658267590903276,
#  0.05628401085242471,
#  0.050682721633996085,
#  -0.015159780725815161,
#  -0.03869245287845091,
#  -0.03869245287845091,
#  -0.030999331930151162,
#  0.06965970827526696,
#  0.06965970827526696,
#  0.06965970827526696,
#  0.06965970827526696,
#  -0.026216866785826264,
#  -0.026216866785826264,
#  0.08630735337721421,
#  -0.0035726241482783114,
#  -0.0035726241482783114,
#  0.024423616312501867,
#  0.024423616312501867,
#  -0.0066017669869355665,
#  -0.0066017669869355665]

# %%
random_corres = pd.DataFrame(random_corres)
random_frame = pd.concat([random_df,random_corres], axis=1)
random_frame.to_csv('/home/lannwal/Documents/random_pairs_data70_2.txt')

# %%
random_frame
# Out:
#                   0                           1            2         0
# 0    ARL6IP5_EFEMP1                 Bone Cancer  7.60984e-05  0.036529
# 1     LILRB3_ATP1B1                    Lymphoma    0.0356096 -0.042649
# 2     LILRB3_ATP1B1                    Rhabdoid   0.00573149 -0.042649
# 3     GSTA2_ATP5IF1                 Skin Cancer    0.0111953  0.015514
# 4      CLCC1_LRRC72                    Lymphoma   0.00165134 -0.027348
# 5    MAPK13_LDHAL6B                    Lymphoma    0.0356096  0.037849
# 6         AGK_H2AFJ                    Leukemia  2.41081e-05 -0.045766
# 7         AGK_H2AFJ                 Bone Cancer    0.0353848 -0.045766
# 8         AGK_H2AFJ                    Lymphoma    0.0356096 -0.045766
# 9   TM7SF3_FAM160A1     Colon/Colorectal Cancer    0.0440382  0.046081
# 10      ESS2_VPS33B               Breast Cancer   0.00220095  0.029371
# 11      ESS2_VPS33B          Gallbladder Cancer    0.0233783  0.029371
# 12      ARSE_PAFAH2                    Lymphoma    0.0356096  0.014299
# 13     CAMKK2_RAB20                    Leukemia   0.00863872 -0.085885
# 14     TPD52L3_RPS9                    Lymphoma   0.00165134 -0.002119
# 15     FCGR2B_RECQL                     Myeloma    0.0291686  0.047243
# 16     FCGR2B_RECQL               Kidney Cancer    0.0428701  0.047243
# 17     FCGR2B_RECQL          Gallbladder Cancer    0.0233783  0.047243
# 18        FRG1_CT55                 Skin Cancer    0.0312087 -0.037996
# 19        EN2_CENPN                 Skin Cancer    0.0312087 -0.061718
# 20      NKAP_SELPLG               Neuroblastoma    0.0235224 -0.032210
# 21      SIK2_ZDHHC8                Brain Cancer    0.0345169 -0.047212
# 22      SIK2_ZDHHC8               Neuroblastoma    0.0235224 -0.047212
# 23      MINDY1_MSI2               Neuroblastoma   4.2178e-09 -0.108602
# 24      MINDY1_MSI2          Gallbladder Cancer    0.0233783 -0.108602
# 25       LLGL2_PAK2     Colon/Colorectal Cancer    0.0440382  0.000575
# 26    SIAH3_SMARCD1                     Myeloma   0.00118708 -0.029168
# 27    SIAH3_SMARCD1                    Rhabdoid    0.0413914 -0.029168
# 28      NLN_TMEM50B                 Bone Cancer    0.0353848  0.118123
# 29    GGCT_ATP6V0D1     Colon/Colorectal Cancer    0.0440382  0.010211
# 30    GGCT_ATP6V0D1              Gastric Cancer    0.0250636  0.010211
# 31    GGCT_ATP6V0D1                 Bone Cancer    0.0353848  0.010211
# 32      MLST8_ARPC3                    Lymphoma   0.00855721  0.131855
# 33      MLST8_ARPC3               Kidney Cancer    0.0109238  0.131855
# 34     RGS18_ZNF787                Brain Cancer    0.0345169  0.019013
# 35     RGS18_ZNF787  Endometrial/Uterine Cancer    0.0250636  0.019013
# 36     RGS18_ZNF787          Gallbladder Cancer    0.0233783  0.019013
# 37      QRICH1_MDN1                    Rhabdoid      0.00053 -0.038700
# 38    PLCXD3_PARP11                 Skin Cancer    0.0312087 -0.039361
# 39      MAGEA3_MED7     Colon/Colorectal Cancer    0.0146109 -0.095815
# 40         ZNF3_PBK                 Skin Cancer    0.0111953  0.076689
# 41       GARS_CDHR2     Colon/Colorectal Cancer   0.00415646 -0.042119
# 42       GARS_CDHR2                 Bone Cancer    0.0353848 -0.042119
# 43       SRRD_MORC4                 Skin Cancer    0.0312087 -0.044986
# 44  RFTN1_KRTAP13-4                 Skin Cancer    0.0312087  0.012318

# %%
clank(random_pairs)
# Out:
# {'ARAF_LAMA1': ['SNU16',
#   'EFE184',
#   'OCIAML3',
#   'UACC62',
#   'OCUG1',
#   'UACC62',
#   'UMUC16',
#   'OCUG1',
#   'SKPNDW',
#   'A427',
#   'TTC642',
#   'TUHR14TKB',
#   'HEL9217',
#   'GIMEN',
#   'LN340',
#   'PEA1',
#   'NCIH23',
#   'C99',
#   'MERO82',
#   'K029AX',
#   'PLCPRF5',
#   'TUHR10TKB',
#   'HCC2429',
#   'A673',
#   'PECAPJ15',
#   'NCIH3122',
#   'CCLFPEDS0008T',
#   'OCIMY5',
#   'SKNFI',
#   'RPMI7951',
#   'SLR26',
#   'HT1080',
#   'NP5',
#   'NCIH1915',
#   'K029AX'],
#  'BRIP1_GH1': ['HB1119',
#   'NCIH2882',
#   'SNGM',
#   'NCIH2052',
#   'SCS214',
#   'HT1197',
#   'HUNS1',
#   'TC32',
#   'NOMO1',
#   'HEL9217',
#   'SUDHL4',
#   'UACC62',
#   'EFE184',
#   'UACC62',
#   'NCIH1339',
#   'JR',
#   'MM383',
#   'SNU46',
#   'SKNFI',
#   'KPL1',
#   'EN',
#   'KYSE150',
#   'GCT',
#   'LOVO',
#   'OCIAML2',
#   'SUM159PT',
#   '697',
#   'SNU668',
#   'UMUC16',
#   'CI',
#   'NCIH3122',
#   'SKMEL30',
#   'LPS6',
#   'ABC1',
#   'HCA1'],
#  'DOK5_KRTAP8-1': ['CII',
#   'GIMEN',
#   'MCF7',
#   'DKMG',
#   'SNU16',
#   'LPS6',
#   'BT16',
#   'HEL9217',
#   'SKPNDW',
#   'SG231',
#   'NB1',
#   'RH30',
#   'GIMEN',
#   'CAOV3',
#   'SCC25',
#   'SKMEL30',
#   'UMUC10',
#   'SNU46',
#   'NCIH2126',
#   'SW948',
#   'KYSE270',
#   'SNB75',
#   'HCC1187',
#   'LOVO',
#   'ISHIKAWAHERAKLIO02ER',
#   'C99',
#   'SH10TC',
#   'CW9019',
#   'TUHR10TKB',
#   'DB',
#   'EFM19',
#   'PACADD188',
#   'COGN305',
#   'U2904',
#   'COLO320'],
#  'CYP4F11_EPN1': ['CL11',
#   'SNU626',
#   'SW948',
#   'MOLM13',
#   'CAKI2',
#   'YSCCC',
#   'SUM52PE',
#   'C99',
#   'NCIH82',
#   'KO52',
#   'NB4',
#   'SUPT1',
#   'NB1643',
#   'EOL1',
#   'PC14',
#   'OCIMY5',
#   'KYSE510',
#   'VCAP',
#   'H4',
#   'MCC26',
#   'SH10TC',
#   'NP8',
#   'SNU1076',
#   'HG3',
#   'CHLA266',
#   'NCIH520',
#   'OS252',
#   'SNU478',
#   'TOV112D',
#   'U2OS',
#   'SNU1077',
#   'DU4475',
#   'HEC6',
#   'SW579',
#   'SKRC20'],
#  'PBOV1_TEX9': ['SNU16',
#   'CORL23',
#   'KMRC1',
#   'C75',
#   'UMUC16',
#   'PA1',
#   'BL70',
#   'HSB2',
#   'HCC15',
#   'NCIH1915',
#   'PSN1',
#   'NCIH82',
#   'EMTOKA',
#   '697',
#   'MCF7',
#   'MCF7',
#   'SUIT2',
#   'SW948',
#   'UMUC9',
#   'NCO2',
#   'KYSE520',
#   'MFE319',
#   'HEL9217',
#   'EN',
#   'OCIM2',
#   'JHH4',
#   'EM2',
#   'SNU308',
#   'OVMANA',
#   'CAKI1',
#   'LP1',
#   'JHH7',
#   'COGN305',
#   'WM1799',
#   'TC138'],
#  'ACOX3_C6orf203': ['SW948',
#   'CORL311',
#   'GIMEN',
#   'ICC3',
#   'CL11',
#   'PA1',
#   'PACADD188',
#   'BL70',
#   'HS695T',
#   'C80',
#   'C8166',
#   'NCIH1693',
#   'SNU46',
#   'UMUC11',
#   'HCC202',
#   'CORL47',
#   'BT12',
#   'ICC2',
#   'SNU46',
#   'BC3C',
#   'MCC13',
#   'C99',
#   'D283MED',
#   'NCIH1703',
#   'EFM19',
#   'GP5D',
#   'C10',
#   'LN18',
#   'HSB2',
#   'SKRC20',
#   'UCH2',
#   'UMUC16',
#   'COLO320',
#   'UACC257',
#   'HKA1'],
#  'WIPF3_RUNX1T1': ['SNU626',
#   'INA6',
#   'CAOV3',
#   'KASUMI1',
#   'KO52',
#   'ASPC1',
#   'SNU1033',
#   'IMR32',
#   'ICC2',
#   'CHLA15',
#   'PECAPJ41CLONED2',
#   'DMS53',
#   'UMUC10',
#   'YAMATO',
#   'DB',
#   'CORL47',
#   'COLO320',
#   'RERFLCAD2',
#   'SNU16',
#   'SUM149PT',
#   'SCS214',
#   'H357',
#   'PA1',
#   'SHP77',
#   'BICR78',
#   'SKMM2',
#   'DETROIT562',
#   'NCIH2122',
#   'SW948',
#   'PACADD188',
#   'SNU869',
#   'HSB2',
#   'KPNYN',
#   'GSS',
#   'MM383'],
#  'SGCZ_TNFAIP8L2': ['SNU46',
#   'SW948',
#   'KASUMI1',
#   'NCIH2052',
#   'LS',
#   'NCIH2126',
#   'NP5',
#   'WM88',
#   'SW948',
#   'HSB2',
#   'KO52',
#   'NCIH3122',
#   'SKRC20',
#   'GIMEN',
#   'OS252',
#   'KE97',
#   'PEA1',
#   'RCC10RGB',
#   'NCIH1568',
#   'UMUC5',
#   'NP2',
#   'SW982',
#   'JHUEM1',
#   'CAOV3',
#   'NCIH292',
#   'UMUC9',
#   'NMCG1',
#   'YD15',
#   'BICR78',
#   'OS252',
#   'SUM52PE',
#   '42MGBA',
#   'HCC202',
#   'SKGI',
#   'UMUC10'],
#  'ZNF668_RAMP1': ['SW948',
#   'SKNMC',
#   'KLE',
#   'NCIH1573',
#   'KARPAS422',
#   'DETROIT562',
#   'SHI1',
#   'OCIAML3',
#   'CME1',
#   'LP1',
#   'UMUC7',
#   'ICC12',
#   'NP8',
#   'HCC38',
#   'KLE',
#   'LOVO',
#   'SUM149PT',
#   'VCAP',
#   'CL11',
#   'SKMEL19',
#   'EJM',
#   'A427',
#   'G401',
#   'DKMG',
#   'HCC202',
#   'SH10TC',
#   'H357',
#   'SG231',
#   'LCLC97TM1',
#   'NP5',
#   'SUM229PE',
#   'NCIH2882',
#   'H357',
#   'CCK81',
#   'CHAGOK1'],
#  'METTL27_HIST1H2AH': ['PACADD188',
#   'HSB2',
#   'KO52',
#   'SNU668',
#   'SKNFI',
#   'MC116',
#   'BICR16',
#   'UMUC7',
#   'GIMEN',
#   'HT3',
#   'RH18DM',
#   'SNU16',
#   'LS',
#   'NCIH2887',
#   'HCC38',
#   'BICR78',
#   'CAKI1',
#   'CII',
#   'K029AX',
#   'CAKI1',
#   'G402',
#   'HUO9',
#   'SKNEP1',
#   'RH18DM',
#   'MEL285',
#   'HT144',
#   'HSC3',
#   'KYSE520',
#   'TTC642',
#   'MKN45',
#   'CL11',
#   'HOP62',
#   'SUM159PT',
#   'BT16',
#   'EMTOKA'],
#  'FIGNL1_RAB40B': ['LCLC97TM1',
#   'PACADD188',
#   'COLO800',
#   'HSB2',
#   'F36P',
#   'NCIH2882',
#   'PK1',
#   'COGN305',
#   'CME1',
#   'CII',
#   'JHUEM7',
#   '59M',
#   'MONOMAC1',
#   'NCIH446',
#   'MDAMB453',
#   'CAOV3',
#   'C32',
#   'TC71',
#   'MELHO',
#   'OCIMY5',
#   'SIMA',
#   'EM2',
#   'SW48',
#   'NB1643',
#   'JR',
#   'SNU1079',
#   'SUM149PT',
#   'NCIH522',
#   'LN340',
#   'RH28',
#   'SCMCRM2',
#   'SCMCRM2',
#   'CHLA15',
#   'CAL12T',
#   'CHP212'],
#  'LAMC3_KCTD11': ['SW948',
#   'NCIH841',
#   'BICR16',
#   'BT549',
#   'C10',
#   'SKPNDW',
#   'PACADD188',
#   'HCC38',
#   'SNU626',
#   'SNU478',
#   'NCO2',
#   'SNU685',
#   'K562',
#   'LS180',
#   'CAL72',
#   'NCIH2887',
#   'CCLFPEDS0003T',
#   'A427',
#   'SNU626',
#   'D425',
#   'SKUT1',
#   'BL70',
#   'HKA1',
#   'HEC6',
#   'DETROIT562',
#   'KYO1',
#   'DU4475',
#   'NB1643',
#   'KNS60',
#   'NCIH1092',
#   'NCIH460',
#   'MELHO',
#   'UMUC11',
#   'HEL9217',
#   'OUMS23'],
#  'YBX3_GLYATL3': ['HSB2',
#   'UMUC16',
#   'SEKI',
#   'CAOV3',
#   'OCUG1',
#   'BL70',
#   'CAKI2',
#   'MONOMAC1',
#   'SCS214',
#   'SCMCRM2',
#   'NCIH1792',
#   'OCIAML3',
#   'EFE184',
#   'PA1',
#   'SKNEP1',
#   'SW579',
#   'NCIH82',
#   'CALU1',
#   'HCC1187',
#   'NCIN87',
#   'SUM149PT',
#   'SUPT1',
#   'WM115',
#   'KYSE150',
#   'BICR78',
#   'SNU449',
#   'KMS34',
#   'LN235',
#   'KU812',
#   'GIMEN',
#   'SNU626',
#   'SKMEL2',
#   'SKHEP1',
#   'CAL120',
#   'KMS26'],
#  'MFSD5_ATRAID': ['SW948',
#   'SW403',
#   'DKMG',
#   'CAS1',
#   'BT16',
#   'PACADD188',
#   'CCLFPEDS0003T',
#   '95T1000',
#   'RCC10RGB',
#   'ICC3',
#   'K029AX',
#   '42MGBA',
#   'CL11',
#   'SKRC20',
#   'JM1',
#   'SKES1',
#   'MELHO',
#   'SKMEL19',
#   '8MGBA',
#   'KPNYN',
#   'EN',
#   'LPS141',
#   'H4',
#   'NCIH647',
#   'PEA1',
#   'RCC10RGB',
#   'UOK101',
#   'SKPNDW',
#   'SCMCRM2',
#   'U87MG',
#   'UACC62',
#   'C99',
#   'UACC62',
#   'RH30',
#   'TTC642'],
#  'LIN9_ACSL5': ['SNU16',
#   'BL70',
#   'NCIH647',
#   'SNU626',
#   'HSB2',
#   'HCC1187',
#   'RH18DM',
#   'SNU1544',
#   'HUO9',
#   'CHLA57',
#   'NMCG1',
#   'TE5',
#   'NCIH2887',
#   'HT1197',
#   'COLO678',
#   'SKNFI',
#   'GP5D',
#   'VCAP',
#   'VMRCRCW',
#   'CH157MN',
#   'YD38',
#   'DETROIT562',
#   'NCIH82',
#   'SW982',
#   'UMUC16',
#   'SH10TC',
#   'KYO1',
#   'UMUC16',
#   'SG231',
#   'HCC366',
#   'CORL47',
#   'SNU1066',
#   'LAN2',
#   'D283MED',
#   'HS746T'],
#  'TSPAN31_XKR9': ['HS695T',
#   'CHLA57',
#   'GIMEN',
#   'HS939T',
#   'HMY1',
#   'SNU46',
#   'RERFLCAD2',
#   'C10',
#   'NGP',
#   'G401',
#   'UACC62',
#   'CII',
#   'UACC62',
#   'SKGI',
#   'A375',
#   'CAL120',
#   'A375',
#   'NCIH1792',
#   'A375',
#   'LS',
#   'A375',
#   'HT144',
#   'SH10TC',
#   'RH18DM',
#   'HEC1',
#   'MSTO211H',
#   'KMS34',
#   'KYO1',
#   'LS',
#   'LN235',
#   'COLO679',
#   'NCIH23',
#   'SNU626',
#   'PATU8902',
#   'NCIH2110'],
#  'TFAP2D_ALAS1': ['SNU626',
#   'CORL311',
#   'HGC27',
#   'GIMEN',
#   'RH18DM',
#   'THP1',
#   'PATU8902',
#   'RKO',
#   'NCIH1573',
#   'NCIH1092',
#   'KYSE510',
#   'SEM',
#   'HEC50B',
#   'A3KAW',
#   'U937',
#   'NCIH1568',
#   'REH',
#   'PA1',
#   'PC14',
#   'EM2',
#   'SUPM2',
#   'KO52',
#   'RERFLCAD2',
#   'KMCH1',
#   'SU8686',
#   'PF382',
#   'BT16',
#   'NCIH1793',
#   'TFK1',
#   'SCMCRM2',
#   'SNU638',
#   'SKBR3',
#   'KARPAS422',
#   'CME1',
#   'NCIH716'],
#  'HIST1H2AD_KNSTRN': ['HSB2',
#   'YAMATO',
#   'NCIH2887',
#   'TC71',
#   'HCC38',
#   'UMUC16',
#   'C8166',
#   'UHO1',
#   'SNU1544',
#   'MONOMAC1',
#   'VCAP',
#   'BL70',
#   'U87MG',
#   'SNU410',
#   'KMS11',
#   'KURAMOCHI',
#   'CHAGOK1',
#   'TTC642',
#   'KO52',
#   '253J',
#   'NCIN87',
#   'MKN45',
#   'RH18DM',
#   'SKNFI',
#   'UMUC9',
#   'CAKI1',
#   'CAL78',
#   'D425',
#   'SNU46',
#   'UMUC7',
#   'CORL279',
#   'EM2',
#   'HEC265',
#   'TUHR10TKB',
#   'HEC251'],
#  'SLC17A9_TIMM21': ['C80',
#   'BL70',
#   'RVH421',
#   'KO52',
#   'KARPAS422',
#   'PA1',
#   'CAL72',
#   'HG3',
#   'SKMEL30',
#   'OCIC5X',
#   'HS939T',
#   'HT1197',
#   'OVMANA',
#   'SNU46',
#   'NCIH2052',
#   'LN319',
#   'SNU1033',
#   'HEL9217',
#   'OV7',
#   'OCUG1',
#   'TUHR4TKB',
#   'CORL311',
#   'CAKI1',
#   'AMO1',
#   'MONOMAC1',
#   'SKMEL19',
#   'NCIH526',
#   'NALM6',
#   'CCLFPEDS0008T',
#   'GSS',
#   'NCIH1703',
#   'JM1',
#   'MFE319',
#   'SG231',
#   'LK2'],
#  'RFX3_APOA4': ['PACADD188',
#   'KO52',
#   'BT16',
#   'SNU626',
#   'KYO1',
#   'GIMEN',
#   '697',
#   'ICC3',
#   'RH18DM',
#   'CII',
#   'JM1',
#   'HCC1954',
#   'BICR16',
#   'HDMYZ',
#   'COGN305',
#   'EFE184',
#   'SMSCTR',
#   'F5',
#   'TTC642',
#   'TTC642',
#   'OCUM1',
#   'UMUC5',
#   'SUM52PE',
#   'TUHR10TKB',
#   'HCC38',
#   'KNS60',
#   'KU812',
#   'PEA1',
#   'BOKU',
#   'INA6',
#   'BICR78',
#   'SNU423',
#   'NMCG1',
#   'BL70',
#   'C8166'],
#  'ANKRD29_ALG10': ['MSTO211H',
#   'SNU16',
#   'OCUG1',
#   'PACADD188',
#   'WM115',
#   'MKN45',
#   'PA1',
#   'GIMEN',
#   'SKHEP1',
#   'KASUMI1',
#   'SCCOHT1',
#   'HEC1',
#   'SNU668',
#   'YD15',
#   'OUMS23',
#   'OCIAML3',
#   'NCIH2087',
#   'CAMA1',
#   'ICC2',
#   'SHP77',
#   'KKU100',
#   'UOK101',
#   'RPMI8226',
#   'ISTMES2',
#   'FTC133',
#   'SF539',
#   'CCLFPEDS0003T',
#   'SKHEP1',
#   'LPS853',
#   'SMZ1',
#   'LU99',
#   'KKU100',
#   'HMY1',
#   'EMTOKA',
#   'MDAMB157'],
#  'H2BFM_ACSF2': ['EFE184',
#   'SW579',
#   'ASPC1',
#   'CAS1',
#   'H357',
#   'GIMEN',
#   'HSB2',
#   'NB1643',
#   'OS252',
#   'CCLFPEDS0001T',
#   'CCK81',
#   'U343',
#   'C8166',
#   'G402',
#   'EFM19',
#   'ACCMESO1',
#   'HCC2935',
#   'CAL27',
#   'CAKI1',
#   'CAKI2',
#   'T24',
#   'SNU16',
#   'ICC3',
#   'NP5',
#   'HG3',
#   'G401',
#   'A375',
#   'WM88',
#   'OCIMY5',
#   'A375',
#   'MHHNB11',
#   'A375',
#   'SNU738',
#   'A375',
#   'TE4'],
#  'ATP11C_CPOX': ['LAN2',
#   'JHUEM1',
#   'BICR78',
#   'UMUC16',
#   'BL70',
#   'OCUG1',
#   'D425',
#   'HT',
#   'HSB2',
#   'RH18DM',
#   'SNU1033',
#   'HSB2',
#   'CAS1',
#   'HEC1',
#   'MC116',
#   'YAMATO',
#   'U2904',
#   'HCC1419',
#   'HEC59',
#   'SW948',
#   'MONOMAC1',
#   'SNU886',
#   'SKMEL30',
#   'PF382',
#   'UACC257',
#   'SUDHL4',
#   'NCIH647',
#   'NCIH82',
#   'NCIH1092',
#   'TCCSUP',
#   'TC71',
#   'NCIH522',
#   'OPM2',
#   'RH30',
#   'CCLP1'],
#  'CCAR1_TIGD3': ['EPLC272H',
#   'CORL23',
#   'IGR1',
#   'CL11',
#   'UMUC10',
#   'MONOMAC1',
#   'CCLFPEDS0008T',
#   'BICR16',
#   'SKHEP1',
#   'S117',
#   'KNS60',
#   'SNU626',
#   'RH28',
#   'TO14',
#   'RH18DM',
#   'BICR6',
#   'KYSE520',
#   'HUH6',
#   'TE4',
#   'SNU16',
#   'BL70',
#   'HS683',
#   'JMSU1',
#   'LCLC97TM1',
#   'SHP77',
#   'KNS60',
#   'NCIH2286',
#   'ICC2',
#   'A388',
#   'NCIH1568',
#   'OCIC5X',
#   'KKU213',
#   'TOV112D',
#   'S117',
#   'BICR6'],
#  'SNX1_PNPLA6': ['ICC2',
#   'OCIC5X',
#   'HSB2',
#   'NCIH1694',
#   'JHH2',
#   'BICR16',
#   'SNU626',
#   'SNU201',
#   'BICR78',
#   'MELHO',
#   'SUM52PE',
#   'NCIH82',
#   'HS939T',
#   'ONDA8',
#   'NCIH2110',
#   'CORL23',
#   'AMO1',
#   'NCIH3122',
#   'CL11',
#   'MSTO211H',
#   'MCC26',
#   'UMUC9',
#   'PATU8988S',
#   'CCLFPEDS0003T',
#   'SKNFI',
#   'C99',
#   'HCC44',
#   'JHH2',
#   'OS252',
#   'CCK81',
#   'EJM',
#   'MERO82',
#   'YH13',
#   'SNU46',
#   'MPP89'],
#  'ITIH1_MYL3': ['GIMEN',
#   'SNU16',
#   'LS',
#   'SUIT2',
#   'RH18DM',
#   'PACADD161',
#   'UMUC9',
#   'PA1',
#   'NCIN87',
#   'KARPAS422',
#   'CAS1',
#   'CCLFPEDS0003T',
#   'OCIAML3',
#   'U87MG',
#   'KU812',
#   'GSS',
#   'OCIMY7',
#   'EFE184',
#   'MCC142',
#   'MM370',
#   'KP2',
#   'CHLA57',
#   'RAJI',
#   'OCUG1',
#   'SW1463',
#   'DETROIT562',
#   'G292CLONEA141B1',
#   'RPMI8226',
#   'BL70',
#   'MELJUSO',
#   'NCIH2052',
#   'KKU100',
#   'HEL9217',
#   'CAKI1',
#   'MELHO'],
#  'C11orf74_BACE2': ['KO52',
#   'EFE184',
#   'KARPAS422',
#   'SW403',
#   'CL11',
#   'JHH2',
#   'TC138',
#   'SKPNDW',
#   'COV318',
#   'CORL23',
#   'SNU626',
#   'U2904',
#   'SKNMC',
#   'HDMYZ',
#   'KMS34',
#   'BICR78',
#   'SNU668',
#   'OVMANA',
#   'NCIH647',
#   'MELHO',
#   'K029AX',
#   'HUO9',
#   'S117',
#   'NMCG1',
#   'FLO1',
#   'NCIH292',
#   'GP5D',
#   'OCIMY5',
#   'TOV112D',
#   'UACC62',
#   'A673',
#   'UACC62',
#   'HSB2',
#   'T24',
#   'WM88'],
#  'PAOX_OR6C70': ['UMUC16',
#   'KNS42',
#   'LN340',
#   'KO52',
#   'SNU626',
#   'HG3',
#   'PSN1',
#   'SNU16',
#   'KO52',
#   'NCIH2052',
#   'NB1',
#   'NCIH1573',
#   'KMCH1',
#   'CL11',
#   'HUO9',
#   'C8166',
#   'ECC2',
#   'PACADD161',
#   'GSS',
#   'C75',
#   'SNU423',
#   'CAMA1',
#   'SNU1079',
#   'HT55',
#   'JM1',
#   'SW403',
#   'MCF7',
#   'ICC12',
#   'NCIH727',
#   'L33',
#   'T84',
#   'NCIN87',
#   'IMR32',
#   'UOK101',
#   'KYSE520'],
#  'CLPB_DSEL': ['HT',
#   'KO52',
#   'TFK1',
#   'SNU1079',
#   'SNU16',
#   'BL70',
#   'PECAPJ34CLONEC12',
#   'NCIH2882',
#   'OCIM2',
#   'EN',
#   'SKPNDW',
#   'TE5',
#   'HCC1143',
#   'LAN2',
#   'SNU46',
#   'TE11',
#   'BICR78',
#   'HUH7',
#   'NCIH647',
#   'MDAMB415',
#   'KMS20',
#   'JAR',
#   'HSC3',
#   'NCIH841',
#   'KIJK',
#   'LMSU',
#   'SUPM2',
#   'SW948',
#   'HDMYZ',
#   'RH30',
#   'SKPNDW',
#   'UMUC9',
#   'NCIH2887',
#   'REH',
#   'SW403'],
#  'RUNX2_SNAPC5': ['NP5',
#   'DB',
#   'JR',
#   'EJM',
#   'KMS11',
#   'UCH2',
#   'MONOMAC1',
#   'HSC5',
#   'T98G',
#   'RH18DM',
#   'DEL',
#   'KMS20',
#   'GI1',
#   'SW948',
#   'S117',
#   'HUO9',
#   'NCIH82',
#   'HB1119',
#   'HEC59',
#   'OCIMY5',
#   'SUPT1',
#   'SAOS2',
#   'OCIAML3',
#   'MDAMB415',
#   'RH30',
#   'RDES',
#   'LP1',
#   'CCFSTTG1',
#   'UMUC9',
#   'THP1',
#   'MM1S',
#   'HCC38',
#   'NB4',
#   'CW9019',
#   'HCC15'],
#  'SLC9A3R1_RASSF6': ['VMRCRCW',
#   'GIMEN',
#   'NCIH2887',
#   'SUM52PE',
#   'SW948',
#   'SW948',
#   'PACADD188',
#   'UMUC9',
#   'TTC642',
#   'HT1197',
#   'BICR16',
#   'MM370',
#   'NCIH3122',
#   'KMS20',
#   'HS939T',
#   'HSB2',
#   'MELHO',
#   'KYSE150',
#   'CORL47',
#   'NB1643',
#   'HOP62',
#   'CAKI1',
#   'D425',
#   'EFE184',
#   'KYO1',
#   'WM1799',
#   'DKMG',
#   'SNU1079',
#   'MERO14',
#   'SUM149PT',
#   'KASUMI1',
#   'KU812',
#   'EN',
#   'C2BBE1',
#   'MHHNB11'],
#  'NUGGC_CXCL8': ['CORL47',
#   'SKPNDW',
#   'SW948',
#   'CAKI1',
#   'UMUC9',
#   'MCF7',
#   'LN340',
#   'DETROIT562',
#   'LP1',
#   'EN',
#   'CORL279',
#   'KNS42',
#   'HSB2',
#   'LAN2',
#   'HCC1187',
#   'SNU46',
#   'NCIH2882',
#   'KNS42',
#   'MERO82',
#   'KPNYN',
#   'MKN45',
#   'C99',
#   'C32',
#   'L33',
#   'SUM52PE',
#   'KMS34',
#   'AML193',
#   'CORL279',
#   'SYO1',
#   'NUGC3',
#   'RT11284',
#   'COV362',
#   'JHUEM1',
#   'SEKI',
#   'UCH2'],
#  'KRTAP19-5_RAB8B': ['SKMEL30',
#   'VCAP',
#   'SW948',
#   'NCIH1573',
#   'PEA1',
#   'OVMANA',
#   'SKES1',
#   'NB1643',
#   'NCIH3122',
#   'CORL47',
#   'HGC27',
#   'SUM52PE',
#   'CFPAC1',
#   'HCC95',
#   'RPMI8226',
#   'CORL47',
#   'ASPC1',
#   'KYO1',
#   'KYSE150',
#   'NB4',
#   'COGN278',
#   'C32',
#   'SKHEP1',
#   'U2904',
#   'LAN2',
#   'LN340',
#   'D425',
#   'NB1',
#   'SEM',
#   '253J',
#   'LAN2',
#   'A375',
#   'SNU16',
#   'A375',
#   'JHH2'],
#  'LIM2_IRAK4': ['SW948',
#   'PACADD188',
#   'U87MG',
#   'LPS853',
#   'SNU886',
#   'OCIAML3',
#   'EFE184',
#   'COV362',
#   'JHUEM7',
#   'HT144',
#   'K029AX',
#   'NCIH647',
#   'MM383',
#   'HEC1',
#   'KPNYN',
#   'TC32',
#   'CAL12T',
#   'SNU16',
#   'HS683',
#   'OCUM1',
#   'SKMEL30',
#   'NCIH2122',
#   'D283MED',
#   'OCIMY7',
#   'ICC2',
#   '8305C',
#   'SNU668',
#   'C33A',
#   'HCC1937',
#   'HT115',
#   'EFE184',
#   'SKGT2',
#   'SUM149PT',
#   'C10',
#   'MORCPR'],
#  'CHRDL1_SH2D1B': ['MONOMAC1',
#   'VMRCRCW',
#   'BL70',
#   'GIMEN',
#   'CII',
#   'OCIM2',
#   'SNU1544',
#   'NCIH446',
#   'C80',
#   'H357',
#   'NP5',
#   'KO52',
#   'A375',
#   'KMS34',
#   'CL11',
#   'A375',
#   'NP5',
#   'A375',
#   'SNU626',
#   'A375',
#   'SMZ1',
#   'HMY1',
#   'MYLA',
#   'KMS20',
#   'C75',
#   'PECAPJ41CLONED2',
#   'HARA',
#   'CORL47',
#   'JR',
#   'HCC515',
#   'UWB1289',
#   'PSN1',
#   'NMCG1',
#   'HCC1187',
#   'OCUG1'],
#  'VAPB_C1QTNF2': ['KPL1',
#   'MKN45',
#   'SKBR3',
#   'OCUG1',
#   'MCF7',
#   'SKNMC',
#   'HS695T',
#   'NCIH1573',
#   'U2904',
#   'SNU16',
#   'HT55',
#   'MELHO',
#   'OVMANA',
#   'CORL47',
#   'OCIC5X',
#   'KKU100',
#   'JHH4',
#   'HCC1419',
#   '42MGBA',
#   'CAL72',
#   'SKMEL30',
#   'NCIH520',
#   'HS939T',
#   '59M',
#   'G401',
#   'OCIMY7',
#   'KELLY',
#   'IGR39',
#   'SKRC20',
#   'NCIH1573',
#   'KNS42',
#   'NCIH292',
#   'SNU182',
#   'NCIN87',
#   'SNU478'],
#  'HIST1H2BF_CD8A': ['HSB2',
#   'PA1',
#   'U2904',
#   'KASUMI1',
#   'JM1',
#   'LCLC97TM1',
#   'C8166',
#   'MCF7',
#   'MM1S',
#   '8MGBA',
#   'KYSE510',
#   'EJM',
#   'NOMO1',
#   'UMUC9',
#   'KE97',
#   'UMUC16',
#   'MONOMAC1',
#   'SNU46',
#   'MV411',
#   'HCA1',
#   'DU4475',
#   'JHH2',
#   '697',
#   'TC138',
#   '253J',
#   'OCUG1',
#   'TUHR14TKB',
#   'UMUC6',
#   'KPNYN',
#   'KURAMOCHI',
#   'WM983B',
#   'MM370',
#   'CCLFPEDS0003T',
#   'WM983B',
#   'HEL9217'],
#  'EPHB3_TDRD5': ['SNU626',
#   'SNU16',
#   'KASUMI1',
#   'BICR16',
#   'RH18DM',
#   'A388',
#   'INA6',
#   'RVH421',
#   'OCUG1',
#   'SG231',
#   'NMCG1',
#   'BL70',
#   'SNU16',
#   'MB1',
#   'A375',
#   'HCC44',
#   'A375',
#   'ICC12',
#   'A375',
#   'SKN',
#   'A375',
#   'EBC1',
#   'KYSE70',
#   'K029AX',
#   'NCIH2882',
#   'KMS20',
#   'NCIH526',
#   'UMUC16',
#   'C75',
#   'HUO9',
#   'EMTOKA',
#   'OVMANA',
#   'SNU1033',
#   'HDMYZ',
#   'KU812'],
#  'GH1_PERP': ['NCIH2882',
#   'SNU626',
#   'NCIH2052',
#   'SKES1',
#   'HT1197',
#   'NCIH2882',
#   'TC32',
#   'NCIH1573',
#   'HEL9217',
#   'SCABER',
#   'UACC62',
#   'HCC2429',
#   'UACC62',
#   'SEM',
#   'KASUMI1',
#   'NCIH1339',
#   'OCUM1',
#   'MM383',
#   'PANC1005',
#   'SKNFI',
#   'VCAP',
#   'EN',
#   'LOVO',
#   'MSTO211H',
#   'SUM159PT',
#   'EJM',
#   'SNU668',
#   'HG3',
#   'INA6',
#   'UMUC16',
#   'MCC26',
#   'NCIH3122',
#   'MCF7',
#   'LPS6',
#   'KO52'],
#  'RAB40B_PEA15': ['PACADD188',
#   'C32',
#   'HSB2',
#   'SKMEL24',
#   'NCIH2882',
#   'COLO679',
#   'COGN305',
#   'WM793',
#   'CII',
#   'WM1799',
#   '59M',
#   'NMCG1',
#   'NCIH446',
#   'A375',
#   'A375',
#   'MDAMB453',
#   'A375',
#   'C32',
#   'A375',
#   'MELHO',
#   'MM383',
#   'SIMA',
#   'NB1643',
#   'RVH421',
#   'SNU1079',
#   'HMY1',
#   'NCIH522',
#   'GIMEN',
#   'WM983B',
#   'LN340',
#   'K029AX',
#   'SCMCRM2',
#   'COLO800',
#   'CHLA15',
#   'SNU626']}

# %%
top_cellines_random_pairs = {}
# the random pairs are not really random. select really random stuff from all 18000 genes. and if something that is known or in our set is present, don't consider it random. 
for _ in random_pairs:
    a,b = _
    a_list = sangerdict[a].index.to_list()
    a_df = pd.DataFrame(a_list)

    b_list = sangerdict[b].index.to_list()
    b_df = pd.DataFrame(b_list)
    
# this needs to be reviewed in detail
    ranked_index = {}
    for _ in a_df.index:
        for j in b_df.index:
            ranked_index[a_df.values[_][0] + '_' + b_df.values[j][0]] = _ + j

# WHAT IS GOING ON HERE? 
    dataX = [v for v in sorted(ranked_index.items(), key=lambda item: item[1])]
    ceL = [ x for x in range(0,500) for x in dataX[x][0].split('_')]
    ceL = set(ceL)
    ceL = list(ceL)
    top_cellines_random_pairs[a + '_' + b] = ceL
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-c29e10025245> in <module>
#       3 for _ in random_pairs:
#       4     a,b = _
# ----> 5     a_list = sangerdict[a].index.to_list()
#       6     a_df = pd.DataFrame(a_list)
#       7
#
# KeyError: 'MKN45'

# %%
for j in top_cellines_random_pairs.keys():
    temp = get_prd(top_cellines_random_pairs[j])
    temp = temp['primary_disease'].value_counts()
    print(j)
    for _ in range(10):
        value_count = temp[_]
        dissease = temp.index[_]
        if get_hypergeometric_p_value(value_count,764,total_occurence(dissease),len(top_cellines_random_pairs[j])) < 0.07:
            print(dissease)
            print(get_hypergeometric_p_value(value_count,764,total_occurence(dissease),len(top_cellines_random_pairs[j])))
    print('\n')

# %%
import seaborn as sns
dataz = allGenes[['CDK6','CCND3']]

a = top_cellines['CDK6_CCND3'][0:20]

datay = dataz.index.isin(a)

datay = dataz[datay]
g = sns.clustermap(datay,row_colors=primDis['primary_disease'])
g.savefig('/home/annerer/Dokumente/clustermap_CDK6_CCND3')
g.ax_heatmap.set_xlabel('Driver Genes')
g.ax_heatmap.set_ylabel('Celllines')

#primlist= primDis['primary_disease'].to_list()
lut = dict(zip(pd.unique(top_cellines['CDK6_CCND3']), "rgb"))

row_colors = row_cols.map(lut)

g = sns.clustermap(datay, row_colors=row_colors)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-576-52132b4e8713> in <module>
#       8 datay = dataz[datay]
#       9 g = sns.clustermap(datay,row_colors=primDis['primary_disease'])
# ---> 10 g.savefig('/home/annerer/Dokumente/clustermap_CDK6_CCND3')
#      11 g.ax_heatmap.set_xlabel('Driver Genes')
#      12 g.ax_heatmap.set_ylabel('Celllines')
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in savefig(self, *args, **kwargs)
#    1043         if 'bbox_inches' not in kwargs:
#    1044             kwargs['bbox_inches'] = 'tight'
# -> 1045         self.fig.savefig(*args, **kwargs)
#    1046
#    1047     def plot_dendrograms(self, row_cluster, col_cluster, metric, method,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/annerer/Dokumente/clustermap_CDK6_CCND3.png'

# %%
datay = dataz.index.isin(a)
datay = dataz[datay]

# %%
prd_list = datay.index.to_list()
primDis = get_prd(prd_list)

# %%
primDis
# Out:
#               primary_disease
# 4                    Leukemia
# 23                    Myeloma
# 40                Bone Cancer
# 81                Bone Cancer
# 114           Prostate Cancer
# ...                       ...
# 1394                  Sarcoma
# 1402  Colon/Colorectal Cancer
# 1430         Bile Duct Cancer
# 1460               Eye Cancer
# 1605              Bone Cancer
#
# [63 rows x 1 columns]

# %% [markdown]
# # stats

# %%
def get_hypergeometric_p_value(count,totalCount,N,sample_size):
    count = count - 1
    pval = hypergeom.sf(count, totalCount, N,sample_size)
 #  (x-1,783,totalhits,20)
    return pval

# %%
data[data['primary_disease'] == 'Bone Cancer']
# Out:
#        DepMap_ID stripped_cell_line_name        CCLE_Name  \
# 38    ACH-000039                   SKNMC            SKNMC
# 40    ACH-000041                    RDES             RDES
# 51    ACH-000052                    A673             A673
# 81    ACH-000082         G292CLONEA141B1  G292CLONEA141B1
# 86    ACH-000087                   SKES1            SKES1
# 278   ACH-000279                  EWS502           EWS502
# 363   ACH-000364                    U2OS             U2OS
# 409   ACH-000410                   SAOS2            SAOS2
# 423   ACH-000424                    TC71             TC71
# 496   ACH-000499                     EW8              EW8
# 513   ACH-000516                   CAL78            CAL78
# 745   ACH-000748                   SJSA1            SJSA1
# 998   ACH-001001                    143B             143B
# 1019  ACH-001033                  CHLA57           CHLA57
# 1024  ACH-001038                 COGE352          COGE352
# 1118  ACH-001192                  SKNEP1           SKNEP1
# 1119  ACH-001193                  SKPNDW           SKPNDW
# 1128  ACH-001205                    TC32             TC32
# 1156  ACH-001283                   TC106            TC106
# 1247  ACH-001430                   TC138            TC138
# 1248  ACH-001431                   TC205            TC205
# 1289  ACH-001526                    HUO9             HUO9
# 1387  ACH-001715                   CAL72            CAL72
# 1413  ACH-001814                   OS252            OS252
# 1442  ACH-001955                    JHC7             JHC7
# 1443  ACH-001956                MUGCHOR1         MUGCHOR1
# 1444  ACH-001957                 UMCHOR1          UMCHOR1
# 1605  ACH-002204                    UCH2             UCH2
#
#                                     Alias   COSMICID      sex  \
# 38                                    NaN        NaN   Female
# 40                                    NaN        NaN     Male
# 51                                    NaN   684052.0   Female
# 81    G292CLONEA141B1, G-292 clone A141B1  1290807.0   Female
# 86                                    NaN   684072.0     Male
# 278                                   NaN        NaN  Unknown
# 363                         U2-OS, U-2 OS   909776.0   Female
# 409                                   NaN   909707.0   Female
# 423                                   NaN  1240221.0     Male
# 496                                   NaN        NaN     Male
# 513                                   NaN  1290765.0     Male
# 745                                   NaN   909717.0     Male
# 998                                   NaN        NaN   Female
# 1019                                  NaN        NaN  Unknown
# 1024                            COG-E-352        NaN     Male
# 1118                               HTB-48        NaN   Female
# 1119                                  NaN   909731.0     Male
# 1128                                  NaN        NaN   Female
# 1156                                  NaN        NaN     Male
# 1247                                  NaN        NaN     Male
# 1248                                  NaN        NaN  Unknown
# 1289                                  NaN   907072.0   Female
# 1387                                  NaN   906827.0     Male
# 1413                                  NaN        NaN  Unknown
# 1442                                  NaN        NaN   Female
# 1443                                  NaN        NaN   Female
# 1444                                  NaN        NaN     Male
# 1605                                  NaN  1503373.0   Female
#
#                          source  Achilles_n_replicates  cell_line_NNMD  \
# 38                         ATCC                    3.0       -2.627972
# 40                         ATCC                    2.0       -2.731637
# 51                         ATCC                    2.0       -2.945665
# 81                         ATCC                    2.0       -4.365854
# 86                         ATCC                    2.0       -3.082132
# 278                Academic lab                    2.0       -4.550668
# 363                        ATCC                    2.0       -3.887180
# 409                        ATCC                    2.0       -5.258975
# 423                        DSMZ                    2.0       -2.405007
# 496                Academic lab                    2.0       -2.872731
# 513                        DSMZ                    2.0       -5.566370
# 745                        ATCC                    1.0       -4.502295
# 998                        ATCC                    1.0       -4.611524
# 1019  Children's Oncology Group                    2.0       -1.960891
# 1024  Children's Oncology Group                    2.0       -5.294465
# 1118               Academic lab                    2.0       -3.319237
# 1119               Academic lab                    2.0       -2.311089
# 1128               Academic lab                    2.0       -2.061526
# 1156               Academic lab                    2.0       -4.224490
# 1247               Academic lab                    2.0       -1.676623
# 1248               Academic lab                    2.0       -2.632445
# 1289                       JCRB                    2.0       -2.929125
# 1387                       DSMZ                    2.0       -2.923916
# 1413               Academic lab                    2.0       -2.174671
# 1442               Academic lab                    2.0       -5.818009
# 1443               Academic lab                    3.0       -5.367905
# 1444               Academic lab                    3.0       -3.687470
# 1605                     Sanger                    3.0       -1.661921
#
#                        culture_type  ... primary_or_metastasis  \
# 38                         Adherent  ...            Metastasis
# 40    Mixed adherent and suspension  ...               Primary
# 51                         Adherent  ...               Primary
# 81                         Adherent  ...               Primary
# 86    Mixed adherent and suspension  ...               Primary
# 278                        Adherent  ...                   NaN
# 363                        Adherent  ...               Primary
# 409                        Adherent  ...               Primary
# 423                        Adherent  ...               Primary
# 496                        Adherent  ...                   NaN
# 513                        Adherent  ...                   NaN
# 745                        Adherent  ...               Primary
# 998                        Adherent  ...               Primary
# 1019                     Suspension  ...                   NaN
# 1024  Mixed adherent and suspension  ...                   NaN
# 1118                     Suspension  ...            Metastasis
# 1119                       Adherent  ...                   NaN
# 1128                       Adherent  ...                   NaN
# 1156                       Adherent  ...            Metastasis
# 1247  Mixed adherent and suspension  ...                   NaN
# 1248                       Adherent  ...                   NaN
# 1289                       Adherent  ...               Primary
# 1387                       Adherent  ...                   NaN
# 1413                       Adherent  ...               Primary
# 1442                       Adherent  ...                   NaN
# 1443                       Adherent  ...                   NaN
# 1444                       Adherent  ...                   NaN
# 1605                       Adherent  ...                   NaN
#
#      primary_disease           Subtype   age Sanger_Model_ID  \
# 38       Bone Cancer    Ewings Sarcoma  14.0       SIDM00634
# 40       Bone Cancer    Ewings Sarcoma  19.0             NaN
# 51       Bone Cancer    Ewings Sarcoma  15.0       SIDM00848
# 81       Bone Cancer      Osteosarcoma   9.0       SIDM00858
# 86       Bone Cancer    Ewings Sarcoma  18.0       SIDM01111
# 278      Bone Cancer    Ewings Sarcoma   NaN             NaN
# 363      Bone Cancer      Osteosarcoma  15.0       SIDM01191
# 409      Bone Cancer      Osteosarcoma  11.0       SIDM01084
# 423      Bone Cancer    Ewings Sarcoma  22.0       SIDM00419
# 496      Bone Cancer    Ewings Sarcoma   NaN             NaN
# 513      Bone Cancer    Chondrosarcoma  76.0       SIDM00929
# 745      Bone Cancer      Osteosarcoma  19.0       SIDM01112
# 998      Bone Cancer      Osteosarcoma  13.0       SIDM00804
# 1019     Bone Cancer    Ewings Sarcoma   NaN             NaN
# 1024     Bone Cancer    Ewings Sarcoma  17.0             NaN
# 1118     Bone Cancer    Ewings Sarcoma   NaN       SIDM00027
# 1119     Bone Cancer    Ewings Sarcoma   NaN       SIDM01097
# 1128     Bone Cancer    Ewings Sarcoma  17.0             NaN
# 1156     Bone Cancer    Ewings Sarcoma  19.0             NaN
# 1247     Bone Cancer    Ewings Sarcoma   NaN             NaN
# 1248     Bone Cancer    Ewings Sarcoma   NaN             NaN
# 1289     Bone Cancer      Osteosarcoma  13.0       SIDM00599
# 1387     Bone Cancer      Osteosarcoma  10.0       SIDM00930
# 1413     Bone Cancer      Osteosarcoma   NaN             NaN
# 1442     Bone Cancer          Chordoma   NaN             NaN
# 1443     Bone Cancer          Chordoma  57.0             NaN
# 1444     Bone Cancer          Chordoma  64.0             NaN
# 1605     Bone Cancer  Chordoma, sacral   NaN       SIDM01185
#
#      depmap_public_comments lineage  lineage_subtype lineage_sub_subtype  \
# 38                      NaN    bone    Ewing_sarcoma                 NaN
# 40                      NaN    bone    Ewing_sarcoma                 NaN
# 51                      NaN    bone    Ewing_sarcoma                 NaN
# 81                      NaN    bone     osteosarcoma                 NaN
# 86                      NaN    bone    Ewing_sarcoma                 NaN
# 278                     NaN    bone    Ewing_sarcoma                 NaN
# 363                     NaN    bone     osteosarcoma                 NaN
# 409                     NaN    bone     osteosarcoma                 NaN
# 423                     NaN    bone    Ewing_sarcoma                 NaN
# 496                     NaN    bone    Ewing_sarcoma                 NaN
# 513                     NaN    bone   chondrosarcoma                 NaN
# 745                     NaN    bone     osteosarcoma                 NaN
# 998                     NaN    bone     osteosarcoma                 NaN
# 1019                    NaN    bone    Ewing_sarcoma                 NaN
# 1024                    NaN    bone    Ewing_sarcoma                 NaN
# 1118                    NaN    bone    Ewing_sarcoma                 NaN
# 1119                    NaN    bone    Ewing_sarcoma                 NaN
# 1128                    NaN    bone    Ewing_sarcoma                 NaN
# 1156                    NaN    bone    Ewing_sarcoma                 NaN
# 1247                    NaN    bone    Ewing_sarcoma                 NaN
# 1248                    NaN    bone    Ewing_sarcoma                 NaN
# 1289                    NaN    bone     osteosarcoma                 NaN
# 1387                    NaN    bone     osteosarcoma                 NaN
# 1413                    NaN    bone     osteosarcoma                 NaN
# 1442                    NaN    bone         chordoma                 NaN
# 1443                    NaN    bone         chordoma                 NaN
# 1444                    NaN    bone         chordoma                 NaN
# 1605                    NaN    bone         chordoma     chordoma_sacral
#
#      lineage_molecular_subtype
# 38                     EWS_FLI
# 40                     EWS_FLI
# 51                     EWS_FLI
# 81                         NaN
# 86                     EWS_FLI
# 278                    EWS_FLI
# 363                        NaN
# 409                        NaN
# 423                        NaN
# 496                    EWS_FLI
# 513                        NaN
# 745                        NaN
# 998                        NaN
# 1019                       NaN
# 1024                   EWS_ERG
# 1118                   EWS_FLI
# 1119                   EWS_FLI
# 1128                   EWS_FLI
# 1156                   EWS_ERG
# 1247                   EWS_FLI
# 1248                   EWS_FEV
# 1289                       NaN
# 1387                       NaN
# 1413                       NaN
# 1442                       NaN
# 1443                       NaN
# 1444                       NaN
# 1605                       NaN
#
# [28 rows x 24 columns]

# %%
get_hypergeometric_p_value(4,764,34,31)
# Out:
# 0.043762439503791044

# %%
data.shape
# Out:
# (1804, 24)

# %%
get_hypergeometric_p_value(5,764,34,31)
# Out:
# 0.008586421714816779

# %%
# check for enrichment if we have only those celllines in data that are actually in DepMap

# %%
depmapgenes = allGenes.index.to_list()
annotatedgenes = data.stripped_cell_line_name.to_list()

len((set(annotatedgenes).intersection(set(depmapgenes))))
# Out:
# 764

# %%
len(annotatedgenes)
# Out:
# 1804

# %%
####### this is needed to get any meaningful statistics!
#####

data = data[data.stripped_cell_line_name.isin(depmapgenes)]

###
####
#####

# %%
data.head()
# Out:
#      DepMap_ID stripped_cell_line_name CCLE_Name Alias  COSMICID   sex source  \
# 3   ACH-000004                     HEL       HEL   NaN  907053.0  Male   DSMZ
# 4   ACH-000005                 HEL9217   HEL9217   NaN       NaN  Male   ATCC
# 6   ACH-000007                   LS513     LS513   NaN  907795.0  Male   ATCC
# 8   ACH-000009                  C2BBE1    C2BBE1   NaN  910700.0  Male   ATCC
# 10  ACH-000011                    253J      253J   NaN       NaN  Male   KCLB
#
#     Achilles_n_replicates  cell_line_NNMD                   culture_type  ...  \
# 3                     2.0       -3.079202                     Suspension  ...
# 4                     2.0       -2.404409  Mixed adherent and suspension  ...
# 6                     2.0       -2.586708                       Adherent  ...
# 8                     3.0       -4.135491                       Adherent  ...
# 10                    1.0       -3.180379                       Adherent  ...
#
#    primary_or_metastasis          primary_disease  \
# 3                    NaN                 Leukemia
# 4                    NaN                 Leukemia
# 6                Primary  Colon/Colorectal Cancer
# 8                Primary  Colon/Colorectal Cancer
# 10            Metastasis           Bladder Cancer
#
#                                               Subtype   age Sanger_Model_ID  \
# 3   Acute Myelogenous Leukemia (AML), M6 (Erythrol...  30.0       SIDM00594
# 4   Acute Myelogenous Leukemia (AML), M6 (Erythrol...  30.0       SIDM00593
# 6                                      Adenocarcinoma  63.0       SIDM00677
# 8                                      Adenocarcinoma  72.0       SIDM01233
# 10                                          Carcinoma  53.0             NaN
#
#    depmap_public_comments        lineage            lineage_subtype  \
# 3                     NaN          blood                        AML
# 4                     NaN          blood                        AML
# 6                     NaN     colorectal  colorectal_adenocarcinoma
# 8                     NaN     colorectal  colorectal_adenocarcinoma
# 10                    NaN  urinary_tract          bladder_carcinoma
#
#    lineage_sub_subtype lineage_molecular_subtype
# 3                   M6                       NaN
# 4                   M6                       NaN
# 6                  NaN                       NaN
# 8                  NaN                       NaN
# 10                 NaN                       NaN
#
# [5 rows x 24 columns]

# %%
def get_prd(pair):
    boolean_series = data.stripped_cell_line_name.isin(pair)
    prd_df = data[boolean_series]['primary_disease']
    #sub_df = data[boolean_series]['lineage_subtype']

    prd = pd.DataFrame(prd_df)
    #sub = pd.DataFrame(sub_df)
    #return [prd,sub]
    return prd

# %%
def get_sub2(pair):
    boolean_series = data.stripped_cell_line_name.isin(pair)
    #prd_df = data[boolean_series]['primary_disease']
    sub_df = data[boolean_series]['lineage_subtype']

    #prd = pd.DataFrame(prd_df)
    sub = pd.DataFrame(sub_df)
    #return [prd,sub]
    return sub

# %% [markdown]
# ## Visualization

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from scipy.stats import pearsonr
import networkx as nx
from scipy.stats import hypergeom

effect = pd.read_csv("/home/annerer/Dokumente/DepMap_Mining/data/Achilles_gene_effect.csv")
data = pd.read_csv("/home/annerer/Dokumente/DepMap_Mining/data/sample_info.csv")
# path changed to laptops

#effect = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/Achilles_gene_effect.csv")
#data = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/sample_info.csv")

mapping = {}

for i in np.arange(0,data.shape[0],1):
    mapping[data.DepMap_ID[i]] = data.CCLE_Name[i]

effect["INDEX"] = effect.DepMap_ID
effect = effect.set_index('INDEX')
effect = effect.rename(index=mapping)
effect = effect.drop("DepMap_ID",1)

gene = effect.columns.to_list()
# split at space
for i in range(len(gene)):
    gene[i] = gene[i].split(" ") 

genes = []
for i in range(len(gene)):
    genes.append(gene[i][0])
                 
effect.columns = genes

cellLine = effect.index.to_list()
# split at space
for i in range(len(cellLine)):
    cellLine[i] = cellLine[i].split("_") 

cellLines = []
for i in range(len(cellLine)):
    cellLines.append(cellLine[i][0])
    
effect.index = cellLines

cellLine = data['CCLE_Name'].to_list()
# split at space
for i in range(len(cellLine)):
    cellLine[i] = cellLine[i].split("_") 

cellLines1 = []
for i in range(len(cellLine)):
    cellLines1.append(cellLine[i][0])
    
data['CCLE_Name'] = cellLines1

a = set(cellLines)
b = set(data["CCLE_Name"])
c = set.intersection(a,b)

print(len(a))
print(len(b))
print(len(c))

cellL = c
allGenes = effect[effect.columns.intersection(cellL)]
# Out:
# 765
# 1781
# 765

# %%
dep = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/Achilles_gene_dependency.csv")
data = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/sample_info.csv")
# path changed to laptops
#effect = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/Achilles_gene_effect.csv")
#data = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/sample_info.csv")
# to contain them.
mapping = {}

for i in np.arange(0,data.shape[0],1):
    mapping[data.DepMap_ID[i]] = data.CCLE_Name[i]

dep["INDEX"] = dep.DepMap_ID
dep = dep.set_index('INDEX')
dep = dep.rename(index=mapping)
dep = dep.drop("DepMap_ID",1)


gene1 = dep.columns.to_list()
# split at space
for i in range(len(gene1)):
    gene1[i] = gene1[i].split(" ") 

genes1 = []
for i in range(len(gene1)):
    genes1.append(gene[i][0])

dep.columns = genes

cellLine1 = dep.index.to_list()
# split at space
for i in range(len(cellLine1)):
    cellLine1[i] = cellLine1[i].split("_") 

cellLines1 = []
for i in range(len(cellLine1)):
    cellLines1.append(cellLine1[i][0])

dep.index = cellLines1

cellLine1 = data['CCLE_Name'].to_list()
# split at space
for i in range(len(cellLine1)):
    cellLine1[i] = cellLine1[i].split("_") 

cellLines1 = []
for i in range(len(cellLine1)):
    cellLines1.append(cellLine1[i][0])
    
data['CCLE_Name'] = cellLines1

a = set(cellLines1)
b = set(data["CCLE_Name"])
c = set.intersection(a,b)

print(len(a))
print(len(b))
print(len(c))

cellL = c

allDep = dep[dep.columns.intersection(cellL)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-517fdf0f81ae> in <module>
# ----> 1 dep = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/Achilles_gene_dependency.csv")
#       2 data = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/sample_info.csv")
#       3 # path changed to laptops
#       4 #effect = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/Achilles_gene_effect.csv")
#       5 #data = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/sample_info.csv")
#
# NameError: name 'pd' is not defined

# %%
#dep = dep.transpose()
#intersect = list(set.intersection(set(allDep.index.to_list()), set(cellL)))
#dep = dep[dep.columns.intersection(cellL)]

#dep.shape
#dep = dep.transpose()

#dep.head()

# %%
effect = effect.transpose()
intersect = list(set.intersection(set(allGenes.index.to_list()), set(cellL)))
allGenes = effect[effect.columns.intersection(cellL)]

allGenes.shape
allGenes = allGenes.transpose()

allGenes.head()
# Out:
#              A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT     A4GNT  \
# HEL      0.178087  0.088290 -0.201464 -0.017011  0.042590 -0.192257  0.352891
# HEL9217 -0.082364  0.239413  0.195457  0.163763 -0.188161 -0.338735  0.254489
# LS513    0.070026  0.075066 -0.064637  0.156905  0.099075  0.141985  0.066314
# C2BBE1   0.107048 -0.006352 -0.053166  0.053055  0.081620 -0.038305  0.082421
# 253J     0.280508  0.079860  0.016981  0.439139 -0.042239 -0.242560  0.103028
#
#              AAAS      AACS     AADAC  ...    ZWILCH     ZWINT      ZXDA  \
# HEL     -0.445209  0.292603  0.165168  ... -0.122795 -0.464567       NaN
# HEL9217 -0.583878 -0.060615  0.015272  ... -0.195061 -0.408063 -0.155155
# LS513   -0.477023 -0.006855  0.291604  ... -0.093252 -0.276874 -0.049716
# C2BBE1  -0.642935  0.159178  0.064128  ... -0.280677 -0.230111 -0.106000
# 253J    -0.419159  0.141445  0.115857  ... -0.410500 -0.507467 -0.138665
#
#              ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
# HEL           NaN  0.258084  0.237593 -0.408563  0.291832  0.218575 -0.139759
# HEL9217 -0.067415  0.229242 -0.075883 -0.104001  0.075901  0.036985 -0.243303
# LS513    0.116683  0.211699 -0.012654 -0.351716  0.089140 -0.392549 -0.442624
# C2BBE1   0.041611  0.083021  0.022771 -0.596777  0.197627 -0.106398 -0.549259
# 253J    -0.119292  0.284407  0.158124 -0.240429  0.124847 -0.250949 -0.379117
#
# [5 rows x 18119 columns]

# %%
data.stripped_cell_line_name.head()
# Out:
# 3         HEL
# 4     HEL9217
# 6       LS513
# 8      C2BBE1
# 10       253J
# Name: stripped_cell_line_name, dtype: object

# %%
def get_prd_and_sub(pair):
    boolean_series = data.stripped_cell_line_name.isin(pair[0])
    prd_df = data[boolean_series]['primary_disease']
    sub_df = data[boolean_series]['lineage_subtype']

    prd = pd.DataFrame(prd_df)
    sub = pd.DataFrame(sub_df)
    return [prd,sub]

# %%
{k:v for k, v in averages.items() if v >= 0.32}
# Out:
# {'ACRV1': 0.3234468280480696,
#  'ACSM2B': 0.32357209523246033,
#  'AKAIN1': 0.3741489872716231,
#  'ARSG': 0.3404548183418292,
#  'ATAD1': 0.4334039619666363,
#  'BIN3': 0.42347642595438606,
#  'C10orf71': 0.3469298612790737,
#  'CACNG7': 0.3698413538582337,
#  'CDKN2C': 0.3359931234850822,
#  'CLEC7A': 0.32017520852080283,
#  'DAB2IP': 0.34587901152320033,
#  'DMRT2': 0.4179531740936098,
#  'EDN3': 0.3348943640512225,
#  'EQTN': 0.400912337523252,
#  'FAM3C': 0.3802633941490323,
#  'FOXD4L4': 0.32076226563498644,
#  'GIMAP4': 0.32866005937100407,
#  'GLYATL2': 0.3647145766482287,
#  'GOLT1A': 0.3236033907578368,
#  'HIST1H4I': 0.3275541979250225,
#  'HLA-DRB5': 0.3458702525245685,
#  'IFNB1': 0.3338825013766949,
#  'IGFL1': 0.4852669289189225,
#  'KLRC3': 0.32443519726244124,
#  'KRTAP4-12': 0.37747638363890185,
#  'MAPK9': 0.38006490026190026,
#  'MGST1': 0.429303806560375,
#  'NCF1': 0.3240924783502524,
#  'NELL1': 0.39450161121803157,
#  'PDCD10': 0.40272427973249386,
#  'POTEE': 0.487484121361694,
#  'PTEN': 0.6571511137118632,
#  'RPP25': 0.32106133640765805,
#  'SCLT1': 0.3207703597039594,
#  'SERPINC1': 0.32611388640956396,
#  'SMCP': 0.43684603087699875,
#  'STEAP1': 0.3243395700981359,
#  'STX17': 0.34792899775793346,
#  'TBC1D19': 0.3736908016717641,
#  'TRHR': 0.35310510405316853,
#  'VAMP5': 0.4054888087736081,
#  'WFDC6': 0.3466713438826658,
#  'ZNF582': 0.36797654709174765,
#  'ZNF611': 0.7318614582232789,
#  'ZNF729': 0.42028572560217725,
#  'ZNF853': 0.33983582758544173}

# %%
TSG_depmap = [k for k, v in averages.items() if v >= -0.32 and v <= 0.32]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1a8237d9fea4> in <module>
# ----> 1 TSG_depmap = [k for k, v in averages.items() if v >= -0.32 and v <= 0.32]
#
# NameError: name 'averages' is not defined

# %%
sang = pd.read_csv("/home/lannwal/Documents/DepMap_Mining/SANGER_CANCER_GENES.csv",sep=',')

# %%
sang.head()
# Out:
#   Gene Symbol                                               Name  \
# 0        A1CF                     APOBEC1 complementation factor
# 1        ABI1                                   abl-interactor 1
# 2        ABL1  v-abl Abelson murine leukemia viral oncogene h...
# 3        ABL2     c-abl oncogene 2, non-receptor tyrosine kinase
# 4       ACKR3                      atypical chemokine receptor 3
#
#    Entrez GeneId        Genome Location  Tier Hallmark  Chr Band Somatic  \
# 0        29974.0   10:50799421-50885675     2      NaN     11.23     yes
# 1        10006.0   10:26746593-26860935     1      Yes     12.10     yes
# 2           25.0  9:130713946-130885683     1      Yes     34.12     yes
# 3           27.0  1:179099327-179229601     1      NaN     25.20     yes
# 4        57007.0  2:236569641-236582358     1      Yes     37.30     yes
#
#   Germline Tumour Types(Somatic) Tumour Types(Germline) Cancer Syndrome  \
# 0      NaN              melanoma                    NaN             NaN
# 1      NaN                   AML                    NaN             NaN
# 2      NaN       CML, ALL, T-ALL                    NaN             NaN
# 3      NaN                   AML                    NaN             NaN
# 4      NaN                lipoma                    NaN             NaN
#
#   Tissue Type Molecular Genetics    Role in Cancer Mutation Types  \
# 0           E                NaN          oncogene            Mis
# 1           L                Dom       TSG, fusion              T
# 2           L                Dom  oncogene, fusion         T, Mis
# 3           L                Dom  oncogene, fusion              T
# 4           M                Dom  oncogene, fusion              T
#
#   Translocation Partner Other Germline Mut Other Syndrome  \
# 0                   NaN                NaN            NaN
# 1                 KMT2A                NaN            NaN
# 2     BCR, ETV6, NUP214                NaN            NaN
# 3                  ETV6                NaN            NaN
# 4                 HMGA2                NaN            NaN
#
#                                             Synonyms
# 0  29974,A1CF,ACF,ACF64,ACF65,APOBEC1CF,ASP,ENSG0...
# 1  10006,ABI-1,ABI1,E3B1,ENSG00000136754.17,Q8IZP...
# 2  25,ABL,ABL1,ENSG00000097007.17,JTK7,P00519,c-A...
# 3         27,ABL2,ABLL,ARG,ENSG00000143322.19,P42684
# 4  57007,ACKR3,CMKOR1,CXCR7,ENSG00000144476.5,GPR...

# %%
TSG_sanger = sang[(sang['Role in Cancer'] == 'TSG')]
TSG_sanger_list = TSG_sanger["Gene Symbol"].to_list()

# %%
ONCO_sanger = sang[(sang['Role in Cancer'] == 'oncogene')]
onco_sanger_list = ONCO_sanger["Gene Symbol"].to_list()

# %%
TSG_sanger.head()
# Out:
#    Gene Symbol                                            Name  Entrez GeneId  \
# 8       ACVR2A                      activin A receptor type 2A           92.0
# 19       AMER1              APC membrane recruitment protein 1       139285.0
# 21         APC         adenomatous polyposis of the colon gene          324.0
# 27    ARHGEF10       Rho guanine nucleotide exchange factor 10         9639.0
# 28   ARHGEF10L  Rho guanine nucleotide exchange factor 10 like        55160.0
#
#           Genome Location  Tier Hallmark  Chr Band Somatic Germline  \
# 8   2:147844517-147930824     1      NaN     23.10     yes      NaN
# 19    X:64185117-64205744     1      Yes     11.20     yes      NaN
# 21  5:112737888-112846239     1      Yes     22.20     yes      yes
# 27      8:1824015-1958641     2      NaN     23.30     yes      NaN
# 28    1:17539835-17697869     2      NaN     36.13     yes      NaN
#
#                                 Tumour Types(Somatic)  \
# 8   large intestine carcinoma, stomach carcinoma, ...
# 19                                       Wilms tumour
# 21  colorectal, pancreatic, desmoid, hepatoblastom...
# 27                                       colon cancer
# 28                                           lymphoma
#
#                                Tumour Types(Germline)  \
# 8                                                 NaN
# 19                                                NaN
# 21  colorectal, pancreatic, desmoid, hepatoblastom...
# 27                                                NaN
# 28                                                NaN
#
#                                 Cancer Syndrome Tissue Type  \
# 8                                           NaN           E
# 19                                          NaN           O
# 21  adenomatous polyposis coli; Turcot syndrome     E, M, O
# 27                                          NaN           E
# 28                                          NaN           L
#
#    Molecular Genetics Role in Cancer   Mutation Types Translocation Partner  \
# 8                 Rec            TSG        Mis, N, F                   NaN
# 19                Rec            TSG     F, D, N, Mis                   NaN
# 21                Rec            TSG  D, Mis, N, F, S                   NaN
# 27                NaN            TSG                D                   NaN
# 28                NaN            TSG                D                   NaN
#
#    Other Germline Mut Other Syndrome  \
# 8                 NaN            NaN
# 19                NaN            NaN
# 21                NaN            NaN
# 27                NaN            NaN
# 28                NaN            NaN
#
#                                              Synonyms
# 8    92,ACTRII,ACVR2,ACVR2A,ENSG00000121989.14,P27037
# 19  139285,AMER1,ENSG00000184675.9,FAM123B,FLJ3982...
# 21  324,APC,DP2,DP2.5,DP3,ENSG00000134982.16,P2505...
# 27  9639,ARHGEF10,ENSG00000104728.15,Gef10,KIAA029...
# 28  55160,ARHGEF10L,ENSG00000074964.16,FLJ10521,KI...

# %% [markdown]
# # TESTING IF THERE IS A BIGGER OVERLAP BETWEEN ONCO AND POSITIVE GENE EFFECTS

# %%
onco_depmap = [k for k, v in averages.items() if v <= 0 and v >= -0.8]
sanger_set = set(onco_sanger_list)
depmap_set = set(onco_depmap)

len(sanger_set.intersection(depmap_set))

# working to get the visualizations from jg-young working
# this should workt
# Out:
# 60

# %% [markdown]
# # PRINT PRIMARY DISEASES

# %%
def print_PRIMARY_DISEASES(clank_lines,number_of_celllines):
    results = {}
    i = 0
    for _ in clank_lines.keys():
        temp = get_prd(clank_lines[_])
        temp = temp['primary_disease'].value_counts()
        print(_)
        for j in range(len(temp)):
            value_count = temp[j]
            dissease = temp.index[j]
            if get_hypergeometric_p_value(value_count,764,total_occurence(dissease),number_of_celllines) < 0.05:
                print(dissease)
                print(get_hypergeometric_p_value(value_count,764,total_occurence(dissease),number_of_celllines))
                results[i] = [_,dissease,get_hypergeometric_p_value(value_count,764,total_occurence(dissease),number_of_celllines)]
                i += 1
        print('\n')
    return results

# %%
allGenes.plot.scatter(x="CDK4", y="CDK6", s=allGenes["CDK4"] * 200)
plt.xlim(0,0.2)
plt.ylim(-0.4,0.3)
# Out:
# (-0.4, 0.3)

# %%
ax = sns.stripplot(x='CDK6', y='CDK4', data=allGenes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1013         try:
# -> 1014             self._set_with_engine(key, value)
#    1015         except com.SettingWithCopyError:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1053         try:
# -> 1054             self.index._engine.set_value(values, key, value)
#    1055             return
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: 'slice(None, None, None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-23766539499e> in <module>
# ----> 1 ax = sns.stripplot(x='CDK6', y='CDK4', data=allGenes)
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2796                        linewidth=linewidth))
#    2797
# -> 2798     plotter.plot(ax, kwargs)
#    2799     return ax
#    2800
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1187     def plot(self, ax, kws):
#    1188         """Make the plot."""
# -> 1189         self.draw_stripplot(ax, kws)
#    1190         self.add_legend_data(ax)
#    1191         self.annotate_axes(ax)
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in draw_stripplot(self, ax, kws)
#    1156
#    1157                 strip_data = group_data[hue_mask]
# -> 1158                 point_colors = np.asarray(self.point_colors[i][hue_mask])
#    1159
#    1160                 # Plot the points in centered positions
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in point_colors(self)
#    1096                 # Use the same color for all points at this level
#    1097                 # group_color = self.colors[i]
# -> 1098                 group_colors[:] = i
#    1099
#    1100             else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1040                     pass
#    1041
# -> 1042             self._set_with(key, value)
#    1043
#    1044         if cacher_needs_updating:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_with(self, key, value)
#    1062         if isinstance(key, slice):
#    1063             indexer = self.index._convert_slice_indexer(key, kind="getitem")
# -> 1064             return self._set_values(indexer, value)
#    1065
#    1066         elif is_scalar(key) and not is_integer(key) and key not in self.index:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_values(self, key, value)
#    1109         if isinstance(key, Series):
#    1110             key = key._values
# -> 1111         self._data = self._data.setitem(indexer=key, value=value)
#    1112         self._maybe_update_cacher()
#    1113
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5284
#    5285         try:
# -> 5286             object.__getattribute__(self, name)
#    5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#
# KeyboardInterrupt:

# %%
mydata = pd.DataFrame({'subtypes':['ALL','AML','AML-M5','Leukemia'],'-log(p)':[3.7,12,7,4.9]})

# %%
plt.style.use('fivethirtyeight')

plt.title('CDK6 CCND3 Enriched Subtypes')
sns.stripplot(x='subtypes', y='-log(p)', data=mydata,s=10)
plt.hlines(2.7,-0.2,3.2,'r')
#plt.label('0.05')
plt.ylim(0,15)
# Out:
# (0.0, 15.0)

# %%
# similar things in the thesis.
