# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dep = pd.read_csv("/home/annerer/Downloads/Achilles_gene_dependency.csv")

# %%
dep.head()
# Out:
#     DepMap_ID  CCLE_Name  CCLE_Names  A1BG (1)  A1CF (29974)   A2M (2)  \
# 0  ACH-000004        0.0         0.0  0.001091      0.004021  0.099893
# 1  ACH-000005        0.0         0.0  0.029417      0.000957  0.001641
# 2  ACH-000007        0.0         0.0  0.003246      0.003033  0.016501
# 3  ACH-000009        0.0         0.0  0.001262      0.006931  0.012980
# 4  ACH-000011        0.0         0.0  0.000211      0.003539  0.007894
#
#    A2ML1 (144568)  A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  ...  \
# 0        0.015456          0.007394        0.092469       0.000051  ...
# 1        0.002380          0.070698        0.193319       0.000791  ...
# 2        0.000984          0.002209        0.001219       0.003403  ...
# 3        0.002929          0.001886        0.010675       0.001864  ...
# 4        0.000015          0.015979        0.109291       0.002602  ...
#
#    ZWILCH (55055)  ZWINT (11130)  ZXDA (7789)  ZXDB (158586)  ZXDC (79364)  \
# ...

# %%
#sns.clustermap(dep)

# %%
dep = dep.drop(["CCLE_Names"],axis=1)

# %%
dep["CCLE_Name"] = sample_info["CCLE_Name"]

# %%
dep.head()
# Out:
#     DepMap_ID                                   CCLE_Name  A1BG (1)  \
# 0  ACH-000004                             NIHOVCAR3_OVARY  0.001091
# 1  ACH-000005     HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.029417
# 2  ACH-000007                       CACO2_LARGE_INTESTINE  0.003246
# 3  ACH-000009      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.001262
# 4  ACH-000011  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.000211
#
#    A1CF (29974)   A2M (2)  A2ML1 (144568)  A3GALT2 (127550)  A4GALT (53947)  \
# 0      0.004021  0.099893        0.015456          0.007394        0.092469
# 1      0.000957  0.001641        0.002380          0.070698        0.193319
# 2      0.003033  0.016501        0.000984          0.002209        0.001219
# 3      0.006931  0.012980        0.002929          0.001886        0.010675
# 4      0.003539  0.007894        0.000015          0.015979        0.109291
#
#    A4GNT (51146)  AAAS (8086)  ...  ZWILCH (55055)  ZWINT (11130)  \
# ...

# %%
dep[dep["CCLE_Name"].str.contains("SOFT")]
# Out:
#       DepMap_ID               CCLE_Name  A1BG (1)  A1CF (29974)   A2M (2)  \
# 50   ACH-000108      TE617T_SOFT_TISSUE  0.023253      0.008052  0.014446
# 53   ACH-000114      HT1080_SOFT_TISSUE  0.008129      0.072469  0.019021
# 95   ACH-000209        G401_SOFT_TISSUE  0.005665      0.002213  0.060843
# 99   ACH-000217        RH41_SOFT_TISSUE  0.000905      0.013368  0.005570
# 132  ACH-000264       HS729_SOFT_TISSUE  0.001433      0.000290  0.049594
# 144  ACH-000281      SKLMS1_SOFT_TISSUE  0.002036      0.000608  0.015738
# 159  ACH-000310        BT12_SOFT_TISSUE  0.007908      0.000240  0.010153
# 168  ACH-000322          RD_SOFT_TISSUE  0.000231      0.001467  0.013795
# 171  ACH-000326        TM87_SOFT_TISSUE  0.001496      0.005123  0.084610
# 200  ACH-000377        A204_SOFT_TISSUE  0.002507      0.004661  0.006399
# 374  ACH-000681        G402_SOFT_TISSUE  0.004896      0.000902  0.066414
# 448  ACH-000805       MESSA_SOFT_TISSUE  0.001063      0.003928  0.017590
# ...

# %%
dep["CCLE_Name"][3]
sample_info["CCLE_Name"][2]
# Out:
# 'CACO2_LARGE_INTESTINE'

# %%
#for x in sample_info["DepMap_ID"]:
#    print(x)

# %%
#dep.insert(dep,dep["CCLE_Name"],sample_info["CCLE_Name"][1])

# %%
#dep["new"] =  dep.apply(lambda row: dep["A1BG"] + dep["A2M"], axis=1)

# %%
#dep.insert(1,"CCLE_Name",np.zeros(len(dep)))

#for x in dep["DepMap_ID"]:
#    for i in sample_info["DepMap_ID"]:
#        if x == i:
 #           dep.insert(dep[x],["CCLE_Name"],sample_info["CCLE_Name"][i])

# %%
sample_info = pd.read_csv("/home/annerer/Downloads/sample_info.csv")

# %%
sample_info.shape
# Out:
# (1804, 24)

# %%
mydata = sample_info[sample_info["CCLE_Name"].str.contains("LUNG")]

plt.hist(mydata["cell_line_NNMD"],20,lw=2)
plt.tight_layout()

# %%
sample_info.shape
# Out:
# (1804, 24)

# %%
#sample_info.columns.values

# %%
soft = sample_info[sample_info["CCLE_Name"].str.contains("SOFT")]
soft["DepMap_ID"]
# Out:
# 50      ACH-000051
# 53      ACH-000054
# 95      ACH-000096
# 99      ACH-000100
# 132     ACH-000133
# 144     ACH-000145
# 159     ACH-000160
# 168     ACH-000169
# 171     ACH-000172
# 200     ACH-000201
# 374     ACH-000375
# 448     ACH-000449
# 502     ACH-000505
# 530     ACH-000533
# 594     ACH-000597
# 604     ACH-000607
# 686     ACH-000689
# 769     ACH-000772
# 830     ACH-000833
# 832     ACH-000835
# 936     ACH-000939
# 1009    ACH-001020
# 1014    ACH-001028
# 1017    ACH-001031
# 1034    ACH-001050
# 1040    ACH-001059
# 1065    ACH-001096
# 1068    ACH-001099
# 1074    ACH-001109
# 1085    ACH-001128
#            ...
# 1157    ACH-001289
# 1168    ACH-001322
# 1249    ACH-001433
# 1293    ACH-001532
# 1297    ACH-001540
# 1381    ACH-001702
# 1394    ACH-001740
# 1395    ACH-001741
# 1396    ACH-001743
# 1397    ACH-001745
# 1398    ACH-001750
# 1399    ACH-001751
# 1400    ACH-001765
# 1401    ACH-001767
# 1403    ACH-001790
# 1404    ACH-001791
# ...

# %%
dep.shape
# Out:
# (769, 18120)

# %%
dep[dep['DepMap_ID'].str.match('ACH-001')].iloc[1:10,0:10]
# Out:
#       DepMap_ID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 564  ACH-001020  0.003467      0.029927  0.022542        0.042352
# 565  ACH-001028  0.000936      0.016149  0.021864        0.001192
# 566  ACH-001031  0.004921      0.024824  0.007917        0.001662
# 567  ACH-001033  0.072529      0.008470  0.009584        0.000028
# 568  ACH-001038  0.001336      0.003457  0.014906        0.000298
# 569  ACH-001048  0.024705      0.016067  0.031072        0.001308
# 570  ACH-001050  0.002386      0.001150  0.034396        0.002918
# 571  ACH-001053  0.000265      0.004721  0.019786        0.000847
# 572  ACH-001054  0.006488      0.000053  0.008099        0.000055
#
#      A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 564          0.096680        0.004838       0.006590     0.372595
# 565          0.005692        0.024753       0.002297     0.462472
# 566          0.036587        0.003232       0.004335     0.750090
# ...

# %%
dep.filter(regex='CDK')
# Out:
#      CDK1 (983)  CDK10 (8558)  CDK11A (728642)  CDK12 (51755)  CDK13 (8621)  \
# 0      0.999974      0.098887         0.968504       0.155826      0.000151
# 1      0.999835      0.153036         0.957097       0.097856      0.083194
# 2      1.000000      0.200331         0.997486       0.524141      0.317320
# 3      0.993440      0.121890         0.997562       0.536190      0.476747
# 4      0.998478      0.170659         0.998919       0.225989      0.484910
# 5      0.999357      0.324152         0.994714       0.510088      0.233850
# 6      1.000000      0.092181         0.998693       0.865351      0.574539
# 7      0.999998      0.000290         0.974500       0.318740      0.045718
# 8      0.999841      0.135596         0.982511       0.107265      0.004339
# 9      0.996964      0.170833         0.965463       0.530443      0.000100
# 10     0.999990      0.078673         0.997617       0.066544      0.083787
# ...

# %%
dep.columns.values.filter(regex="SOFT")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-d7f3ed5e8769> in <module>
# ----> 1 dep.columns.values.filter(regex="SOFT")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'filter'

# %%
dep.columns.values
# Out:
# array(['DepMap_ID', 'A1BG (1)', 'A1CF (29974)', ..., 'ZYX (7791)',
#        'ZZEF1 (23140)', 'ZZZ3 (26009)'], dtype=object)

# %%
dep[dep[0].str.match('SOFT')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-4a5b4ec30a74> in <module>
# ----> 1 dep[dep[0].str.match('SOFT')]
#
# ...

# %%
plt.pcolor(sub,edgecolors='k', linewidths=4)
