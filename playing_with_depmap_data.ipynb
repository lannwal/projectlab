# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dep = pd.read_csv("/home/annerer/Downloads/Achilles_gene_dependency.csv")

# %%
dep[dep['DepMap_ID'].str.match('ACH-001')].iloc[1:10,0:10]
# Out:
#       DepMap_ID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 564  ACH-001020  0.003467      0.029927  0.022542        0.042352
# 565  ACH-001028  0.000936      0.016149  0.021864        0.001192
# 566  ACH-001031  0.004921      0.024824  0.007917        0.001662
# 567  ACH-001033  0.072529      0.008470  0.009584        0.000028
# 568  ACH-001038  0.001336      0.003457  0.014906        0.000298
# 569  ACH-001048  0.024705      0.016067  0.031072        0.001308
# 570  ACH-001050  0.002386      0.001150  0.034396        0.002918
# 571  ACH-001053  0.000265      0.004721  0.019786        0.000847
# 572  ACH-001054  0.006488      0.000053  0.008099        0.000055
#
#      A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 564          0.096680        0.004838       0.006590     0.372595
# 565          0.005692        0.024753       0.002297     0.462472
# 566          0.036587        0.003232       0.004335     0.750090
# ...

# %%
dep.filter(regex='CDK')
# Out:
#      CDK1 (983)  CDK10 (8558)  CDK11A (728642)  CDK12 (51755)  CDK13 (8621)  \
# 0      0.999974      0.098887         0.968504       0.155826      0.000151
# 1      0.999835      0.153036         0.957097       0.097856      0.083194
# 2      1.000000      0.200331         0.997486       0.524141      0.317320
# 3      0.993440      0.121890         0.997562       0.536190      0.476747
# 4      0.998478      0.170659         0.998919       0.225989      0.484910
# 5      0.999357      0.324152         0.994714       0.510088      0.233850
# 6      1.000000      0.092181         0.998693       0.865351      0.574539
# 7      0.999998      0.000290         0.974500       0.318740      0.045718
# 8      0.999841      0.135596         0.982511       0.107265      0.004339
# 9      0.996964      0.170833         0.965463       0.530443      0.000100
# 10     0.999990      0.078673         0.997617       0.066544      0.083787
# ...

# %%
dep.columns.values.filter(regex="SOFT")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-d7f3ed5e8769> in <module>
# ----> 1 dep.columns.values.filter(regex="SOFT")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'filter'

# %%
dep['DepMap_ID']
# Out:
# 0      ACH-000004
# 1      ACH-000005
# 2      ACH-000007
# 3      ACH-000009
# 4      ACH-000011
# 5      ACH-000012
# 6      ACH-000013
# 7      ACH-000014
# 8      ACH-000015
# 9      ACH-000017
# 10     ACH-000018
# 11     ACH-000019
# 12     ACH-000021
# 13     ACH-000022
# 14     ACH-000024
# 15     ACH-000025
# 16     ACH-000028
# 17     ACH-000029
# 18     ACH-000030
# 19     ACH-000035
# 20     ACH-000036
# 21     ACH-000037
# 22     ACH-000039
# 23     ACH-000040
# 24     ACH-000041
# 25     ACH-000042
# 26     ACH-000045
# 27     ACH-000047
# 28     ACH-000048
# 29     ACH-000052
#           ...
# 739    ACH-001814
# 740    ACH-001835
# 741    ACH-001836
# 742    ACH-001838
# 743    ACH-001841
# 744    ACH-001842
# 745    ACH-001843
# 746    ACH-001848
# 747    ACH-001849
# 748    ACH-001852
# 749    ACH-001853
# 750    ACH-001856
# 751    ACH-001857
# 752    ACH-001858
# 753    ACH-001864
# 754    ACH-001955
# 755    ACH-001956
# 756    ACH-001957
# 757    ACH-001959
# ...

# %%
dep[dep[0].str.match('SOFT')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-4a5b4ec30a74> in <module>
# ----> 1 dep[dep[0].str.match('SOFT')]
#
# ...

# %%
plt.pcolor(sub,edgecolors='k', linewidths=4)
